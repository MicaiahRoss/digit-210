# %% [markdown]
# ## Words to Network Data
#
# Now that we know some ways to pull an interesting selection of words, let's think about them like a network. Network analysis involves looking at how things relate to each other based on shared properties.
#
# In this notebook, we will address a simple research question: Which **files** (or **chapters**, or **scenes**, or **authors**, or **titles**) share each others' top 5 or 10 **verbs** (or **adjectives**, or **nouns**, or **WordNet synsets**, etc)?
#
# We will try exploring this as a network of data and import it into network visualization software.
#
# ### Installs in your Terminal
# * If you did not do this in the previous notebook: `pip install spacy`
# * We need the **pandas** library to make dataframes: `pip install pandas`
#
# <pre>
#     ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣤⣶⣿⣷⣦⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢸⣿⣿⣿⣿⣿⡇⠀⠀⠀⠀⠀⠀⠀⣰⣿⣿⣿⣦⡀
# ⠀⠀⠀⠀⢀⠄⠀⠀⠀⠀⢈⣿⣿⣿⠟⠛⠁⠀⠀⠀⠀⠀⠀⠐⢿⣿⣿⣿⣿⣷
# ⠀⠀⢀⡔⠁⠀⠀⠀⢀⣴⡿⠃⠈⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⢿⣿⠟⠁
# ⠀⣠⡟⠀⠀⠀⠀⣰⣿⣿⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⢠⣿⠁⠀⠀⠀⢰⣿⣿⡏⠀⠀⠀⢀⣤⣤⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⣾⣿⠀⠀⠀⠀⢸⣿⣿⡇⠀⠀⢠⣿⣿⣿⣿⠀⠀⠀⠀⣰⣾⣶⣆⠀⠀⠀⠀⡄
# ⣿⣿⡀⠀⠀⠀⢸⣿⣿⣧⠀⠀⢸⣿⣿⡿⠃⠀⠀⠀⠀⢿⣿⣿⣿⡆⠀⠀⢸⣧
# ⢿⣿⣧⠀⠀⠀⢸⣿⣿⣿⣦⡀⠀⠉⠉⠀⠀⠀⠀⠀⠀⠈⠻⣿⠿⠁⠀⢠⣿⣿
# ⢸⣿⣿⣷⣄⠀⣿⣿⣿⣿⣿⣿⣷⣦⣄⠀⠲⣶⣶⣶⠀⠀⠀⠀⠀⣀⣴⣿⣿⣿
# ⢰⣿⣿⣿⣿⣷⣽⣿⣿⣿⣿⣿⣿⣿⣿⣦⡄⣬⣅⣀⣠⣾⣿⣿⣿⣿⣿⣿⣿⡟
# ⠈⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⣤⣤⣾⣿⣿⣿⣿⣿⣿⣿⣿⣿⠇
# ⠀⠹⣿⣿⣿⣿⣿⣿⢿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡏⠀⠈⣿⣿⣿⣿⣿⣿⣿⡿⠀
# ⠀⠀⠻⣿⣿⣿⣿⣿⡎⢿⣿⣿⣿⣿⣿⣿⣿⣿⡇⠀⠀⣿⣿⣿⣿⣿⣿⣿⠃⠀
# ⠀⠀⠀⠙⠻⠿⣿⣿⠗⠀⢻⣿⣿⣿⣿⣿⣿⣿⡇⠀⢸⣿⣿⣿⣿⣿⡿⠃⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠹⣿⣿⣿⣿⣿⣿⣿⠀⢸⣿⣿⣿⡿⠟⠁⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠛⠿⢿⣿⣿⡿⠇⠀⠈⠉⠁⠀⠀⠀⠀⠀⠀
# </pre>
#
#
#
# Image credit: <https://emojicombos.com/panda-ascii-art>
#
# ### Language Models
# Like NLTK's collections that we downloaded, [spaCy has trained language models](https://spacy.io/usage/models) to download. You download these in your Python script after you import spacy, and after you download once, you don't need to do it again (so you can comment out the download line). We're going to try the medium and large models in English. (It's good to know that both spaCy and NLTK have resources for NLP on other languages, too!)

# %%
import spacy
import os

# %% [markdown]
# ### Downloading language models
# To work with spaCy's pre-trained language models, you need to download them to you virtual environment. There are:
# * en_core_web_sm (smallest--not as much info as the others)
# * **en_core_web_md** (Pretty good date here, size: 34 MB )
# * **en_core_web_lg** (Lots of data here, size: 400 MB.)
# Note that the LARGEST  one will have the most data and probably be the most reliable.

# %%
# CAN YOU SKIP THIS???
# After you download a model into your virtual environment for the first time, you can comment out the download line.
# spaCy's medium and large models will give us the best results for NLP tagging.
# nlp = spacy.cli.download("en_core_web_sm")
# nlp = spacy.cli.download("en_core_web_md")
nlp = spacy.cli.download("en_core_web_lg")
# Out:
# Collecting en-core-web-lg==3.8.0
#   Downloading en_core_web_lg-3.8.0-py3-none-any.whl (400.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.7/400.7 MB 49.5 MB/s  0:00:07:00:0100:01
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %% [markdown]
# ### Load the model
# Now we redefine the nlp variable to LOAD the model you downloaded.

# %%
nlp = spacy.load("en_core_web_lg")

# %% [markdown]
# ## File Collection
# You can set this to read a collection of text files that you've prepped for natural language processing.
# For this notebook, we'll work with just the dialogue text we pulled from the One Piece project.
# The text is organized as one file for each volume of OnePiece, so we can maybe explore how much the dialogue is relying on certain words, and how it might be changing over the volumes.
#
# We're going to get volume information from OnePiece's filenames (which look like this: `vol-9.txt'. We can use the `os` library to help us isolate the filename from the file extension. Let's try that so we can simplify our references to the volumes when we output our data.

# %%
collPath = 'jojo'
for file in os.listdir(collPath):
    if file.endswith(".txt"):
        filepath = f"{collPath}/{file}"
        name, extension = os.path.splitext(file)
        print(name)
        with open(filepath, 'r', encoding='utf8') as f:
            readFile = f.read()
            lengthFile = len(readFile)
            print(lengthFile)
# We're just printing out the filepaths and lengths of the files as a "smoke test" to see if we're reading the files.
# Out:
# 04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_
# 16740
# 04x34_-_The_Requiem_Quietly_Plays__Part_1
# 15365
# 04x05_-_Find_Polpo_s_Fortune__-_Let_s_Find_Polpo_s_Fortune_
# 20476
# 04x35_-_The_Requiem_Quietly_Plays__Part_2
# 14539
# 04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem
# 16102
# 04x14_-_Express_Train_to_Florence_-_Il_Treno_Espresso_per_Firenze
# 16066
# 04x37_-_King_of_Kings
# 11981
# 04x07_-_Sex_Pistols_Appears__Part_1_-_Six_b_ll_ts_Appears__Part_1
# 16084
# 04x09_-_The_First_Mission_from_the_Boss
# 20199
# 04x28_-_Beneath_a_Sky_on_the_Verge_of_Falling
# 16410
# 04x22_-_The__G__in_Guts_-_The__G__in_Gozzo
# 15012
# 04x21_5_-_Determination
# 17535
# 04x29_-_Get_to_the_Roman_Colosseum__-_Verso_il_Colosseo_di_Roma
# 18818
# 04x20_-_The_Final_Mission_from_the_Boss
# 16543
# 04x16_-_The_Grateful_Dead__Part_2_-_Thankful_Death__Part_2
# 14324
# 04x08_-_Sex_Pistols_Appears__Part_2_-_Six_b_ll_ts_Appears__Part_2
# 16190
# 04x32_-_Green_Day_and_Oasis__Part_3_-_Green_Tea_and_Sanctuary__Part_3
# 14539
# 04x30_-_Green_Day_and_Oasis__Part_1_-_Green_Tea_and_Sanctuary__Part_1
# 15691
# 04x39_-_The_Sleeping_sl_ve
# 14754
# 04x18_-_Head_to_Venice__-_Verso_Venezia
# 16180
# 04x27_-_King_Crimson_vs__Metallica_-_Emperor_Crimson_vs__Metallic
# 17072
# 04x17_-_Baby_Face_-_Babyhead
# 17657
# 04x12_-_The_Second_Mission_from_the_Boss
# 17196
# 04x03_-_Meet_the_Gangster_Behind_the_Wall_-_Meet_the_Mafioso_Behind_the_Wall
# 15288
# 04x21_-_The_Mystery_of_King_Crimson_-_The_Mystery_of_Emperor_Crimson
# 17500
# 04x11_-_Narancia_s_Aerosmith_-_Narancia_s_Li_l_Bomber
# 16222
# 04x23_-_Clash_and_Talking_Head_-_Crush_and_Talking_Mouth
# 14899
# 04x06_-_Moody_Blues__Counterattack_-_Moody_Jazz_s_Counterattack
# 14703
# 04x02_-_Bucciarati_Is_Coming_-_Bucciarati_Appears
# 16250
# 04x36_-_Diavolo_Surfaces
# 16583
# 04x13_-_Man_in_the_Mirror_and_Purple_Haze_-_Mirror_Man_and_Purple_Smoke
# 14335
# 04x28_5_-_Destiny
# 17675
# 04x01_-_Gold_Experience_-_Golden_Wind
# 19182
# 04x31_-_Green_Day_and_Oasis__Part_2_-_Green_Tea_and_Sanctuary__Part_2
# 13995
# 04x13_5_-_The_Beginning_of_Golden_Wind
# 16297
# 04x25_-_Spice_Girl_-_Spicy_Lady
# 14335
# 04x04_-_Joining_the_g_ng_-_Joining_the_Famiglia
# 14426
# 04x15_-_The_Grateful_Dead__Part_1_-_Thankful_Death__Part_1
# 13907
# 04x19_-_White_Album_-_White_Ice
# 16396
# 04x10_-_Hitman_Team
# 15208
# 04x33_-_His_Name_Is_Diavolo
# 16421
# 04x24_-_Notorious_B_I_G_-_Notorious_Chase
# 14292

# %% [markdown]
# ## Collect some words with a little help from spaCy
# Let's build this up to go file by file. We'll start by surveying what we have...(Ultimately we want to collect the top 5 or 10 most frequently repeating words of a kind.)

# %%
# SURVEY IT ALL! :-) (Yeah, lots of data...)
for file in os.listdir(collPath):
    if file.endswith(".txt"):
        filepath = f"{collPath}/{file}"
        name, extension = os.path.splitext(file)
        print(name)
        with open(filepath, 'r', encoding='utf8') as f:
            readFile = f.read()
            spacyRead = nlp(readFile)
            for token in spacyRead:
                print(token.text, "---->", token.pos_, ":::::", token.lemma_)
# Out:
# 04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_
# JoJo ----> PROPN ::::: JoJo
# - ----> PUNCT ::::: -
# EpTitle ----> PROPN ::::: EpTitle
# , ----> PUNCT ::::: ,
# Sign ----> NOUN ::::: sign
# : ----> PUNCT ::::: :
# Episodio ----> PROPN ::::: Episodio
#   ----> SPACE :::::
# A ----> DET ::::: a
# Little ----> PROPN ::::: Little
# Story ----> PROPN ::::: Story
# From ----> ADP ::::: from
# the ----> DET ::::: the
# Past ----> NOUN ::::: past
# ~My ----> DET ::::: ~my
# Name ----> NOUN ::::: name
# Is ----> AUX ::::: be
# Doppio~ ----> PROPN ::::: Doppio~
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Nar ----> NOUN ::::: nar
# : ----> PUNCT ::::: :
# This ----> PRON ::::: this
# is ----> AUX ::::: be
# a ----> DET ::::: a
# little ----> ADJ ::::: little
# story ----> NOUN ::::: story
# from ----> ADP ::::: from
# the ----> DET ::::: the
# past ----> NOUN ::::: past
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Sign ----> NOUN ::::: sign
# : ----> PUNCT ::::: :
# Summer ----> PROPN ::::: Summer
# , ----> PUNCT ::::: ,
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Nar ----> NOUN ::::: nar
# : ----> PUNCT ::::: :
# We ----> PRON ::::: we
# 're ----> AUX ::::: be
# going ----> VERB ::::: go
# back ----> ADV ::::: back
# to ----> ADP ::::: to
# the ----> DET ::::: the
# summer ----> NOUN ::::: summer
# of ----> ADP ::::: of
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Lady ----> PROPN ::::: Lady
# : ----> PUNCT ::::: :
# Prisoner ----> PROPN ::::: Prisoner
# ! ----> PUNCT ::::: !
# What ----> PRON ::::: what
# 's ----> AUX ::::: be
# going ----> VERB ::::: go
# on ----> ADP ::::: on
# here ----> ADV ::::: here
# ? ----> PUNCT ::::: ?
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Lady ----> PROPN ::::: Lady
# : ----> PUNCT ::::: :
# Prisoner ----> PROPN ::::: Prisoner
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# JoJo ----> PROPN ::::: JoJo
# - ----> PUNCT ::::: -
# flashback ----> NOUN ::::: flashback
# : ----> PUNCT ::::: :
# , ----> PUNCT ::::: ,
# Did ----> AUX ::::: do
# you ----> PRON ::::: you
# eat ----> VERB ::::: eat
# something ----> PRON ::::: something
# bad ----> ADJ ::::: bad
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Lady ----> PROPN ::::: Lady
# : ----> PUNCT ::::: :
# She ----> PRON ::::: she
# 's ----> AUX ::::: be
# pregnant ----> ADJ ::::: pregnant
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# JoJo ----> PROPN ::::: JoJo
# - ----> PUNCT ::::: -
# flashback ----> NOUN ::::: flashback
# : ----> PUNCT ::::: :
# , ----> PUNCT ::::: ,
# This ----> PRON ::::: this
# is ----> AUX ::::: be
# a ----> DET ::::: a
# women ----> NOUN ::::: woman
# 's ----> PART ::::: 's
# prison ----> NOUN ::::: prison
# on ----> ADP ::::: on
# a ----> DET ::::: a
# remote ----> ADJ ::::: remote
# island ----> NOUN ::::: island
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Lady ----> PROPN ::::: Lady
# : ----> PUNCT ::::: :
# There ----> PRON ::::: there
# are ----> VERB ::::: be
# only ----> ADV ::::: only
# women ----> NOUN ::::: woman
# here ----> ADV ::::: here
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Lady ----> PROPN ::::: Lady
# : ----> PUNCT ::::: :
# Not ----> PART ::::: not
# to ----> PART ::::: to
# mention ----> VERB ::::: mention
# , ----> PUNCT ::::: ,
# this ----> DET ::::: this
# prisoner ----> NOUN ::::: prisoner
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# JoJo ----> PROPN ::::: JoJo
# - ----> PUNCT ::::: -
# flashback ----> NOUN ::::: flashback
# : ----> PUNCT ::::: :
# , ----> PUNCT ::::: ,
# was ----> AUX ::::: be
# sentenced ----> VERB ::::: sentence
# to ----> ADP ::::: to
# ten ----> NUM ::::: ten
# years ----> NOUN ::::: year
# for ----> ADP ::::: for
# bank ----> NOUN ::::: bank
# robbery ----> NOUN ::::: robbery
# and ----> CCONJ ::::: and
# as*ault ----> NOUN ::::: as*ault
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Lady ----> PROPN ::::: Lady
# : ----> PUNCT ::::: :
# She ----> PRON ::::: she
# 's ----> AUX ::::: be
# been ----> AUX ::::: be
# here ----> ADV ::::: here
# for ----> ADP ::::: for
# two ----> NUM ::::: two
# years ----> NOUN ::::: year
# already ----> ADV ::::: already
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Lady ----> PROPN ::::: Lady
# : ----> PUNCT ::::: :
# Push ----> VERB ::::: push
# ! ----> PUNCT ::::: !
# Just ----> ADV ::::: just
# a ----> DET ::::: a
# little ----> ADJ ::::: little
# bit ----> NOUN ::::: bit
# more ----> ADJ ::::: more
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Lady ----> PROPN ::::: Lady
# : ----> PUNCT ::::: :
# When ----> SCONJ ::::: when
# could ----> AUX ::::: could
# she ----> PRON ::::: she
# have ----> AUX ::::: have
# gotten ----> VERB ::::: get
# pregnant ----> ADJ ::::: pregnant
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# JoJo ----> PROPN ::::: JoJo
# - ----> PUNCT ::::: -
# flashback ----> NOUN ::::: flashback
# : ----> PUNCT ::::: :
# , ----> PUNCT ::::: ,
# She ----> PRON ::::: she
# was ----> AUX ::::: be
# n't ----> PART ::::: not
# big ----> ADJ ::::: big
# earlier ----> ADV ::::: early
# today ----> NOUN ::::: today
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Lady ----> PROPN ::::: Lady
# : ----> PUNCT ::::: :
# And ----> CCONJ ::::: and
# now ----> ADV ::::: now
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Lady ----> PROPN ::::: Lady
# : ----> PUNCT ::::: :
# Hey ----> INTJ ::::: hey
# , ----> PUNCT ::::: ,
# you ----> PRON ::::: you
# ! ----> PUNCT ::::: !
# Who ----> PRON ::::: who
# the ----> DET ::::: the
# hell ----> NOUN ::::: hell
# 's ----> PART ::::: 's
# this ----> DET ::::: this
# kid ----> NOUN ::::: kid
# 's ----> PART ::::: 's
# father ----> NOUN ::::: father
# ? ----> PUNCT ::::: ?
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Inmate ----> PROPN ::::: Inmate
# : ----> PUNCT ::::: :
# He ----> PRON ::::: he
# 's ----> AUX ::::: be
# ... ----> PUNCT ::::: ...
# dead ----> ADJ ::::: dead
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Inamate ----> PROPN ::::: Inamate
# : ----> PUNCT ::::: :
# For ----> ADP ::::: for
# over ----> ADP ::::: over
# two ----> NUM ::::: two
# years ----> NOUN ::::: year
# ... ----> PUNCT ::::: ...
# now ----> ADV ::::: now
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Lady ----> PROPN ::::: Lady
# : ----> PUNCT ::::: :
# You ----> PRON ::::: you
# ca ----> AUX ::::: can
# n't ----> PART ::::: not
# be ----> AUX ::::: be
# serious ----> ADJ ::::: serious
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# JoJo ----> PROPN ::::: JoJo
# - ----> PUNCT ::::: -
# flashback ----> NOUN ::::: flashback
# : ----> PUNCT ::::: :
# , ----> PUNCT ::::: ,
# A ----> DET ::::: a
# barnacle ----> NOUN ::::: barnacle
# growing ----> VERB ::::: grow
# in ----> ADP ::::: in
# your ----> PRON ::::: your
# knee ----> NOUN ::::: knee
# would ----> AUX ::::: would
# be ----> AUX ::::: be
# more ----> ADV ::::: more
# believable ----> ADJ ::::: believable
# than ----> ADP ::::: than
# that ----> PRON ::::: that
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Lady ----> PROPN ::::: Lady
# : ----> PUNCT ::::: :
# Looks ----> VERB ::::: look
# like ----> SCONJ ::::: like
# the ----> DET ::::: the
# baby ----> NOUN ::::: baby
# made ----> VERB ::::: make
# it ----> PRON ::::: it
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Lady ----> PROPN ::::: Lady
# : ----> PUNCT ::::: :
# Yes ----> INTJ ::::: yes
# ... ----> PUNCT ::::: ...
# But ----> CCONJ ::::: but
# something ----> PRON ::::: something
# 's ----> AUX ::::: be
# strange ----> ADJ ::::: strange
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# JoJo ----> PROPN ::::: JoJo
# - ----> PUNCT ::::: -
# flashback ----> NOUN ::::: flashback
# : ----> PUNCT ::::: :
# , ----> PUNCT ::::: ,
# The ----> DET ::::: the
# baby ----> NOUN ::::: baby
# 's ----> PART ::::: 's
# eyes ----> NOUN ::::: eye
# have ----> AUX ::::: have
# been ----> AUX ::::: be
# open ----> ADJ ::::: open
# ever ----> ADV ::::: ever
# since ----> SCONJ ::::: since
# he ----> PRON ::::: he
# was ----> AUX ::::: be
# born ----> VERB ::::: bear
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Lady ----> PROPN ::::: Lady
# : ----> PUNCT ::::: :
# And ----> CCONJ ::::: and
# he ----> PRON ::::: he
# 's ----> AUX ::::: be
# not ----> PART ::::: not
# crying ----> VERB ::::: cry
# at ----> ADV ::::: at
# all ----> ADV ::::: all
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Lady ----> PROPN ::::: Lady
# : ----> PUNCT ::::: :
# This ----> PRON ::::: this
# goes ----> VERB ::::: go
# without ----> ADP ::::: without
# saying ----> VERB ::::: say
# , ----> PUNCT ::::: ,
# but ----> CCONJ ::::: but
# we ----> PRON ::::: we
# ca ----> AUX ::::: can
# n't ----> PART ::::: not
# raise ----> VERB ::::: raise
# a ----> DET ::::: a
# baby ----> NOUN ::::: baby
# here ----> ADV ::::: here
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Lady ----> PROPN ::::: Lady
# : ----> PUNCT ::::: :
# We ----> PRON ::::: we
# 'll ----> AUX ::::: will
# find ----> VERB ::::: find
# someone ----> PRON ::::: someone
# to ----> PART ::::: to
# take ----> VERB ::::: take
# him ----> PRON ::::: he
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Lady ----> PROPN ::::: Lady
# : ----> PUNCT ::::: :
# Where ----> SCONJ ::::: where
# are ----> AUX ::::: be
# you ----> PRON ::::: you
# from ----> ADP ::::: from
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Inmate ----> PROPN ::::: Inmate
# : ----> PUNCT ::::: :
# Sar ----> PROPN ::::: Sar
# ... ----> PUNCT ::::: ...
# di ----> PROPN ::::: di
# ... ----> PROPN ::::: ...
# nia ----> PROPN ::::: nia
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Nar ----> PROPN ::::: Nar
# : ----> PUNCT ::::: :
# A ----> DET ::::: a
# priest ----> NOUN ::::: priest
# at ----> ADP ::::: at
# a ----> DET ::::: a
# small ----> ADJ ::::: small
# church ----> NOUN ::::: church
# there ----> ADV ::::: there
# took ----> VERB ::::: take
# the ----> DET ::::: the
# child ----> NOUN ::::: child
# in ----> ADP ::::: in
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Nar ----> PROPN ::::: Nar
# : ----> PUNCT ::::: :
# Time ----> PROPN ::::: Time
# passed ----> VERB ::::: pass
# , ----> PUNCT ::::: ,
# and ----> CCONJ ::::: and
# the ----> DET ::::: the
# boy ----> NOUN ::::: boy
# became ----> AUX ::::: became
# known ----> VERB ::::: know
# as ----> ADP ::::: as
# someone ----> PRON ::::: someone
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# JoJo ----> PROPN ::::: JoJo
# - ----> PUNCT ::::: -
# internal ----> ADJ ::::: internal
# / ----> SYM ::::: /
# narrator ----> NOUN ::::: narrator
# : ----> PUNCT ::::: :
# , ----> PUNCT ::::: ,
# rather ----> ADV ::::: rather
# cowardly ----> ADJ ::::: cowardly
# and ----> CCONJ ::::: and
# a ----> DET ::::: a
# bit ----> NOUN ::::: bit
# slow ----> ADJ ::::: slow
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Sign ----> NOUN ::::: sign
# : ----> PUNCT ::::: :
# { ----> PUNCT ::::: {
# \fad(,)\pos(,)\fs}June ----> PROPN ::::: \fad(,)\pos(,)\fs}June
# , ----> PUNCT ::::: ,
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Doppio ----> PROPN ::::: Doppio
# : ----> PUNCT ::::: :
# Well ----> INTJ ::::: well
# , ----> PUNCT ::::: ,
# I ----> PRON ::::: I
# 'll ----> AUX ::::: will
# be ----> AUX ::::: be
# going ----> VERB ::::: go
# now ----> ADV ::::: now
# . ----> PUNCT ::::: .
# See ----> VERB ::::: see
# you ----> PRON ::::: you
# later ----> ADV ::::: later
# , ----> PUNCT ::::: ,
# Mr. ----> PROPN ::::: Mr.
# Frog ----> PROPN ::::: Frog
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Man ----> NOUN ::::: man
# : ----> PUNCT ::::: :
# Hey ----> INTJ ::::: hey
# , ----> PUNCT ::::: ,
# watch ----> VERB ::::: watch
# it ----> PRON ::::: it
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Man ----> NOUN ::::: man
# : ----> PUNCT ::::: :
# Oh ----> INTJ ::::: oh
# , ----> PUNCT ::::: ,
# it ----> PRON ::::: it
# 's ----> AUX ::::: be
# you ----> PRON ::::: you
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Man ----> NOUN ::::: man
# : ----> PUNCT ::::: :
# Walk ----> VERB ::::: walk
# closer ----> ADV ::::: close
# to ----> ADP ::::: to
# the ----> DET ::::: the
# edge ----> NOUN ::::: edge
# , ----> PUNCT ::::: ,
# you ----> PRON ::::: you
# dumbass ----> VERB ::::: dumbass
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Man ----> NOUN ::::: man
# : ----> PUNCT ::::: :
# Do ----> AUX ::::: do
# n't ----> PART ::::: not
# you ----> PRON ::::: you
# dare ----> VERB ::::: dare
# tell ----> VERB ::::: tell
# the ----> DET ::::: the
# priest ----> NOUN ::::: priest
# about ----> ADP ::::: about
# this ----> PRON ::::: this
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Doppio ----> PROPN ::::: Doppio
# : ----> PUNCT ::::: :
# Th ----> PROPN ::::: Th
# - ----> PUNCT ::::: -
# That ----> PRON ::::: that
# was ----> AUX ::::: be
# close ----> ADJ ::::: close
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Doppio ----> PROPN ::::: Doppio
# : ----> PUNCT ::::: :
# But ----> CCONJ ::::: but
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# glad ----> ADJ ::::: glad
# you ----> PRON ::::: you
# did ----> AUX ::::: do
# n't ----> PART ::::: not
# get ----> AUX ::::: get
# squished ----> VERB ::::: squish
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Girl ----> PROPN ::::: Girl
# : ----> PUNCT ::::: :
# Do ----> AUX ::::: do
# you ----> PRON ::::: you
# like ----> VERB ::::: like
# frogs ----> NOUN ::::: frog
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Girl ----> PROPN ::::: Girl
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# like ----> VERB ::::: like
# frogs ----> NOUN ::::: frog
# , ----> PUNCT ::::: ,
# too ----> ADV ::::: too
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# JoJo ----> PROPN ::::: JoJo
# - ----> PUNCT ::::: -
# flashback ----> NOUN ::::: flashback
# : ----> PUNCT ::::: :
# , ----> PUNCT ::::: ,
# I ----> PRON ::::: I
# hate ----> VERB ::::: hate
# bugs ----> NOUN ::::: bug
# , ----> PUNCT ::::: ,
# though ----> ADV ::::: though
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Girl ----> PROPN ::::: Girl
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# also ----> ADV ::::: also
# do ----> AUX ::::: do
# n't ----> PART ::::: not
# like ----> VERB ::::: like
# guys ----> NOUN ::::: guy
# who ----> PRON ::::: who
# smell ----> VERB ::::: smell
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Girl ----> PROPN ::::: Girl
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# hate ----> VERB ::::: hate
# everything ----> PRON ::::: everything
# that ----> PRON ::::: that
# 's ----> AUX ::::: be
# not ----> PART ::::: not
# beautiful ----> ADJ ::::: beautiful
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Girl ----> PROPN ::::: Girl
# : ----> PUNCT ::::: :
# Are ----> AUX ::::: be
# you ----> PRON ::::: you
# from ----> ADP ::::: from
# around ----> ADV ::::: around
# here ----> ADV ::::: here
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Doppio ----> PROPN ::::: Doppio
# : ----> PUNCT ::::: :
# Y ----> PROPN ::::: Y
# - ----> PUNCT ::::: -
# Yeah ----> PROPN ::::: Yeah
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Doppio ----> PROPN ::::: Doppio
# : ----> PUNCT ::::: :
# Say ----> VERB ::::: say
# , ----> PUNCT ::::: ,
# it ----> PRON ::::: it
# 's ----> AUX ::::: be
# a ----> DET ::::: a
# bit ----> NOUN ::::: bit
# hot ----> ADJ ::::: hot
# out ----> ADP ::::: out
# . ----> PUNCT ::::: .
# Want ----> VERB ::::: want
# to ----> PART ::::: to
# get ----> VERB ::::: get
# something ----> PRON ::::: something
# to ----> PART ::::: to
# drink ----> VERB ::::: drink
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Girl ----> NOUN ::::: girl
# : ----> PUNCT ::::: :
# Well ----> INTJ ::::: well
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Girl ----> PROPN ::::: Girl
# : ----> PUNCT ::::: :
# That ----> PRON ::::: that
# 's ----> AUX ::::: be
# not ----> PART ::::: not
# a ----> DET ::::: a
# bad ----> ADJ ::::: bad
# idea ----> NOUN ::::: idea
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Girl ----> PROPN ::::: Girl
# : ----> PUNCT ::::: :
# Then ----> ADV ::::: then
# I ----> PRON ::::: I
# want ----> VERB ::::: want
# sparkling ----> ADJ ::::: sparkling
# water ----> NOUN ::::: water
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Girl ----> PROPN ::::: Girl
# : ----> PUNCT ::::: :
# Hard ----> ADJ ::::: hard
# water ----> NOUN ::::: water
# from ----> ADP ::::: from
# France ----> PROPN ::::: France
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Girl ----> PROPN ::::: Girl
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# hope ----> VERB ::::: hope
# you ----> PRON ::::: you
# 're ----> AUX ::::: be
# treating ----> VERB ::::: treat
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Priest ----> PROPN ::::: Priest
# : ----> PUNCT ::::: :
# You ----> PRON ::::: you
# want ----> VERB ::::: want
# to ----> PART ::::: to
# become ----> VERB ::::: become
# a ----> DET ::::: a
# sailor ----> NOUN ::::: sailor
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Doppio ----> PROPN ::::: Doppio
# : ----> PUNCT ::::: :
# Yeah ----> INTJ ::::: yeah
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Priest ----> PROPN ::::: Priest
# : ----> PUNCT ::::: :
# Well ----> INTJ ::::: well
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# JoJo ----> PROPN ::::: JoJo
# - ----> PUNCT ::::: -
# flashback ----> NOUN ::::: flashback
# : ----> PUNCT ::::: :
# , ----> PUNCT ::::: ,
# You ----> PRON ::::: you
# 're ----> AUX ::::: be
# a ----> DET ::::: a
# simple ----> ADJ ::::: simple
# man ----> NOUN ::::: man
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Priest ----> PROPN ::::: Priest
# : ----> PUNCT ::::: :
# That ----> PRON ::::: that
# 's ----> AUX ::::: be
# probably ----> ADV ::::: probably
# best ----> ADJ ::::: good
# for ----> ADP ::::: for
# you ----> PRON ::::: you
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Priest ----> PROPN ::::: Priest
# : ----> PUNCT ::::: :
# Oh ----> INTJ ::::: oh
# ? ----> PROPN ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Guy ----> PROPN ::::: Guy
# : ----> PUNCT ::::: :
# He ----> PRON ::::: he
# walked ----> VERB ::::: walk
# all ----> DET ::::: all
# this ----> DET ::::: this
# way ----> NOUN ::::: way
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Guy ----> PROPN ::::: Guy
# : ----> PUNCT ::::: :
# Good ----> ADJ ::::: good
# on ----> ADP ::::: on
# him ----> PRON ::::: he
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Priest ----> PROPN ::::: Priest
# : ----> PUNCT ::::: :
# It ----> PRON ::::: it
# might ----> AUX ::::: might
# be ----> AUX ::::: be
# a ----> DET ::::: a
# good ----> ADJ ::::: good
# idea ----> NOUN ::::: idea
# to ----> PART ::::: to
# get ----> VERB ::::: get
# him ----> PRON ::::: he
# a ----> DET ::::: a
# car ----> NOUN ::::: car
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Nar ----> PROPN ::::: Nar
# : ----> PUNCT ::::: :
# In ----> ADP ::::: in
# order ----> NOUN ::::: order
# to ----> PART ::::: to
# build ----> VERB ::::: build
# a ----> DET ::::: a
# garage ----> NOUN ::::: garage
# next ----> ADV ::::: next
# to ----> ADP ::::: to
# his ----> PRON ::::: his
# room ----> NOUN ::::: room
# , ----> PUNCT ::::: ,
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# JoJo ----> PROPN ::::: JoJo
# - ----> PUNCT ::::: -
# internal ----> ADJ ::::: internal
# / ----> SYM ::::: /
# narrator ----> NOUN ::::: narrator
# : ----> PUNCT ::::: :
# , ----> PUNCT ::::: ,
# the ----> DET ::::: the
# priest ----> NOUN ::::: priest
# started ----> VERB ::::: start
# digging ----> VERB ::::: dig
# into ----> ADP ::::: into
# the ----> DET ::::: the
# floor ----> NOUN ::::: floor
# with ----> ADP ::::: with
# a ----> DET ::::: a
# pick ----> NOUN ::::: pick
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Priest ----> PROPN ::::: Priest
# : ----> PUNCT ::::: :
# What ----> PRON ::::: what
# 's ----> AUX ::::: be
# this ----> PRON ::::: this
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Priest ----> PROPN ::::: Priest
# : ----> PUNCT ::::: :
# A ----> DET ::::: a
# corpse ----> NOUN ::::: corpse
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# JoJo ----> PROPN ::::: JoJo
# - ----> PUNCT ::::: -
# flashback ----> NOUN ::::: flashback
# : ----> PUNCT ::::: :
# , ----> PUNCT ::::: ,
# No ----> INTJ ::::: no
# , ----> PUNCT ::::: ,
# it ----> PRON ::::: it
# 's ----> AUX ::::: be
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Nar ----> NOUN ::::: nar
# : ----> PUNCT ::::: :
# As ----> SCONJ ::::: as
# he ----> PRON ::::: he
# carefully ----> ADV ::::: carefully
# picked ----> VERB ::::: pick
# at ----> ADP ::::: at
# the ----> DET ::::: the
# concrete ----> NOUN ::::: concrete
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Nar ----> PROPN ::::: Nar
# : ----> PUNCT ::::: :
# The ----> DET ::::: the
# person ----> NOUN ::::: person
# he ----> PRON ::::: he
# discovered ----> VERB ::::: discover
# was ----> AUX ::::: be
# a ----> DET ::::: a
# woman ----> NOUN ::::: woman
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Nar ----> PROPN ::::: Nar
# : ----> PUNCT ::::: :
# It ----> PRON ::::: it
# was ----> AUX ::::: be
# the ----> DET ::::: the
# woman ----> NOUN ::::: woman
# who ----> PRON ::::: who
# gave ----> VERB ::::: give
# birth ----> NOUN ::::: birth
# to ----> ADP ::::: to
# the ----> DET ::::: the
# boy ----> NOUN ::::: boy
# the ----> DET ::::: the
# priest ----> NOUN ::::: priest
# took ----> VERB ::::: take
# in ----> ADP ::::: in
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Priest ----> PROPN ::::: Priest
# : ----> PUNCT ::::: :
# Sh ----> PROPN ::::: Sh
# - ----> PUNCT ::::: -
# She ----> PROPN ::::: She
# 's ----> AUX ::::: be
# alive ----> ADJ ::::: alive
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Nar ----> PROPN ::::: Nar
# : ----> PUNCT ::::: :
# She ----> PRON ::::: she
# could ----> AUX ::::: could
# n't ----> PART ::::: not
# move ----> VERB ::::: move
# nor ----> CCONJ ::::: nor
# talk ----> VERB ::::: talk
# , ----> PUNCT ::::: ,
# but ----> CCONJ ::::: but
# somehow ----> ADV ::::: somehow
# , ----> PUNCT ::::: ,
# she ----> PRON ::::: she
# was ----> AUX ::::: be
# being ----> AUX ::::: be
# kept ----> VERB ::::: keep
# alive ----> ADJ ::::: alive
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Nar ----> PROPN ::::: Nar
# : ----> PUNCT ::::: :
# How ----> SCONJ ::::: how
# many ----> ADJ ::::: many
# years ----> NOUN ::::: year
# had ----> AUX ::::: have
# it ----> PRON ::::: it
# been ----> AUX ::::: be
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# JoJo ----> PROPN ::::: JoJo
# - ----> PUNCT ::::: -
# internal ----> ADJ ::::: internal
# / ----> SYM ::::: /
# narrator ----> NOUN ::::: narrator
# : ----> PUNCT ::::: :
# , ----> PUNCT ::::: ,
# The ----> DET ::::: the
# woman ----> NOUN ::::: woman
# had ----> VERB ::::: have
# no ----> DET ::::: no
# sense ----> NOUN ::::: sense
# of ----> ADP ::::: of
# time ----> NOUN ::::: time
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Nar ----> PROPN ::::: Nar
# : ----> PUNCT ::::: :
# Hatred ----> PROPN ::::: Hatred
# ? ----> PUNCT ::::: ?
# Love ----> NOUN ::::: love
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# JoJo ----> PROPN ::::: JoJo
# - ----> PUNCT ::::: -
# internal ----> ADJ ::::: internal
# / ----> SYM ::::: /
# narrator ----> NOUN ::::: narrator
# : ----> PUNCT ::::: :
# , ----> PUNCT ::::: ,
# Her ----> PRON ::::: her
# heart ----> NOUN ::::: heart
# was ----> AUX ::::: be
# dark ----> ADJ ::::: dark
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Priest ----> PROPN ::::: Priest
# : ----> PUNCT ::::: :
# This ----> DET ::::: this
# hair ----> NOUN ::::: hair
# color ----> NOUN ::::: color
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Nar ----> PROPN ::::: Nar
# : ----> PUNCT ::::: :
# That ----> DET ::::: that
# night ----> NOUN ::::: night
# , ----> PUNCT ::::: ,
# the ----> DET ::::: the
# whole ----> ADJ ::::: whole
# village ----> NOUN ::::: village
# burned ----> VERB ::::: burn
# , ----> PUNCT ::::: ,
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# JoJo ----> PROPN ::::: JoJo
# - ----> PUNCT ::::: -
# internal ----> ADJ ::::: internal
# / ----> SYM ::::: /
# narrator ----> NOUN ::::: narrator
# : ----> PUNCT ::::: :
# , ----> PUNCT ::::: ,
# with ----> ADP ::::: with
# strong ----> ADJ ::::: strong
# winds ----> NOUN ::::: wind
# carrying ----> VERB ::::: carry
# the ----> DET ::::: the
# fire ----> NOUN ::::: fire
# to ----> ADP ::::: to
# every ----> DET ::::: every
# single ----> ADJ ::::: single
# house ----> NOUN ::::: house
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Nar ----> PROPN ::::: Nar
# : ----> PUNCT ::::: :
# No ----> DET ::::: no
# one ----> NOUN ::::: one
# knows ----> VERB ::::: know
# how ----> SCONJ ::::: how
# it ----> PRON ::::: it
# started ----> VERB ::::: start
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Nar ----> PROPN ::::: Nar
# : ----> PUNCT ::::: :
# Seven ----> NUM ::::: seven
# people ----> NOUN ::::: people
# died ----> VERB ::::: die
# , ----> PUNCT ::::: ,
# and ----> CCONJ ::::: and
# others ----> NOUN ::::: other
# went ----> VERB ::::: go
# missing ----> VERB ::::: miss
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Nar ----> PROPN ::::: Nar
# : ----> PUNCT ::::: :
# On ----> ADP ::::: on
# the ----> DET ::::: the
# list ----> NOUN ::::: list
# of ----> ADP ::::: of
# the ----> DET ::::: the
# deceased ----> ADJ ::::: deceased
# were ----> AUX ::::: be
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Nar ----> PROPN ::::: Nar
# : ----> PUNCT ::::: :
# the ----> DET ::::: the
# names ----> NOUN ::::: name
# of ----> ADP ::::: of
# the ----> DET ::::: the
# priestand ----> NOUN ::::: priestand
# the ----> DET ::::: the
# boy ----> NOUN ::::: boy
# he ----> PRON ::::: he
# 'd ----> AUX ::::: would
# taken ----> VERB ::::: take
# in ----> ADP ::::: in
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Sign ----> NOUN ::::: sign
# : ----> PUNCT ::::: :
# { ----> PUNCT ::::: {
# \fad(,)\fs\pos(,)}Olbia ----> NOUN ::::: \fad(,)\fs\pos(,)}olbia
# , ----> PUNCT ::::: ,
# Sardinia ----> PROPN ::::: Sardinia
# : ----> PUNCT ::::: :
# Present ----> PROPN ::::: Present
# Day ----> PROPN ::::: Day
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Boy ----> NOUN ::::: boy
# : ----> PUNCT ::::: :
# Why ----> SCONJ ::::: why
# , ----> PUNCT ::::: ,
# you ----> PRON ::::: you
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Doppio ----> PROPN ::::: Doppio
# : ----> PUNCT ::::: :
# Hey ----> INTJ ::::: hey
# , ----> PUNCT ::::: ,
# kid ----> NOUN ::::: kid
# ! ----> PUNCT ::::: !
# Look ----> VERB ::::: look
# out ----> ADP ::::: out
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Boy ----> NOUN ::::: boy
# : ----> PUNCT ::::: :
# Shut ----> VERB ::::: shut
# up ----> ADP ::::: up
# . ----> PUNCT ::::: .
# I ----> PRON ::::: I
# know ----> VERB ::::: know
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# JoJo ----> PROPN ::::: JoJo
# - ----> PUNCT ::::: -
# main ----> ADJ ::::: main
# : ----> PUNCT ::::: :
# , ----> PUNCT ::::: ,
# There ----> PRON ::::: there
# 's ----> VERB ::::: be
# a ----> DET ::::: a
# truck ----> NOUN ::::: truck
# coming ----> VERB ::::: come
# , ----> PUNCT ::::: ,
# right ----> ADJ ::::: right
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Driver ----> PROPN ::::: Driver
# : ----> PUNCT ::::: :
# You ----> PRON ::::: you
# b*stard ----> PROPN ::::: b*stard
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# JoJo ----> PROPN ::::: JoJo
# - ----> PUNCT ::::: -
# main ----> ADJ ::::: main
# : ----> PUNCT ::::: :
# , ----> PUNCT ::::: ,
# Where ----> SCONJ ::::: where
# the ----> DET ::::: the
# hell ----> NOUN ::::: hell
# do ----> AUX ::::: do
# you ----> PRON ::::: you
# think ----> VERB ::::: think
# you ----> PRON ::::: you
# 're ----> AUX ::::: be
# walking ----> VERB ::::: walk
# , ----> PUNCT ::::: ,
# you ----> PRON ::::: you
# dumbass ----> ADJ ::::: dumbass
# ? ----> PUNCT ::::: ?
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Doppio ----> PROPN ::::: Doppio
# : ----> PUNCT ::::: :
# O ----> X ::::: o
# - ----> PUNCT ::::: -
# Ow ----> VERB ::::: ow
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Doppio ----> PROPN ::::: Doppio
# : ----> PUNCT ::::: :
# Aw ----> INTJ ::::: aw
# , ----> PUNCT ::::: ,
# man ----> NOUN ::::: man
# ... ----> PUNCT ::::: ...
# Ow ----> INTJ ::::: ow
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Doppio ----> PROPN ::::: Doppio
# : ----> PUNCT ::::: :
# Guess ----> INTJ ::::: guess
# I ----> PRON ::::: I
# had ----> VERB ::::: have
# the ----> DET ::::: the
# wrong ----> ADJ ::::: wrong
# idea ----> NOUN ::::: idea
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Guy ----> PROPN ::::: Guy
# : ----> PUNCT ::::: :
# Looks ----> VERB ::::: look
# like ----> SCONJ ::::: like
# you ----> PRON ::::: you
# 're ----> AUX ::::: be
# down ----> ADV ::::: down
# on ----> ADP ::::: on
# your ----> PRON ::::: your
# luck ----> NOUN ::::: luck
# . ----> PUNCT ::::: .
# Having ----> VERB ::::: have
# a ----> DET ::::: a
# bad ----> ADJ ::::: bad
# day ----> NOUN ::::: day
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Guy ----> PROPN ::::: Guy
# : ----> PUNCT ::::: :
# Or ----> CCONJ ::::: or
# have ----> AUX ::::: have
# you ----> PRON ::::: you
# been ----> AUX ::::: be
# having ----> VERB ::::: have
# a ----> DET ::::: a
# streak ----> NOUN ::::: streak
# of ----> ADP ::::: of
# bad ----> ADJ ::::: bad
# luck ----> NOUN ::::: luck
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Doppio ----> PROPN ::::: Doppio
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# 'd ----> AUX ::::: would
# say ----> VERB ::::: say
# so ----> ADV ::::: so
# . ----> PUNCT ::::: .
# I ----> PRON ::::: I
# 've ----> AUX ::::: have
# had ----> VERB ::::: have
# one ----> NUM ::::: one
# problem ----> NOUN ::::: problem
# after ----> ADP ::::: after
# another ----> PRON ::::: another
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Guy ----> PROPN ::::: Guy
# : ----> PUNCT ::::: :
# Why ----> SCONJ ::::: why
# not ----> PART ::::: not
# let ----> VERB ::::: let
# me ----> PRON ::::: I
# tell ----> VERB ::::: tell
# your ----> PRON ::::: your
# fortune ----> NOUN ::::: fortune
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Guy ----> PROPN ::::: Guy
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# 'll ----> AUX ::::: will
# make ----> VERB ::::: make
# it ----> PRON ::::: it
# cheap ----> ADJ ::::: cheap
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Doppio ----> PROPN ::::: Doppio
# : ----> PUNCT ::::: :
# Huh ----> INTJ ::::: huh
# ? ----> PUNCT ::::: ?
# Nah ----> INTJ ::::: nah
# , ----> PUNCT ::::: ,
# I ----> PRON ::::: I
# 'll ----> AUX ::::: will
# pass ----> VERB ::::: pass
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Guy ----> PROPN ::::: Guy
# : ----> PUNCT ::::: :
# Sardinia ----> PROPN ::::: Sardinia
# is ----> AUX ::::: be
# your ----> PRON ::::: your
# home ----> NOUN ::::: home
# , ----> PUNCT ::::: ,
# is ----> AUX ::::: be
# n't ----> PART ::::: not
# it ----> PRON ::::: it
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Guy ----> PROPN ::::: Guy
# : ----> PUNCT ::::: :
# And ----> CCONJ ::::: and
# it ----> PRON ::::: it
# 's ----> AUX ::::: be
# been ----> AUX ::::: be
# a ----> DET ::::: a
# while ----> NOUN ::::: while
# since ----> SCONJ ::::: since
# you ----> PRON ::::: you
# 've ----> AUX ::::: have
# been ----> AUX ::::: be
# back ----> ADV ::::: back
# here ----> ADV ::::: here
# , ----> PUNCT ::::: ,
# has ----> VERB ::::: have
# n't ----> PART ::::: not
# it ----> PRON ::::: it
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Doppio ----> PROPN ::::: Doppio
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# would ----> AUX ::::: would
# n't ----> PART ::::: not
# call ----> VERB ::::: call
# that ----> DET ::::: that
# fortunetelling ----> NOUN ::::: fortunetelling
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Doppio ----> PROPN ::::: Doppio
# : ----> PUNCT ::::: :
# You ----> PRON ::::: you
# can ----> AUX ::::: can
# tell ----> VERB ::::: tell
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# a ----> DET ::::: a
# traveler ----> NOUN ::::: traveler
# just ----> ADV ::::: just
# by ----> ADP ::::: by
# looking ----> VERB ::::: look
# at ----> ADP ::::: at
# me ----> PRON ::::: I
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# JoJo ----> PROPN ::::: JoJo
# - ----> PUNCT ::::: -
# main ----> NOUN ::::: main
# : ----> PUNCT ::::: :
# , ----> PUNCT ::::: ,
# Anyone ----> PRON ::::: anyone
# could ----> AUX ::::: could
# figure ----> VERB ::::: figure
# that ----> PRON ::::: that
# out ----> ADP ::::: out
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Guy ----> PROPN ::::: Guy
# : ----> PUNCT ::::: :
# You ----> PRON ::::: you
# 're ----> AUX ::::: be
# ... ----> PUNCT ::::: ...
# living ----> VERB ::::: live
# with ----> ADP ::::: with
# a ----> DET ::::: a
# secret ----> NOUN ::::: secret
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# JoJo ----> PROPN ::::: JoJo
# - ----> PUNCT ::::: -
# main ----> ADJ ::::: main
# : ----> PUNCT ::::: :
# , ----> PUNCT ::::: ,
# Light ----> NOUN ::::: light
# and ----> CCONJ ::::: and
# shadow ----> NOUN ::::: shadow
# , ----> PUNCT ::::: ,
# what ----> PRON ::::: what
# 's ----> AUX ::::: be
# inside ----> ADJ ::::: inside
# and ----> CCONJ ::::: and
# what ----> PRON ::::: what
# 's ----> AUX ::::: be
# out ----> ADP ::::: out
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Guy ----> PROPN ::::: Guy
# : ----> PUNCT ::::: :
# You ----> PRON ::::: you
# could ----> AUX ::::: could
# probably ----> ADV ::::: probably
# call ----> VERB ::::: call
# it ----> PRON ::::: it
# two ----> NUM ::::: two
# separate ----> ADJ ::::: separate
# lives ----> NOUN ::::: life
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Guy ----> PROPN ::::: Guy
# : ----> PUNCT ::::: :
# But ----> CCONJ ::::: but
# you ----> PRON ::::: you
# take ----> VERB ::::: take
# advantage ----> NOUN ::::: advantage
# of ----> ADP ::::: of
# that ----> DET ::::: that
# secret ----> NOUN ::::: secret
# and ----> CCONJ ::::: and
# have ----> VERB ::::: have
# an ----> DET ::::: an
# unyielding ----> ADJ ::::: unyielding
# personality ----> NOUN ::::: personality
# , ----> PUNCT ::::: ,
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# JoJo ----> PROPN ::::: JoJo
# - ----> PUNCT ::::: -
# main ----> ADJ ::::: main
# : ----> PUNCT ::::: :
# , ----> PUNCT ::::: ,
# which ----> PRON ::::: which
# has ----> AUX ::::: have
# earned ----> VERB ::::: earn
# you ----> PRON ::::: you
# nothing ----> PRON ::::: nothing
# but ----> SCONJ ::::: but
# victories ----> NOUN ::::: victory
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Doppio ----> PROPN ::::: Doppio
# : ----> PUNCT ::::: :
# What ----> PRON ::::: what
# ? ----> SYM ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Guy ----> PROPN ::::: Guy
# : ----> PUNCT ::::: :
# Oh ----> INTJ ::::: oh
# , ----> PUNCT ::::: ,
# please ----> INTJ ::::: please
# forgive ----> VERB ::::: forgive
# my ----> PRON ::::: my
# rudeness ----> NOUN ::::: rudeness
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Guy ----> PROPN ::::: Guy
# : ----> PUNCT ::::: :
# There ----> PRON ::::: there
# 's ----> VERB ::::: be
# something ----> PRON ::::: something
# about ----> ADP ::::: about
# your ----> PRON ::::: your
# face ----> NOUN ::::: face
# that ----> PRON ::::: that
# is ----> AUX ::::: be
# very ----> ADV ::::: very
# intriguing ----> ADJ ::::: intriguing
# to ----> ADP ::::: to
# someone ----> PRON ::::: someone
# in ----> ADP ::::: in
# my ----> PRON ::::: my
# field ----> NOUN ::::: field
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Guy ----> PROPN ::::: Guy
# : ----> PUNCT ::::: :
# Please ----> INTJ ::::: please
# , ----> PUNCT ::::: ,
# let ----> VERB ::::: let
# me ----> PRON ::::: I
# tell ----> VERB ::::: tell
# you ----> PRON ::::: you
# your ----> PRON ::::: your
# fortune ----> NOUN ::::: fortune
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Guy ----> PROPN ::::: Guy
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# 'll ----> AUX ::::: will
# make ----> VERB ::::: make
# it ----> PRON ::::: it
# , ----> PUNCT ::::: ,
# ... ----> PUNCT ::::: ...
# no ----> INTJ ::::: no
# , ----> PUNCT ::::: ,
# , ----> PUNCT ::::: ,
# lire ----> NOUN ::::: lira
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Doppio ----> PROPN ::::: Doppio
# : ----> PUNCT ::::: :
# Everyone ----> PRON ::::: everyone
# has ----> VERB ::::: have
# their ----> PRON ::::: their
# secrets ----> NOUN ::::: secret
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# JoJo ----> PROPN ::::: JoJo
# - ----> PUNCT ::::: -
# main ----> ADJ ::::: main
# : ----> PUNCT ::::: :
# , ----> PUNCT ::::: ,
# That ----> PRON ::::: that
# 's ----> AUX ::::: be
# a ----> DET ::::: a
# pretty ----> ADV ::::: pretty
# broad ----> ADJ ::::: broad
# statement ----> NOUN ::::: statement
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Guy ----> PROPN ::::: Guy
# : ----> PUNCT ::::: :
# You ----> PRON ::::: you
# 're ----> AUX ::::: be
# looking ----> VERB ::::: look
# for ----> ADP ::::: for
# someone ----> PRON ::::: someone
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# JoJo ----> PROPN ::::: JoJo
# - ----> PUNCT ::::: -
# main ----> ADJ ::::: main
# : ----> PUNCT ::::: :
# , ----> PUNCT ::::: ,
# You ----> PRON ::::: you
# 're ----> AUX ::::: be
# currently ----> ADV ::::: currently
# looking ----> VERB ::::: look
# for ----> ADP ::::: for
# someone ----> PRON ::::: someone
# very ----> ADV ::::: very
# important ----> ADJ ::::: important
# to ----> ADP ::::: to
# you ----> PRON ::::: you
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Doppio ----> PROPN ::::: Doppio
# : ----> PUNCT ::::: :
# Seriously ----> ADV ::::: seriously
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Doppio ----> PROPN ::::: Doppio
# : ----> PUNCT ::::: :
# Everyone ----> PRON ::::: everyone
# spends ----> VERB ::::: spend
# their ----> PRON ::::: their
# lives ----> NOUN ::::: life
# looking ----> VERB ::::: look
# for ----> ADP ::::: for
# someone ----> PRON ::::: someone
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Doppio ----> PROPN ::::: Doppio
# : ----> PUNCT ::::: :
# A ----> DET ::::: a
# beautiful ----> ADJ ::::: beautiful
# girlfriend ----> NOUN ::::: girlfriend
# or ----> CCONJ ::::: or
# a ----> DET ::::: a
# good ----> ADJ ::::: good
# friend ----> NOUN ::::: friend
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Doppio ----> PROPN ::::: Doppio
# : ----> PUNCT ::::: :
# But ----> CCONJ ::::: but
# I ----> PRON ::::: I
# guess ----> VERB ::::: guess
# it ----> PRON ::::: it
# 's ----> AUX ::::: be
# nice ----> ADJ ::::: nice
# to ----> PART ::::: to
# hear ----> VERB ::::: hear
# these ----> DET ::::: these
# things ----> NOUN ::::: thing
# at ----> ADP ::::: at
# times ----> NOUN ::::: time
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# JoJo ----> PROPN ::::: JoJo
# - ----> PUNCT ::::: -
# main ----> ADJ ::::: main
# : ----> PUNCT ::::: :
# , ----> PUNCT ::::: ,
# How ----> SCONJ ::::: how
# do ----> AUX ::::: do
# you ----> PRON ::::: you
# go ----> VERB ::::: go
# about ----> ADP ::::: about
# doing ----> VERB ::::: do
# it ----> PRON ::::: it
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Doppio ----> PROPN ::::: Doppio
# : ----> PUNCT ::::: :
# With ----> ADP ::::: with
# that ----> DET ::::: that
# crystal ----> NOUN ::::: crystal
# ball ----> NOUN ::::: ball
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Guy ----> PROPN ::::: Guy
# : ----> PUNCT ::::: :
# No ----> INTJ ::::: no
# ... ----> PUNCT ::::: ...
# I ----> PRON ::::: I
# 've ----> AUX ::::: have
# already ----> ADV ::::: already
# begun ----> VERB ::::: begin
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Guy ----> PROPN ::::: Guy
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# can ----> AUX ::::: can
# tell ----> VERB ::::: tell
# just ----> ADV ::::: just
# by ----> ADP ::::: by
# looking ----> VERB ::::: look
# at ----> ADP ::::: at
# the ----> DET ::::: the
# shape ----> NOUN ::::: shape
# of ----> ADP ::::: of
# the ----> DET ::::: the
# mud ----> NOUN ::::: mud
# splatter ----> NOUN ::::: splatter
# on ----> ADP ::::: on
# your ----> PRON ::::: your
# pants ----> NOUN ::::: pant
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Guy ----> PROPN ::::: Guy
# : ----> PUNCT ::::: :
# It ----> PRON ::::: it
# 's ----> AUX ::::: be
# been ----> AUX ::::: be
# said ----> VERB ::::: say
# for ----> ADP ::::: for
# thousands ----> NOUN ::::: thousand
# of ----> ADP ::::: of
# years ----> NOUN ::::: year
# that ----> SCONJ ::::: that
# in ----> ADP ::::: in
# Romani ----> PROPN ::::: Romani
# fortunetelling ----> NOUN ::::: fortunetelling
# , ----> PUNCT ::::: ,
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# JoJo ----> PROPN ::::: JoJo
# - ----> PUNCT ::::: -
# main ----> ADJ ::::: main
# : ----> PUNCT ::::: :
# , ----> PUNCT ::::: ,
# the ----> DET ::::: the
# best ----> ADJ ::::: good
# results ----> NOUN ::::: result
# come ----> VERB ::::: come
# from ----> ADP ::::: from
# looking ----> VERB ::::: look
# at ----> ADP ::::: at
# the ----> DET ::::: the
# shape ----> NOUN ::::: shape
# of ----> ADP ::::: of
# something ----> PRON ::::: something
# that ----> PRON ::::: that
# formed ----> VERB ::::: form
# coincidentally ----> ADV ::::: coincidentally
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Guy ----> PROPN ::::: Guy
# : ----> PUNCT ::::: :
# Because ----> SCONJ ::::: because
# that ----> PRON ::::: that
# is ----> AUX ::::: be
# the ----> DET ::::: the
# symbol ----> NOUN ::::: symbol
# of ----> ADP ::::: of
# fate ----> NOUN ::::: fate
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Guy ----> PROPN ::::: Guy
# : ----> PUNCT ::::: :
# Your ----> PRON ::::: your
# daughter ----> NOUN ::::: daughter
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# JoJo ----> PROPN ::::: JoJo
# - ----> PUNCT ::::: -
# main ----> ADJ ::::: main
# : ----> PUNCT ::::: :
# , ----> PUNCT ::::: ,
# Yes ----> INTJ ::::: yes
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# JoJo ----> PROPN ::::: JoJo
# - ----> PUNCT ::::: -
# main ----> NOUN ::::: main
# : ----> PUNCT ::::: :
# , ----> PUNCT ::::: ,
# The ----> DET ::::: the
# person ----> NOUN ::::: person
# you ----> PRON ::::: you
# 're ----> AUX ::::: be
# looking ----> VERB ::::: look
# for ----> ADP ::::: for
# is ----> AUX ::::: be
# your ----> PRON ::::: your
# daughter ----> NOUN ::::: daughter
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Guy ----> PROPN ::::: Guy
# : ----> PUNCT ::::: :
# You ----> PRON ::::: you
# came ----> VERB ::::: come
# back ----> ADV ::::: back
# to ----> ADP ::::: to
# Sardinia ----> PROPN ::::: Sardinia
# to ----> PART ::::: to
# find ----> VERB ::::: find
# the ----> DET ::::: the
# child ----> NOUN ::::: child
# of ----> ADP ::::: of
# the ----> DET ::::: the
# woman ----> NOUN ::::: woman
# you ----> PRON ::::: you
# left ----> VERB ::::: leave
# fifteen ----> NUM ::::: fifteen
# years ----> NOUN ::::: year
# ago ----> ADV ::::: ago
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Doppio ----> PROPN ::::: Doppio
# : ----> PUNCT ::::: :
# Huh ----> PROPN ::::: Huh
# ? ----> PROPN ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Guy ----> PROPN ::::: Guy
# : ----> PUNCT ::::: :
# Huh ----> INTJ ::::: huh
# ? ----> PUNCT ::::: ?
# Er ----> INTJ ::::: er
# ... ----> PUNCT ::::: ...
# Something ----> PRON ::::: something
# 's ----> AUX ::::: be
# strange ----> ADJ ::::: strange
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# JoJo ----> PROPN ::::: JoJo
# - ----> PUNCT ::::: -
# main ----> ADJ ::::: main
# : ----> PUNCT ::::: :
# , ----> PUNCT ::::: ,
# You ----> PRON ::::: you
# 're ----> AUX ::::: be
# rather ----> ADV ::::: rather
# young ----> ADJ ::::: young
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Guy ----> PROPN ::::: Guy
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# know ----> VERB ::::: know
# what ----> PRON ::::: what
# I ----> PRON ::::: I
# just ----> ADV ::::: just
# said ----> VERB ::::: say
# , ----> PUNCT ::::: ,
# but ----> CCONJ ::::: but
# this ----> PRON ::::: this
# is ----> AUX ::::: be
# strange ----> ADJ ::::: strange
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Doppio ----> PROPN ::::: Doppio
# : ----> PUNCT ::::: :
# Whose ----> DET ::::: whose
# child ----> NOUN ::::: child
# ? ----> PUNCT ::::: ?
# Mine ----> NOUN ::::: mine
# ? ----> PROPN ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Guy ----> PROPN ::::: Guy
# : ----> PUNCT ::::: :
# But ----> CCONJ ::::: but
# you ----> PRON ::::: you
# have ----> VERB ::::: have
# one ----> NUM ::::: one
# . ----> PUNCT ::::: .
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# sure ----> ADJ ::::: sure
# of ----> ADP ::::: of
# it ----> PRON ::::: it
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Guy ----> PROPN ::::: Guy
# : ----> PUNCT ::::: :
# Let ----> VERB ::::: let
# me ----> PRON ::::: I
# see ----> VERB ::::: see
# your ----> PRON ::::: your
# palm ----> NOUN ::::: palm
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Doppio ----> PROPN ::::: Doppio
# : ----> PUNCT ::::: :
# Hey ----> INTJ ::::: hey
# ! ----> PROPN ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Guy ----> PROPN ::::: Guy
# : ----> PUNCT ::::: :
# Please ----> INTJ ::::: please
# ! ----> PUNCT ::::: !
# My ----> PRON ::::: my
# pride ----> NOUN ::::: pride
# as ----> ADP ::::: as
# a ----> DET ::::: a
# fortuneteller ----> NOUN ::::: fortuneteller
# is ----> AUX ::::: be
# on ----> ADP ::::: on
# the ----> DET ::::: the
# line ----> NOUN ::::: line
# here ----> ADV ::::: here
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Doppio ----> PROPN ::::: Doppio
# : ----> PUNCT ::::: :
# Let ----> VERB ::::: let
# go ----> VERB ::::: go
# of ----> ADP ::::: of
# my ----> PRON ::::: my
# hand ----> NOUN ::::: hand
# ... ----> PUNCT ::::: ...
# Do ----> AUX ::::: do
# n't ----> PART ::::: not
# touch ----> VERB ::::: touch
# me ----> PRON ::::: I
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Guy ----> PROPN ::::: Guy
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# wo ----> AUX ::::: will
# n't ----> PART ::::: not
# ask ----> VERB ::::: ask
# for ----> ADP ::::: for
# payment ----> NOUN ::::: payment
# ... ----> PUNCT ::::: ...
# Actually ----> ADV ::::: actually
# , ----> PUNCT ::::: ,
# I ----> PRON ::::: I
# 'll ----> AUX ::::: will
# pay ----> VERB ::::: pay
# you ----> PRON ::::: you
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Guy ----> PROPN ::::: Guy
# : ----> PUNCT ::::: :
# , ----> PUNCT ::::: ,
# ... ----> PUNCT ::::: ...
# No ----> INTJ ::::: no
# , ----> PUNCT ::::: ,
# I ----> PRON ::::: I
# 'll ----> AUX ::::: will
# pay ----> VERB ::::: pay
# you ----> PRON ::::: you
# , ----> PUNCT ::::: ,
# lire ----> NOUN ::::: lira
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Guy ----> PROPN ::::: Guy
# : ----> PUNCT ::::: :
# Please ----> INTJ ::::: please
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Doppio ----> PROPN ::::: Doppio
# : ----> PUNCT ::::: :
# You ----> PRON ::::: you
# 're ----> AUX ::::: be
# friggin ----> ADJ ::::: friggin
# ' ----> PUNCT ::::: '
# annoying ----> ADJ ::::: annoying
# ! ----> PUNCT ::::: !
# Do ----> AUX ::::: do
# n't ----> PART ::::: not
# touch ----> VERB ::::: touch
# me ----> PRON ::::: I
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Doppio ----> PROPN ::::: Doppio
# : ----> PUNCT ::::: :
# What ----> PRON ::::: what
# good ----> ADJ ::::: good
# would ----> AUX ::::: would
# it ----> PRON ::::: it
# do ----> VERB ::::: do
# for ----> SCONJ ::::: for
# you ----> PRON ::::: you
# to ----> PART ::::: to
# see ----> VERB ::::: see
# it ----> PRON ::::: it
# , ----> PUNCT ::::: ,
# huh ----> INTJ ::::: huh
# ? ----> PUNCT ::::: ?
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Diavolo ----> PROPN ::::: Diavolo
# : ----> PUNCT ::::: :
# Considering ----> VERB ::::: consider
# you ----> PRON ::::: you
# 're ----> AUX ::::: be
# about ----> ADJ ::::: about
# to ----> PART ::::: to
# die ----> VERB ::::: die
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Guy ----> PROPN ::::: Guy
# : ----> PUNCT ::::: :
# Your ----> PRON ::::: your
# face ----> NOUN ::::: face
# ... ----> PUNCT ::::: ...
# Your ----> PRON ::::: your
# age ----> NOUN ::::: age
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Diavolo ----> PROPN ::::: Diavolo
# : ----> PUNCT ::::: :
# It ----> PRON ::::: it
# appears ----> VERB ::::: appear
# you ----> PRON ::::: you
# 're ----> AUX ::::: be
# not ----> PART ::::: not
# a ----> DET ::::: a
# Stand ----> PROPN ::::: Stand
# user ----> NOUN ::::: user
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Diavolo ----> PROPN ::::: Diavolo
# : ----> PUNCT ::::: :
# You ----> PRON ::::: you
# have ----> VERB ::::: have
# the ----> DET ::::: the
# wisdom ----> NOUN ::::: wisdom
# to ----> PART ::::: to
# see ----> VERB ::::: see
# people ----> NOUN ::::: people
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# JoJo ----> PROPN ::::: JoJo
# - ----> PUNCT ::::: -
# main ----> ADJ ::::: main
# : ----> PUNCT ::::: :
# , ----> PUNCT ::::: ,
# for ----> ADP ::::: for
# who ----> PRON ::::: who
# they ----> PRON ::::: they
# really ----> ADV ::::: really
# are ----> AUX ::::: be
# , ----> PUNCT ::::: ,
# and ----> CCONJ ::::: and
# you ----> PRON ::::: you
# made ----> VERB ::::: make
# that ----> SCONJ ::::: that
# your ----> PRON ::::: your
# business ----> NOUN ::::: business
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Diavolo ----> PROPN ::::: Diavolo
# : ----> PUNCT ::::: :
# That ----> PRON ::::: that
# was ----> AUX ::::: be
# your ----> PRON ::::: your
# greatest ----> ADJ ::::: great
# failing ----> VERB ::::: fail
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Diavolo ----> PROPN ::::: Diavolo
# : ----> PUNCT ::::: :
# No ----> DET ::::: no
# one ----> NOUN ::::: one
# in ----> ADP ::::: in
# this ----> DET ::::: this
# world ----> NOUN ::::: world
# is ----> AUX ::::: be
# allowed ----> VERB ::::: allow
# to ----> PART ::::: to
# know ----> VERB ::::: know
# who ----> PRON ::::: who
# I ----> PRON ::::: I
# really ----> ADV ::::: really
# am ----> AUX ::::: be
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Diavolo ----> PROPN ::::: Diavolo
# : ----> PUNCT ::::: :
# But ----> CCONJ ::::: but
# I ----> PRON ::::: I
# now ----> ADV ::::: now
# know ----> VERB ::::: know
# that ----> SCONJ ::::: that
# you ----> PRON ::::: you
# are ----> AUX ::::: be
# indeed ----> ADV ::::: indeed
# an ----> DET ::::: an
# excellent ----> ADJ ::::: excellent
# fortuneteller ----> NOUN ::::: fortuneteller
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Diavolo ----> PROPN ::::: Diavolo
# : ----> PUNCT ::::: :
# Out ----> ADP ::::: out
# of ----> ADP ::::: of
# respect ----> NOUN ::::: respect
# for ----> ADP ::::: for
# that ----> PRON ::::: that
# , ----> PUNCT ::::: ,
# I ----> PRON ::::: I
# 'll ----> AUX ::::: will
# be ----> AUX ::::: be
# sure ----> ADJ ::::: sure
# to ----> PART ::::: to
# k*ll ----> VERB ::::: k*ll
# you ----> PRON ::::: you
# instantly ----> ADV ::::: instantly
# so ----> SCONJ ::::: so
# you ----> PRON ::::: you
# do ----> AUX ::::: do
# n't ----> PART ::::: not
# feel ----> VERB ::::: feel
# any ----> DET ::::: any
# pain ----> NOUN ::::: pain
# . ----> PUNCT ::::: .
#
#
#
#
# ...
# : ----> PUNCT ::::: :
# What ----> PRON ::::: what
# am ----> AUX ::::: be
# I ----> PRON ::::: I
# seeing ----> VERB ::::: see
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Dia ----> PROPN ::::: Dia
# : ----> PUNCT ::::: :
# A ----> PROPN ::::: A
# - ----> PUNCT ::::: -
# Am ----> AUX ::::: am
# I ----> PRON ::::: I
# dreaming ----> VERB ::::: dream
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Dia ----> PROPN ::::: Dia
# : ----> PUNCT ::::: :
# Am ----> AUX ::::: be
# I ----> PRON ::::: I
# witnessing ----> VERB ::::: witness
# some ----> DET ::::: some
# kind ----> NOUN ::::: kind
# of ----> ADP ::::: of
# illusion ----> NOUN ::::: illusion
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Dia ----> PROPN ::::: Dia
# : ----> PUNCT ::::: :
# No ----> INTJ ::::: no
# ... ----> PUNCT ::::: ...
# that ----> PRON ::::: that
# ca ----> AUX ::::: can
# n't ----> PART ::::: not
# be ----> AUX ::::: be
# true ----> ADJ ::::: true
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Dia ----> PROPN ::::: Dia
# : ----> PUNCT ::::: :
# The ----> DET ::::: the
# only ----> ADJ ::::: only
# one ----> NOUN ::::: one
# who ----> PRON ::::: who
# can ----> AUX ::::: can
# move ----> VERB ::::: move
# within ----> ADP ::::: within
# the ----> DET ::::: the
# time ----> NOUN ::::: time
# I ----> PRON ::::: I
# 've ----> AUX ::::: have
# disposed ----> VERB ::::: dispose
# of ----> ADP ::::: of
# is ----> AUX ::::: be
# me ----> PRON ::::: I
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# GW ----> PROPN ::::: GW
# : ----> PUNCT ::::: :
# This ----> PRON ::::: this
# is ----> AUX ::::: be
# ... ----> PUNCT ::::: ...
# Requiem ----> PROPN ::::: Requiem
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Gw ----> PROPN ::::: Gw
# : ----> PUNCT ::::: :
# What ----> PRON ::::: what
# you ----> PRON ::::: you
# 're ----> AUX ::::: be
# seeing ----> VERB ::::: see
# is ----> AUX ::::: be
# indeed ----> ADV ::::: indeed
# the ----> DET ::::: the
# truth ----> NOUN ::::: truth
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Gw ----> PROPN ::::: Gw
# : ----> PUNCT ::::: :
# You ----> PRON ::::: you
# are ----> AUX ::::: be
# seeing ----> VERB ::::: see
# the ----> DET ::::: the
# movements ----> NOUN ::::: movement
# created ----> VERB ::::: create
# by ----> ADP ::::: by
# your ----> PRON ::::: your
# abilities ----> NOUN ::::: ability
# , ----> PUNCT ::::: ,
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Gw ----> PROPN ::::: Gw
# : ----> PUNCT ::::: :
# but ----> CCONJ ::::: but
# you ----> PRON ::::: you
# will ----> AUX ::::: will
# never ----> ADV ::::: never
# arrive ----> VERB ::::: arrive
# at ----> ADP ::::: at
# the ----> DET ::::: the
# truth ----> NOUN ::::: truth
# that ----> PRON ::::: that
# 's ----> AUX ::::: be
# going ----> VERB ::::: go
# to ----> PART ::::: to
# happen ----> VERB ::::: happen
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Gw ----> PROPN ::::: Gw
# : ----> PUNCT ::::: :
# None ----> NOUN ::::: none
# who ----> PRON ::::: who
# stand ----> VERB ::::: stand
# before ----> ADP ::::: before
# me ----> PRON ::::: I
# shall ----> AUX ::::: shall
# ever ----> ADV ::::: ever
# get ----> VERB ::::: get
# there ----> ADV ::::: there
# , ----> PUNCT ::::: ,
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Gw ----> NOUN ::::: gw
# : ----> PUNCT ::::: :
# regardless ----> ADV ::::: regardless
# of ----> ADP ::::: of
# their ----> PRON ::::: their
# abilities ----> NOUN ::::: ability
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Gw ----> PROPN ::::: Gw
# : ----> PUNCT ::::: :
# This ----> PRON ::::: this
# is ----> AUX ::::: be
# the ----> DET ::::: the
# power ----> NOUN ::::: power
# of ----> ADP ::::: of
# Golden ----> PROPN ::::: Golden
# Wind ----> PROPN ::::: Wind
# Requiem ----> PROPN ::::: Requiem
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Gw ----> PROPN ::::: Gw
# : ----> PUNCT ::::: :
# This ----> PRON ::::: this
# is ----> AUX ::::: be
# unknown ----> ADJ ::::: unknown
# even ----> ADV ::::: even
# to ----> ADP ::::: to
# Giorno ----> PROPN ::::: Giorno
# Giovanna ----> PROPN ::::: Giovanna
# , ----> PUNCT ::::: ,
# who ----> PRON ::::: who
# controls ----> VERB ::::: control
# me ----> PRON ::::: I
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Dia ----> PROPN ::::: Dia
# : ----> PUNCT ::::: :
# Giorno ----> PROPN ::::: Giorno
# Giovanna ----> PROPN ::::: Giovanna
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Dia ----> PROPN ::::: Dia
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# wo ----> AUX ::::: will
# n't ----> PART ::::: not
# even ----> ADV ::::: even
# give ----> VERB ::::: give
# you ----> PRON ::::: you
# the ----> DET ::::: the
# chance ----> NOUN ::::: chance
# to ----> PART ::::: to
# regret ----> VERB ::::: regret
# your ----> PRON ::::: your
# death ----> NOUN ::::: death
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Dia ----> PROPN ::::: Dia
# : ----> PUNCT ::::: :
# What ----> PRON ::::: what
# am ----> AUX ::::: be
# I ----> PRON ::::: I
# saying ----> VERB ::::: say
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Dia ----> PROPN ::::: Dia
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# - ----> PUNCT ::::: -
# I ----> NOUN ::::: i
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Dia ----> PROPN ::::: Dia
# : ----> PUNCT ::::: :
# have ----> AUX ::::: have
# n't ----> PART ::::: not
# moved ----> VERB ::::: move
# at ----> ADV ::::: at
# all ----> ADV ::::: all
# from ----> ADP ::::: from
# the ----> DET ::::: the
# start ----> NOUN ::::: start
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Dia ----> PROPN ::::: Dia
# : ----> PUNCT ::::: :
# Th ----> PROPN ::::: Th
# - ----> PUNCT ::::: -
# This ----> DET ::::: this
# premonition ----> NOUN ::::: premonition
# that ----> PRON ::::: that
# I ----> PRON ::::: I
# had ----> VERB ::::: have
# ... ----> PUNCT ::::: ...
# It ----> PRON ::::: it
# 's ----> AUX ::::: be
# the ----> DET ::::: the
# truth ----> NOUN ::::: truth
# that ----> PRON ::::: that
# 's ----> AUX ::::: be
# going ----> VERB ::::: go
# to ----> PART ::::: to
# happen ----> VERB ::::: happen
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Dia ----> PROPN ::::: Dia
# : ----> PUNCT ::::: :
# My ----> PRON ::::: my
# invincible ----> ADJ ::::: invincible
# Emperor ----> PROPN ::::: Emperor
# Crimson ----> PROPN ::::: Crimson
# should ----> AUX ::::: should
# be ----> AUX ::::: be
# heading ----> VERB ::::: head
# toward ----> ADP ::::: toward
# victory ----> NOUN ::::: victory
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Gw ----> NOUN ::::: gw
# : ----> PUNCT ::::: :
# Useless ----> ADJ ::::: useless
# ! ----> PUNCT ::::: !
# Useless ----> ADJ ::::: useless
# ! ----> PUNCT ::::: !
# Useless ----> ADJ ::::: useless
# ! ----> PUNCT ::::: !
# Useless ----> ADJ ::::: useless
# ! ----> PUNCT ::::: !
# Useless ----> ADJ ::::: useless
# ! ----> PUNCT ::::: !
# Useless ----> ADJ ::::: useless
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Gw ----> NOUN ::::: gw
# : ----> PUNCT ::::: :
# Useless ----> ADJ ::::: useless
# ! ----> PUNCT ::::: !
# Useless ----> ADJ ::::: useless
# ! ----> PUNCT ::::: !
# Useless ----> ADJ ::::: useless
# ! ----> PUNCT ::::: !
# Useless ----> ADJ ::::: useless
# ! ----> PUNCT ::::: !
# Useless ----> ADJ ::::: useless
# ! ----> PUNCT ::::: !
# Useless ----> ADJ ::::: useless
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Gw ----> NOUN ::::: gw
# : ----> PUNCT ::::: :
# Useless ----> ADJ ::::: useless
# ! ----> PUNCT ::::: !
# Useless ----> ADJ ::::: useless
# ! ----> PUNCT ::::: !
# Useless ----> ADJ ::::: useless
# ! ----> PUNCT ::::: !
# Useless ----> ADJ ::::: useless
# ! ----> PUNCT ::::: !
# Useless ----> ADJ ::::: useless
# ! ----> PUNCT ::::: !
# Useless ----> ADJ ::::: useless
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Gw ----> NOUN ::::: gw
# : ----> PUNCT ::::: :
# Useless ----> ADJ ::::: useless
# ! ----> PUNCT ::::: !
# Useless ----> ADJ ::::: useless
# ! ----> PUNCT ::::: !
# Useless ----> ADJ ::::: useless
# ! ----> PUNCT ::::: !
# Useless ----> ADJ ::::: useless
# ! ----> PUNCT ::::: !
# Useless ----> ADJ ::::: useless
# ! ----> PUNCT ::::: !
# Useless ----> ADJ ::::: useless
# ! ----> PUNCT ::::: !
# 04x07_-_Sex_Pistols_Appears__Part_1_-_Six_b_ll_ts_Appears__Part_1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 9
#       5         name, extension = os.path.splitext(file)
#       6         print(name)
#       7         with open(filepath, 'r', encoding='utf8') as f:
#       8             readFile = f.read()
# ----> 9             spacyRead = nlp(readFile)
#      10             for token in spacyRead:
#      11                 print(token.text, "---->", token.pos_, ":::::", token.lemma_)
#
# File ~/github/digit-210/python-nlp/.venv/lib/python3.12/site-packages/spacy/language.py:1053, in Language.__call__(self, text, disable, component_cfg)
#    1051     error_handler = proc.get_error_handler()
#    1052 try:
# -> 1053     doc = proc(doc, **component_cfg.get(name, {}))  # type: ignore[call-arg]
#    1054 except KeyError as e:
#    1055     # This typically happens if a component is not initialized
#    1056     raise ValueError(Errors.E109.format(name=name)) from e
#
#     [... skipping similar frames: Model.__call__ at line 310 (1 times)]
#
# File spacy/pipeline/trainable_pipe.pyx:52, in spacy.pipeline.trainable_pipe.TrainablePipe.__call__()
# ---> 52 'Could not get source, probably due dynamically evaluated source code.'
#
# File spacy/pipeline/transition_parser.pyx:264, in spacy.pipeline.transition_parser.Parser.predict()
# --> 264 'Could not get source, probably due dynamically evaluated source code.'
#
# File spacy/pipeline/transition_parser.pyx:285, in spacy.pipeline.transition_parser.Parser.greedy_parse()
# --> 285 'Could not get source, probably due dynamically evaluated source code.'
#
# File ~/github/digit-210/python-nlp/.venv/lib/python3.12/site-packages/thinc/model.py:334, in Model.predict(self, X)
#     330 def predict(self, X: InT) -> OutT:
#     331     """Call the model's `forward` function with `is_train=False`, and return
#     332     only the output, instead of the `(output, callback)` tuple.
#     333     """
# --> 334     return self._func(self, X, is_train=False)[0]
#
# File ~/github/digit-210/python-nlp/.venv/lib/python3.12/site-packages/spacy/ml/tb_framework.py:32, in forward(model, X, is_train)
#      31 def forward(model, X, is_train):
# ---> 32     step_model = ParserStepModel(
#      33         X,
#      34         model.layers,
#      35         unseen_classes=model.attrs["unseen_classes"],
#      36         train=is_train,
#      37         has_upper=model.attrs["has_upper"],
#      38     )
#      40     return step_model, step_model.finish_steps
#
#     [... skipping similar frames: Model.__call__ at line 310 (1 times)]
#
# File spacy/ml/parser_model.pyx:250, in spacy.ml.parser_model.ParserStepModel.__init__()
# --> 250 'Could not get source, probably due dynamically evaluated source code.'
#
# File ~/github/digit-210/python-nlp/.venv/lib/python3.12/site-packages/thinc/model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File ~/github/digit-210/python-nlp/.venv/lib/python3.12/site-packages/thinc/layers/chain.py:55, in forward(model, X, is_train)
#      53 callbacks = []
#      54 for layer in model.layers:
# ---> 55     Y, inc_layer_grad = layer(X, is_train=is_train)
#      56     callbacks.append(inc_layer_grad)
#      57     X = Y
#
# File ~/github/digit-210/python-nlp/.venv/lib/python3.12/site-packages/thinc/model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File ~/github/digit-210/python-nlp/.venv/lib/python3.12/site-packages/thinc/layers/chain.py:55, in forward(model, X, is_train)
#      53 callbacks = []
#      54 for layer in model.layers:
# ---> 55     Y, inc_layer_grad = layer(X, is_train=is_train)
#      56     callbacks.append(inc_layer_grad)
#      57     X = Y
#
#     [... skipping similar frames: Model.__call__ at line 310 (1 times)]
#
# File ~/github/digit-210/python-nlp/.venv/lib/python3.12/site-packages/thinc/layers/chain.py:55, in forward(model, X, is_train)
#      53 callbacks = []
#      54 for layer in model.layers:
# ---> 55     Y, inc_layer_grad = layer(X, is_train=is_train)
#      56     callbacks.append(inc_layer_grad)
#      57     X = Y
#
# File ~/github/digit-210/python-nlp/.venv/lib/python3.12/site-packages/thinc/model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File ~/github/digit-210/python-nlp/.venv/lib/python3.12/site-packages/thinc/layers/with_array.py:36, in forward(model, Xseq, is_train)
#      32 def forward(
#      33     model: Model[SeqT, SeqT], Xseq: SeqT, is_train: bool
#      34 ) -> Tuple[SeqT, Callable]:
#      35     if isinstance(Xseq, Ragged):
# ---> 36         return cast(Tuple[SeqT, Callable], _ragged_forward(model, Xseq, is_train))
#      37     elif isinstance(Xseq, Padded):
#      38         return cast(Tuple[SeqT, Callable], _padded_forward(model, Xseq, is_train))
#
# File ~/github/digit-210/python-nlp/.venv/lib/python3.12/site-packages/thinc/layers/with_array.py:91, in _ragged_forward(model, Xr, is_train)
#      87 def _ragged_forward(
#      88     model: Model[SeqT, SeqT], Xr: Ragged, is_train: bool
#      89 ) -> Tuple[Ragged, Callable]:
#      90     layer: Model[ArrayXd, ArrayXd] = model.layers[0]
# ---> 91     Y, get_dX = layer(Xr.dataXd, is_train)
#      93     def backprop(dYr: Ragged) -> Ragged:
#      94         return Ragged(get_dX(dYr.dataXd), dYr.lengths)
#
# File ~/github/digit-210/python-nlp/.venv/lib/python3.12/site-packages/thinc/model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File ~/github/digit-210/python-nlp/.venv/lib/python3.12/site-packages/thinc/layers/chain.py:55, in forward(model, X, is_train)
#      53 callbacks = []
#      54 for layer in model.layers:
# ---> 55     Y, inc_layer_grad = layer(X, is_train=is_train)
#      56     callbacks.append(inc_layer_grad)
#      57     X = Y
#
# File ~/github/digit-210/python-nlp/.venv/lib/python3.12/site-packages/thinc/model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File ~/github/digit-210/python-nlp/.venv/lib/python3.12/site-packages/thinc/layers/chain.py:55, in forward(model, X, is_train)
#      53 callbacks = []
#      54 for layer in model.layers:
# ---> 55     Y, inc_layer_grad = layer(X, is_train=is_train)
#      56     callbacks.append(inc_layer_grad)
#      57     X = Y
#
# File ~/github/digit-210/python-nlp/.venv/lib/python3.12/site-packages/thinc/model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File ~/github/digit-210/python-nlp/.venv/lib/python3.12/site-packages/thinc/layers/maxout.py:52, in forward(model, X, is_train)
#      50 W = model.get_param("W")
#      51 W = model.ops.reshape2f(W, nO * nP, nI)
# ---> 52 Y = model.ops.gemm(X, W, trans2=True)
#      53 Y += model.ops.reshape1f(b, nO * nP)
#      54 Z = model.ops.reshape3f(Y, Y.shape[0], nO, nP)
#
# KeyboardInterrupt:

# %%
# Remember, we can request an explanation from spaCy of its tags: 
spacy.explain("ADJ")
# Out:
# 'adjective'

# %% [markdown]
# ### Okay, let's select something interesting
#  ...and maybe only collect the lemmas.
#
# Let's do this with a **function** call. We can easily switch the kind of word we want to output this way.
# Here we are starting to associate words wtih volumes...we're going to refine that by making a dataframe next.

# %%
def wordCollector(words, unit):
    wordList = []
    for token in words:
        if token.pos_ == "ADJ":
            wordList.append((token.lemma_, unit))
    uniqueLems = set(wordList)
    return uniqueLems

for file in os.listdir(collPath):
    if file.endswith(".txt"):
        filepath = f"{collPath}/{file}"
        name, extension = os.path.splitext(file)
        with open(filepath, 'r', encoding='utf8') as f:
            readFile = f.read()
            spacyRead = nlp(readFile)
            myWords = wordCollector(spacyRead, name)
            print(myWords)
# Out:
# {('important', '04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_'), ('intriguing', '04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_'), ('sorry', '04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_'), ('single', '04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_'), ('good', '04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_'), ('small', '04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_'), ('right', '04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_'), ('alive', '04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_'), ('broad', '04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_'), ('dark', '04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_'), ('nice', '04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_'), ('slow', '04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_'), ('true', '04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_'), ('beautiful', '04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_'), ('careful', '04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_'), ('whole', '04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_'), ('many', '04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_'), ('close', '04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_'), ('separate', '04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_'), ('extra', '04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_'), ('deceased', '04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_'), ('strange', '04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_'), ('much', '04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_'), ('unguarded', '04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_'), ('bad', '04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_'), ('dead', '04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_'), ('main', '04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_'), ('actual', '04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_'), ('believable', '04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_'), ('excellent', '04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_'), ('satisfied', '04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_'), ('sure', '04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_'), ('fine', '04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_'), ('about', '04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_'), ('inside', '04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_'), ('interested', '04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_'), ('impossible', '04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_'), ('ranged', '04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_'), ('serious', '04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_'), ('suspicious', '04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_'), ('great', '04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_'), ('strong', '04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_'), ('sparkling', '04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_'), ('friggin', '04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_'), ('different', '04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_'), ('wrong', '04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_'), ('murderous', '04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_'), ('unyielding', '04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_'), ('own', '04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_'), ('cowardly', '04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_'), ('internal', '04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_'), ('next', '04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_'), ('left', '04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_'), ('simple', '04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_'), ('dumbass', '04x26_-_A_Little_Story_From_The_Past__My_Name_Is_Doppio_'), ('big', '04x26_-_A_Li ...
# {('impossible', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('great', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('able', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('normal', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('malformed', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('irresponsible', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('wet', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('closed', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('gross', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('elastic', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('eternal', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('itchy', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('wrong', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('next', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('internal', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('own', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('mysterious', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('left', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('weird', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('big', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('few', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('little', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('firm', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('certain', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('unbelievable', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ("li'l", '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('first', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('refreshed', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('more', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('full', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('berserk', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('old', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('trivial', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('mere', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('important', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('clear', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('arduous', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('elite', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('okay', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('second', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('deep', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('hairy', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('small', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('right', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('single', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('other', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('good', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('insignificant', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('asleep', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('enough', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('surprised', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('true', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('slight', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('precise', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('strange', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('close', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('female', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('dead', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('much', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('bad', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('main', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('mista', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('fine', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('\\c&h&\\c&hfcc&}rumble', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('about', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('only', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('sure', '04x34_-_The_Requiem_Quietly_Plays__Part_1'), ('tight', '04x34_-_The_Requiem_Quietly_Plays__Part_1')}
# {('secret', '04x05_-_Find_Polpo_s_Fortune__-_Let_s_Find_Polpo_s_Fortune_'), ('mysterious', '04x05_-_Find_Polpo_s_Fortune__-_Let_s_Find_Polpo_s_Fortune_'), ('own', '04x05_-_Find_Polpo_s_Fortune__-_Let_s_Find_Polpo_s_Fortune_'), ('internal', '04x05_-_Find_Polpo_s_Fortune__-_Let_s_Find_Polpo_s_Fortune_'), ('particular', '04x05_-_Find_Polpo_s_Fortune__-_Let_s_Find_Polpo_s_Fortune_'), ('amazing', '04x05_-_Find_Polpo_s_Fortune__-_Let_s_Find_Polpo_s_Fortune_'), ('wrong', '04x05_-_Find_Polpo_s_Fortune__-_Let_s_Find_Polpo_s_Fortune_'), ('left', '04x05_-_Find_Polpo_s_Fortune__-_Let_s_Find_Polpo_s_Fortune_'), ('big', '04x05_-_Find_Polpo_s_Fortune__-_Let_s_Find_Polpo_s_Fortune_'), ('young', '04x05_-_Find_Polpo_s_Fortune__-_Let_s_Find_Polpo_s_Fortune_'), ('helpless', '04x05_-_Find_Polpo_s_Fortune__-_Let_s_Find_Polpo_s_Fortune_'), ('little', '04x05_-_Find_Polpo_s_Fortune__-_Let_s_Find_Polpo_s_Fortune_'), ('crazy', '04x05_-_Find_Polpo_s_Fortune__-_Let_s_Find_Polpo_s_Fortune_'), ('favorite', '04x05_-_Find_Polpo_s_Fortune__-_Let_s_Find_Polpo_s_Fortune_'), ('certain', '04x05_-_Find_Polpo_s_Fortune__-_Let_s_Find_Polpo_s_Fortune_'), ('worth', '04x05_-_Find_Polpo_s_Fortune__-_Let_s_Find_Polpo_s_Fortune_'), ('scared', '04x05_-_Find_Polpo_s_Fortune__-_Let_s_Find_Polpo_s_Fortune_'), ('hard', '04x05_-_Find_Polpo_s_Fortune__-_Let_s_Find_Polpo_s_Fortune_'), ('old', '04x05_-_Find_Polpo_s_Fortune__-_Let_s_Find_Polpo_s_Fortune_'), ('fatty', '04x05_-_Find_Polpo_s_Fortune__-_Let_s_Find_Polpo_s_Fortune_'), ('hot', '04x05_-_Find_Polpo_s_Fortune__-_Let_s_Find_Polpo_s_Fortune_'), ('correct', '04x05_-_Find_Polpo_s_Fortune__-_Let_s_Find_Polpo_s_Fortune_'), ('sorry', '04x05_-_Find_Polpo_s_Fortune__-_Let_s_Find_Polpo_s_Fortune_'), ('second', '04x05_-_Find_Polpo_s_Fortune__-_Let_s_Find_Polpo_s_Fortune_'), ('clear', '04x05_-_Find_Polpo_s_Fortune__-_Let_s_Find_Polpo_s_Fortune_'), ('safe', '04x05_-_Find_Polpo_s_Fortune__-_Let_s_Find_Polpo_s_Fortune_'), ('free', '04x05_-_Find_Polpo_s_Fortune__-_Let_s_Find_Polpo_s_Fortune_'), ('considerate', '04x05_-_Find_Polpo_s_Fortune__-_Let_s_Find_Polpo_s_Fortune_'), ('right', '04x05_-_Find_Polpo_s_Fortune__-_Let_s_Find_Polpo_s_Fortune_'), ('awesome', '04x05_-_Find_Polpo_s_Fortune__-_Let_s_Find_Polpo_s_Fortune_'), ('other', '04x05_-_Find_Polpo_s_Fortune__-_Let_s_Find_Polpo_s_Fortune_'), ('good', '04x05_-_Find_Polpo_s_Fortune__-_Let_s_Find_Polpo_s_Fortune_'), ('hilarious', '04x05_-_Find_Polpo_s_Fortune__-_Let_s_Find_Polpo_s_Fortune_'), ('sad', '04x05_-_Find_Polpo_s_Fortune__-_Let_s_Find_Polpo_s_Fortune_'), ('untrustworthy', '04x05_-_Find_Polpo_s_Fortune__-_Let_s_Find_Polpo_s_Fortune_'), ('such', '04x05_-_Find_Polpo_s_Fortune__-_Let_s_Find_Polpo_s_Fortune_'), ('anxious', '04x05_-_Find_Polpo_s_Fortune__-_Let_s_Find_Polpo_s_Fortune_'), ('alive', '04x05_-_Find_Polpo_s_Fortune__-_Let_s_Find_Polpo_s_Fortune_'), ('cautious', '04x05_-_Find_Polpo_s_Fortune__-_Let_s_Find_Polpo_s_Fortune_'), ('perfect', '04x05_-_Find_Polpo_s_Fortune__-_Let_s_Find_Polpo_s_Fortune_'), ('special', '04x05_-_Find_Polpo_s_Fortune__-_Let_s_Find_Polpo_s_Fortune_'), ('nice', '04x05_-_Find_Polpo_s_Fortune__-_Let_s_Find_Polpo_s_Fortune_'), ('new', '04x05_-_Find_Polpo_s_Fortune__-_Let_s_Find_Polpo_s_Fortune_'), ('stupid', '04x05_-_Find_Polpo_s_Fortune__-_Let_s_Find_Polpo_s_Fortune_'), ('respectful', '04x05_-_Find_Polpo_s_Fortune__-_Let_s_Find_Polpo_s_Fortune_'), ('impatient', '04x05_-_Find_Polpo_s_Fortune__-_Let_s_Find_Polpo_s_Fortune_'), ('rough', '04x05_-_Find_Polpo_s_Fortune__-_Let_s_Find_Polpo_s_Fortune_'), ('careful', '04x05_-_Find_Polpo_s_Fortune__-_Let_s_Find_Polpo_s_Fortune_'), ('freakin', '04x05_-_Find_Polpo_s_Fortune__-_Let_s_Find_Polpo_s_Fortune_'), ('many', '04x05_-_Find_Polpo_s_Fortune__-_Let_s_Find_Polpo_s_Fortune_'), ('close', '04x05_-_Find_Polpo_s_Fortune__-_Let_s_Find_Polpo_s_Fortune_'), ('much', '04x05_-_Find_Polpo_s_Fortune__-_Let_s_Find_Polpo_s_Fortune_'), ('depressed', '04x05_-_Find_Polpo_s_Fortune__-_Let_s_Find_Polpo_s_Fortune_'), ('believable', '04x05_ ...
# {('able', '04x35_-_The_Requiem_Quietly_Plays__Part_2'), ('dumb', '04x35_-_The_Requiem_Quietly_Plays__Part_2'), ('traumatic', '04x35_-_The_Requiem_Quietly_Plays__Part_2'), ('wrong', '04x35_-_The_Requiem_Quietly_Plays__Part_2'), ('coincidental', '04x35_-_The_Requiem_Quietly_Plays__Part_2'), ('own', '04x35_-_The_Requiem_Quietly_Plays__Part_2'), ('eternal', '04x35_-_The_Requiem_Quietly_Plays__Part_2'), ('dominant', '04x35_-_The_Requiem_Quietly_Plays__Part_2'), ('left', '04x35_-_The_Requiem_Quietly_Plays__Part_2'), ('\\shad\\fad(,)}jean', '04x35_-_The_Requiem_Quietly_Plays__Part_2'), ('few', '04x35_-_The_Requiem_Quietly_Plays__Part_2'), ('vital', '04x35_-_The_Requiem_Quietly_Plays__Part_2'), ('weak', '04x35_-_The_Requiem_Quietly_Plays__Part_2'), ('first', '04x35_-_The_Requiem_Quietly_Plays__Part_2'), ('black', '04x35_-_The_Requiem_Quietly_Plays__Part_2'), ('more', '04x35_-_The_Requiem_Quietly_Plays__Part_2'), ('bizarre', '04x35_-_The_Requiem_Quietly_Plays__Part_2'), ('defensive', '04x35_-_The_Requiem_Quietly_Plays__Part_2'), ('empty', '04x35_-_The_Requiem_Quietly_Plays__Part_2'), ('old', '04x35_-_The_Requiem_Quietly_Plays__Part_2'), ("li'l", '04x35_-_The_Requiem_Quietly_Plays__Part_2'), ('multiple', '04x35_-_The_Requiem_Quietly_Plays__Part_2'), ('hot', '04x35_-_The_Requiem_Quietly_Plays__Part_2'), ('physical', '04x35_-_The_Requiem_Quietly_Plays__Part_2'), ('authentic', '04x35_-_The_Requiem_Quietly_Plays__Part_2'), ('berserk', '04x35_-_The_Requiem_Quietly_Plays__Part_2'), ('glad', '04x35_-_The_Requiem_Quietly_Plays__Part_2'), ('dear', '04x35_-_The_Requiem_Quietly_Plays__Part_2'), ('safe', '04x35_-_The_Requiem_Quietly_Plays__Part_2'), ('correct', '04x35_-_The_Requiem_Quietly_Plays__Part_2'), ('okay', '04x35_-_The_Requiem_Quietly_Plays__Part_2'), ('back', '04x35_-_The_Requiem_Quietly_Plays__Part_2'), ('other', '04x35_-_The_Requiem_Quietly_Plays__Part_2'), ('most', '04x35_-_The_Requiem_Quietly_Plays__Part_2'), ('right', '04x35_-_The_Requiem_Quietly_Plays__Part_2'), ('slow', '04x35_-_The_Requiem_Quietly_Plays__Part_2'), ('split', '04x35_-_The_Requiem_Quietly_Plays__Part_2'), ('inconceivable', '04x35_-_The_Requiem_Quietly_Plays__Part_2'), ('separate', '04x35_-_The_Requiem_Quietly_Plays__Part_2'), ('close', '04x35_-_The_Requiem_Quietly_Plays__Part_2'), ('bad', '04x35_-_The_Requiem_Quietly_Plays__Part_2'), ('main', '04x35_-_The_Requiem_Quietly_Plays__Part_2'), ('invincible', '04x35_-_The_Requiem_Quietly_Plays__Part_2'), ('awake', '04x35_-_The_Requiem_Quietly_Plays__Part_2'), ('possible', '04x35_-_The_Requiem_Quietly_Plays__Part_2'), ('only', '04x35_-_The_Requiem_Quietly_Plays__Part_2'), ('difficult', '04x35_-_The_Requiem_Quietly_Plays__Part_2'), ('sure', '04x35_-_The_Requiem_Quietly_Plays__Part_2'), ('same', '04x35_-_The_Requiem_Quietly_Plays__Part_2'), ('\\c&h&\\c&hc&}rumble', '04x35_-_The_Requiem_Quietly_Plays__Part_2'), ('cold', '04x35_-_The_Requiem_Quietly_Plays__Part_2'), ('impossible', '04x35_-_The_Requiem_Quietly_Plays__Part_2'), ('sudden', '04x35_-_The_Requiem_Quietly_Plays__Part_2')}
# {('precious', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('unknown', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('delicious', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('damn', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('vegetarian', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('sweetfish', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('well', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('careful', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('rough', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('ordinary', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('real', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('main', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('convincing', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('usual', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('fine', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('autopsy', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('high', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('private', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('golden', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('herbivorous', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('responsible', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('young', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('absolute', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('blue', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('unimaginable', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('guilty', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('important', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('sorry', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('stab', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('youthful', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('right', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('alive', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('nice', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('such', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('whole', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('only', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('culinary', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('impossible', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('late', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('past', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('weak', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('unbelievable', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('rightful', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('lucky', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('free', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('other', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('useless', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('happy', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('hunched', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('enough', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('true', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('bitter', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('much', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('dead', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('bad', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('same', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('last', '04x38_-_Gold_Experience_Requiem_-_Golden_Wind_Requiem'), ('disgusting', '04x38_-_Gold_Experience_Requiem_-_Golden_W ...
# {('direct', '04x14_-_Express_Train_to_Florence_-_Il_Treno_Espresso_per_Firenze'), ('light', '04x14_-_Express_Train_to_Florence_-_Il_Treno_Espresso_per_Firenze'), ('confident', '04x14_-_Express_Train_to_Florence_-_Il_Treno_Espresso_per_Firenze'), ('cold', '04x14_-_Express_Train_to_Florence_-_Il_Treno_Espresso_per_Firenze'), ('sudden', '04x14_-_Express_Train_to_Florence_-_Il_Treno_Espresso_per_Firenze'), ('non', '04x14_-_Express_Train_to_Florence_-_Il_Treno_Espresso_per_Firenze'), ('carbonated', '04x14_-_Express_Train_to_Florence_-_Il_Treno_Espresso_per_Firenze'), ('sixth', '04x14_-_Express_Train_to_Florence_-_Il_Treno_Espresso_per_Firenze'), ('able', '04x14_-_Express_Train_to_Florence_-_Il_Treno_Espresso_per_Firenze'), ('gross', '04x14_-_Express_Train_to_Florence_-_Il_Treno_Espresso_per_Firenze'), ('pro', '04x14_-_Express_Train_to_Florence_-_Il_Treno_Espresso_per_Firenze'), ('different', '04x14_-_Express_Train_to_Florence_-_Il_Treno_Espresso_per_Firenze'), ('wrong', '04x14_-_Express_Train_to_Florence_-_Il_Treno_Espresso_per_Firenze'), ('tired', '04x14_-_Express_Train_to_Florence_-_Il_Treno_Espresso_per_Firenze'), ('warm', '04x14_-_Express_Train_to_Florence_-_Il_Treno_Espresso_per_Firenze'), ('fat', '04x14_-_Express_Train_to_Florence_-_Il_Treno_Espresso_per_Firenze'), ('next', '04x14_-_Express_Train_to_Florence_-_Il_Treno_Espresso_per_Firenze'), ('big', '04x14_-_Express_Train_to_Florence_-_Il_Treno_Espresso_per_Firenze'), ('white', '04x14_-_Express_Train_to_Florence_-_Il_Treno_Espresso_per_Firenze'), ('dangerous', '04x14_-_Express_Train_to_Florence_-_Il_Treno_Espresso_per_Firenze'), ('lead', '04x14_-_Express_Train_to_Florence_-_Il_Treno_Espresso_per_Firenze'), ('little', '04x14_-_Express_Train_to_Florence_-_Il_Treno_Espresso_per_Firenze'), ('ow', '04x14_-_Express_Train_to_Florence_-_Il_Treno_Espresso_per_Firenze'), ('early', '04x14_-_Express_Train_to_Florence_-_Il_Treno_Espresso_per_Firenze'), ('-', '04x14_-_Express_Train_to_Florence_-_Il_Treno_Espresso_per_Firenze'), ('chilled', '04x14_-_Express_Train_to_Florence_-_Il_Treno_Espresso_per_Firenze'), ('homeless', '04x14_-_Express_Train_to_Florence_-_Il_Treno_Espresso_per_Firenze'), ('black', '04x14_-_Express_Train_to_Florence_-_Il_Treno_Espresso_per_Firenze'), ('more', '04x14_-_Express_Train_to_Florence_-_Il_Treno_Espresso_per_Firenze'), ('cooler', '04x14_-_Express_Train_to_Florence_-_Il_Treno_Espresso_per_Firenze'), ('hard', '04x14_-_Express_Train_to_Florence_-_Il_Treno_Espresso_per_Firenze'), ('old', '04x14_-_Express_Train_to_Florence_-_Il_Treno_Espresso_per_Firenze'), ('hot', '04x14_-_Express_Train_to_Florence_-_Il_Treno_Espresso_per_Firenze'), ('definitive', '04x14_-_Express_Train_to_Florence_-_Il_Treno_Espresso_per_Firenze'), ('second', '04x14_-_Express_Train_to_Florence_-_Il_Treno_Espresso_per_Firenze'), ('desperate', '04x14_-_Express_Train_to_Florence_-_Il_Treno_Espresso_per_Firenze'), ('muggy', '04x14_-_Express_Train_to_Florence_-_Il_Treno_Espresso_per_Firenze'), ('good', '04x14_-_Express_Train_to_Florence_-_Il_Treno_Espresso_per_Firenze'), ('other', '04x14_-_Express_Train_to_Florence_-_Il_Treno_Espresso_per_Firenze'), ('brutal', '04x14_-_Express_Train_to_Florence_-_Il_Treno_Espresso_per_Firenze'), ('awesome', '04x14_-_Express_Train_to_Florence_-_Il_Treno_Espresso_per_Firenze'), ('small', '04x14_-_Express_Train_to_Florence_-_Il_Treno_Espresso_per_Firenze'), ('right', '04x14_-_Express_Train_to_Florence_-_Il_Treno_Espresso_per_Firenze'), ('loud', '04x14_-_Express_Train_to_Florence_-_Il_Treno_Espresso_per_Firenze'), ('alarming', '04x14_-_Express_Train_to_Florence_-_Il_Treno_Espresso_per_Firenze'), ('alive', '04x14_-_Express_Train_to_Florence_-_Il_Treno_Espresso_per_Firenze'), ('stiff', '04x14_-_Express_Train_to_Florence_-_Il_Treno_Espresso_per_Firenze'), ('dry', '04x14_-_Express_Train_to_Florence_-_Il_Treno_Espresso_per_Firenze'), ('aged', '04x14_-_Express_Train_to_Florence_-_Il_Treno_Espresso_per_Firenze'), ('less', '04x14_-_Express_Train_to_Florence_-_Il_Treno_Espresso_per_ ...
# {('useless', '04x37_-_King_of_Kings'), ('tremendous', '04x37_-_King_of_Kings'), ('stupid', '04x37_-_King_of_Kings'), ('ideal', '04x37_-_King_of_Kings'), ('unexpected', '04x37_-_King_of_Kings'), ('true', '04x37_-_King_of_Kings'), ('pointless', '04x37_-_King_of_Kings'), ('original', '04x37_-_King_of_Kings'), ('close', '04x37_-_King_of_Kings'), ('worthy', '04x37_-_King_of_Kings'), ('undeniable', '04x37_-_King_of_Kings'), ('invincible', '04x37_-_King_of_Kings'), ('only', '04x37_-_King_of_Kings'), ('sure', '04x37_-_King_of_Kings'), ('unworthy', '04x37_-_King_of_Kings'), ('about', '04x37_-_King_of_Kings'), ('quick', '04x37_-_King_of_Kings'), ('normal', '04x37_-_King_of_Kings'), ('able', '04x37_-_King_of_Kings'), ('complete', '04x37_-_King_of_Kings'), ('suitable', '04x37_-_King_of_Kings'), ('eternal', '04x37_-_King_of_Kings'), ('honest', '04x37_-_King_of_Kings'), ('wrong', '04x37_-_King_of_Kings'), ('next', '04x37_-_King_of_Kings'), ('open', '04x37_-_King_of_Kings'), ('little', '04x37_-_King_of_Kings'), ('weak', '04x37_-_King_of_Kings'), ('righteous', '04x37_-_King_of_Kings'), ('translucent', '04x37_-_King_of_Kings'), ('worth', '04x37_-_King_of_Kings'), ('superficial', '04x37_-_King_of_Kings'), ('few', '04x37_-_King_of_Kings'), ('berserk', '04x37_-_King_of_Kings'), ('glad', '04x37_-_King_of_Kings'), ('unknown', '04x37_-_King_of_Kings'), ('okay', '04x37_-_King_of_Kings'), ('right', '04x37_-_King_of_Kings'), ('insulting', '04x37_-_King_of_Kings')}
# {('white', '04x07_-_Sex_Pistols_Appears__Part_1_-_Six_b_ll_ts_Appears__Part_1'), ('current', '04x07_-_Sex_Pistols_Appears__Part_1_-_Six_b_ll_ts_Appears__Part_1'), ('vital', '04x07_-_Sex_Pistols_Appears__Part_1_-_Six_b_ll_ts_Appears__Part_1'), ('little', '04x07_-_Sex_Pistols_Appears__Part_1_-_Six_b_ll_ts_Appears__Part_1'), ('blue', '04x07_-_Sex_Pistols_Appears__Part_1_-_Six_b_ll_ts_Appears__Part_1'), ('remote', '04x07_-_Sex_Pistols_Appears__Part_1_-_Six_b_ll_ts_Appears__Part_1'), ('first', '04x07_-_Sex_Pistols_Appears__Part_1_-_Six_b_ll_ts_Appears__Part_1'), ('more', '04x07_-_Sex_Pistols_Appears__Part_1_-_Six_b_ll_ts_Appears__Part_1'), ('hard', '04x07_-_Sex_Pistols_Appears__Part_1_-_Six_b_ll_ts_Appears__Part_1'), ('dear', '04x07_-_Sex_Pistols_Appears__Part_1_-_Six_b_ll_ts_Appears__Part_1'), ('ancient', '04x07_-_Sex_Pistols_Appears__Part_1_-_Six_b_ll_ts_Appears__Part_1'), ('panicky', '04x07_-_Sex_Pistols_Appears__Part_1_-_Six_b_ll_ts_Appears__Part_1'), ('powerful', '04x07_-_Sex_Pistols_Appears__Part_1_-_Six_b_ll_ts_Appears__Part_1'), ('safe', '04x07_-_Sex_Pistols_Appears__Part_1_-_Six_b_ll_ts_Appears__Part_1'), ('menacing', '04x07_-_Sex_Pistols_Appears__Part_1_-_Six_b_ll_ts_Appears__Part_1'), ('single', '04x07_-_Sex_Pistols_Appears__Part_1_-_Six_b_ll_ts_Appears__Part_1'), ('other', '04x07_-_Sex_Pistols_Appears__Part_1_-_Six_b_ll_ts_Appears__Part_1'), ('good', '04x07_-_Sex_Pistols_Appears__Part_1_-_Six_b_ll_ts_Appears__Part_1'), ('delicious', '04x07_-_Sex_Pistols_Appears__Part_1_-_Six_b_ll_ts_Appears__Part_1'), ('most', '04x07_-_Sex_Pistols_Appears__Part_1_-_Six_b_ll_ts_Appears__Part_1'), ('excited', '04x07_-_Sex_Pistols_Appears__Part_1_-_Six_b_ll_ts_Appears__Part_1'), ('right', '04x07_-_Sex_Pistols_Appears__Part_1_-_Six_b_ll_ts_Appears__Part_1'), ('tuscan', '04x07_-_Sex_Pistols_Appears__Part_1_-_Six_b_ll_ts_Appears__Part_1'), ('back', '04x07_-_Sex_Pistols_Appears__Part_1_-_Six_b_ll_ts_Appears__Part_1'), ('dark', '04x07_-_Sex_Pistols_Appears__Part_1_-_Six_b_ll_ts_Appears__Part_1'), ('loud', '04x07_-_Sex_Pistols_Appears__Part_1_-_Six_b_ll_ts_Appears__Part_1'), ('perfect', '04x07_-_Sex_Pistols_Appears__Part_1_-_Six_b_ll_ts_Appears__Part_1'), ('cautious', '04x07_-_Sex_Pistols_Appears__Part_1_-_Six_b_ll_ts_Appears__Part_1'), ('beautiful', '04x07_-_Sex_Pistols_Appears__Part_1_-_Six_b_ll_ts_Appears__Part_1'), ('enough', '04x07_-_Sex_Pistols_Appears__Part_1_-_Six_b_ll_ts_Appears__Part_1'), ('stupid', '04x07_-_Sex_Pistols_Appears__Part_1_-_Six_b_ll_ts_Appears__Part_1'), ('plastic', '04x07_-_Sex_Pistols_Appears__Part_1_-_Six_b_ll_ts_Appears__Part_1'), ('well', '04x07_-_Sex_Pistols_Appears__Part_1_-_Six_b_ll_ts_Appears__Part_1'), ('ri', '04x07_-_Sex_Pistols_Appears__Part_1_-_Six_b_ll_ts_Appears__Part_1'), ('rear', '04x07_-_Sex_Pistols_Appears__Part_1_-_Six_b_ll_ts_Appears__Part_1'), ('sharp', '04x07_-_Sex_Pistols_Appears__Part_1_-_Six_b_ll_ts_Appears__Part_1'), ('various', '04x07_-_Sex_Pistols_Appears__Part_1_-_Six_b_ll_ts_Appears__Part_1'), ('roundabout', '04x07_-_Sex_Pistols_Appears__Part_1_-_Six_b_ll_ts_Appears__Part_1'), ('flat', '04x07_-_Sex_Pistols_Appears__Part_1_-_Six_b_ll_ts_Appears__Part_1'), ('whole', '04x07_-_Sex_Pistols_Appears__Part_1_-_Six_b_ll_ts_Appears__Part_1'), ('many', '04x07_-_Sex_Pistols_Appears__Part_1_-_Six_b_ll_ts_Appears__Part_1'), ('close', '04x07_-_Sex_Pistols_Appears__Part_1_-_Six_b_ll_ts_Appears__Part_1'), ('wary', '04x07_-_Sex_Pistols_Appears__Part_1_-_Six_b_ll_ts_Appears__Part_1'), ('busy', '04x07_-_Sex_Pistols_Appears__Part_1_-_Six_b_ll_ts_Appears__Part_1'), ('rid', '04x07_-_Sex_Pistols_Appears__Part_1_-_Six_b_ll_ts_Appears__Part_1'), ('bad', '04x07_-_Sex_Pistols_Appears__Part_1_-_Six_b_ll_ts_Appears__Part_1'), ('main', '04x07_-_Sex_Pistols_Appears__Part_1_-_Six_b_ll_ts_Appears__Part_1'), ('fine', '04x07_-_Sex_Pistols_Appears__Part_1_-_Six_b_ll_ts_Appears__Part_1'), ('about', '04x07_-_Sex_Pistols_Appears__Part_1_-_Six_b_ll_ts_Appears__Part_1'), ('possible', '04x07_-_Sex_Pistols_Appears__Part_1_-_Six_b_ll_t ...
# {('direct', '04x09_-_The_First_Mission_from_the_Boss'), ('last', '04x09_-_The_First_Mission_from_the_Boss'), ('suspicious', '04x09_-_The_First_Mission_from_the_Boss'), ('able', '04x09_-_The_First_Mission_from_the_Boss'), ('shirtless', '04x09_-_The_First_Mission_from_the_Boss'), ('high', '04x09_-_The_First_Mission_from_the_Boss'), ('trustworthy', '04x09_-_The_First_Mission_from_the_Boss'), ('rude', '04x09_-_The_First_Mission_from_the_Boss'), ('stuck', '04x09_-_The_First_Mission_from_the_Boss'), ('unfinished', '04x09_-_The_First_Mission_from_the_Boss'), ('own', '04x09_-_The_First_Mission_from_the_Boss'), ('aware', '04x09_-_The_First_Mission_from_the_Boss'), ('internal', '04x09_-_The_First_Mission_from_the_Boss'), ('amazing', '04x09_-_The_First_Mission_from_the_Boss'), ('mysterious', '04x09_-_The_First_Mission_from_the_Boss'), ('jeez', '04x09_-_The_First_Mission_from_the_Boss'), ('reliable', '04x09_-_The_First_Mission_from_the_Boss'), ('narrow', '04x09_-_The_First_Mission_from_the_Boss'), ('dangerous', '04x09_-_The_First_Mission_from_the_Boss'), ('little', '04x09_-_The_First_Mission_from_the_Boss'), ('young', '04x09_-_The_First_Mission_from_the_Boss'), ('absolute', '04x09_-_The_First_Mission_from_the_Boss'), ('worth', '04x09_-_The_First_Mission_from_the_Boss'), ('few', '04x09_-_The_First_Mission_from_the_Boss'), ('tiny', '04x09_-_The_First_Mission_from_the_Boss'), ('yourtrue', '04x09_-_The_First_Mission_from_the_Boss'), ('opposite', '04x09_-_The_First_Mission_from_the_Boss'), ('frail', '04x09_-_The_First_Mission_from_the_Boss'), ('old', '04x09_-_The_First_Mission_from_the_Boss'), ('morallywrong', '04x09_-_The_First_Mission_from_the_Boss'), ('immediate', '04x09_-_The_First_Mission_from_the_Boss'), ('safe', '04x09_-_The_First_Mission_from_the_Boss'), ('important', '04x09_-_The_First_Mission_from_the_Boss'), ('free', '04x09_-_The_First_Mission_from_the_Boss'), ('lucky', '04x09_-_The_First_Mission_from_the_Boss'), ('okay', '04x09_-_The_First_Mission_from_the_Boss'), ('correct', '04x09_-_The_First_Mission_from_the_Boss'), ('clear', '04x09_-_The_First_Mission_from_the_Boss'), ('small', '04x09_-_The_First_Mission_from_the_Boss'), ('right', '04x09_-_The_First_Mission_from_the_Boss'), ('good', '04x09_-_The_First_Mission_from_the_Boss'), ('other', '04x09_-_The_First_Mission_from_the_Boss'), ('useless', '04x09_-_The_First_Mission_from_the_Boss'), ('cautious', '04x09_-_The_First_Mission_from_the_Boss'), ('damn', '04x09_-_The_First_Mission_from_the_Boss'), ('new', '04x09_-_The_First_Mission_from_the_Boss'), ('picky', '04x09_-_The_First_Mission_from_the_Boss'), ('less', '04x09_-_The_First_Mission_from_the_Boss'), ('worthless', '04x09_-_The_First_Mission_from_the_Boss'), ('whole', '04x09_-_The_First_Mission_from_the_Boss'), ('real', '04x09_-_The_First_Mission_from_the_Boss'), ('many', '04x09_-_The_First_Mission_from_the_Boss'), ('comic', '04x09_-_The_First_Mission_from_the_Boss'), ('dead', '04x09_-_The_First_Mission_from_the_Boss'), ('intelligent', '04x09_-_The_First_Mission_from_the_Boss'), ('rid', '04x09_-_The_First_Mission_from_the_Boss'), ('dizzy', '04x09_-_The_First_Mission_from_the_Boss'), ('bad', '04x09_-_The_First_Mission_from_the_Boss'), ('main', '04x09_-_The_First_Mission_from_the_Boss'), ('worried', '04x09_-_The_First_Mission_from_the_Boss'), ('fine', '04x09_-_The_First_Mission_from_the_Boss'), ('italian', '04x09_-_The_First_Mission_from_the_Boss'), ('same', '04x09_-_The_First_Mission_from_the_Boss'), ('only', '04x09_-_The_First_Mission_from_the_Boss'), ('sure', '04x09_-_The_First_Mission_from_the_Boss'), ('scary', '04x09_-_The_First_Mission_from_the_Boss'), ('late', '04x09_-_The_First_Mission_from_the_Boss')}
# {('able', '04x28_-_Beneath_a_Sky_on_the_Verge_of_Falling'), ('high', '04x28_-_Beneath_a_Sky_on_the_Verge_of_Falling'), ('great', '04x28_-_Beneath_a_Sky_on_the_Verge_of_Falling'), ('sensitive', '04x28_-_Beneath_a_Sky_on_the_Verge_of_Falling'), ('wrong', '04x28_-_Beneath_a_Sky_on_the_Verge_of_Falling'), ('exact', '04x28_-_Beneath_a_Sky_on_the_Verge_of_Falling'), ('very', '04x28_-_Beneath_a_Sky_on_the_Verge_of_Falling'), ('unable', '04x28_-_Beneath_a_Sky_on_the_Verge_of_Falling'), ('curious', '04x28_-_Beneath_a_Sky_on_the_Verge_of_Falling'), ('dangerous', '04x28_-_Beneath_a_Sky_on_the_Verge_of_Falling'), ('rocky', '04x28_-_Beneath_a_Sky_on_the_Verge_of_Falling'), ('little', '04x28_-_Beneath_a_Sky_on_the_Verge_of_Falling'), ('tat', '04x28_-_Beneath_a_Sky_on_the_Verge_of_Falling'), ('weak', '04x28_-_Beneath_a_Sky_on_the_Verge_of_Falling'), ('more', '04x28_-_Beneath_a_Sky_on_the_Verge_of_Falling'), ("li'l", '04x28_-_Beneath_a_Sky_on_the_Verge_of_Falling'), ('hard', '04x28_-_Beneath_a_Sky_on_the_Verge_of_Falling'), ('proud', '04x28_-_Beneath_a_Sky_on_the_Verge_of_Falling'), ('powerful', '04x28_-_Beneath_a_Sky_on_the_Verge_of_Falling'), ('sorry', '04x28_-_Beneath_a_Sky_on_the_Verge_of_Falling'), ('second', '04x28_-_Beneath_a_Sky_on_the_Verge_of_Falling'), ('guilty', '04x28_-_Beneath_a_Sky_on_the_Verge_of_Falling'), ('important', '04x28_-_Beneath_a_Sky_on_the_Verge_of_Falling'), ('nearby', '04x28_-_Beneath_a_Sky_on_the_Verge_of_Falling'), ('good', '04x28_-_Beneath_a_Sky_on_the_Verge_of_Falling'), ('other', '04x28_-_Beneath_a_Sky_on_the_Verge_of_Falling'), ('small', '04x28_-_Beneath_a_Sky_on_the_Verge_of_Falling'), ('right', '04x28_-_Beneath_a_Sky_on_the_Verge_of_Falling'), ('enough', '04x28_-_Beneath_a_Sky_on_the_Verge_of_Falling'), ('prepared', '04x28_-_Beneath_a_Sky_on_the_Verge_of_Falling'), ('true', '04x28_-_Beneath_a_Sky_on_the_Verge_of_Falling'), ('pathetic', '04x28_-_Beneath_a_Sky_on_the_Verge_of_Falling'), ('crafty', '04x28_-_Beneath_a_Sky_on_the_Verge_of_Falling'), ('whole', '04x28_-_Beneath_a_Sky_on_the_Verge_of_Falling'), ('many', '04x28_-_Beneath_a_Sky_on_the_Verge_of_Falling'), ('fast', '04x28_-_Beneath_a_Sky_on_the_Verge_of_Falling'), ('close', '04x28_-_Beneath_a_Sky_on_the_Verge_of_Falling'), ('worthless', '04x28_-_Beneath_a_Sky_on_the_Verge_of_Falling'), ('unfortunate', '04x28_-_Beneath_a_Sky_on_the_Verge_of_Falling'), ('much', '04x28_-_Beneath_a_Sky_on_the_Verge_of_Falling'), ('bad', '04x28_-_Beneath_a_Sky_on_the_Verge_of_Falling'), ('main', '04x28_-_Beneath_a_Sky_on_the_Verge_of_Falling'), ('dead', '04x28_-_Beneath_a_Sky_on_the_Verge_of_Falling'), ('long', '04x28_-_Beneath_a_Sky_on_the_Verge_of_Falling'), ('usual', '04x28_-_Beneath_a_Sky_on_the_Verge_of_Falling'), ('only', '04x28_-_Beneath_a_Sky_on_the_Verge_of_Falling'), ('motivated', '04x28_-_Beneath_a_Sky_on_the_Verge_of_Falling'), ('sure', '04x28_-_Beneath_a_Sky_on_the_Verge_of_Falling'), ('confident', '04x28_-_Beneath_a_Sky_on_the_Verge_of_Falling'), ('about', '04x28_-_Beneath_a_Sky_on_the_Verge_of_Falling'), ('distinguished', '04x28_-_Beneath_a_Sky_on_the_Verge_of_Falling'), ('same', '04x28_-_Beneath_a_Sky_on_the_Verge_of_Falling'), ('last', '04x28_-_Beneath_a_Sky_on_the_Verge_of_Falling'), ('serious', '04x28_-_Beneath_a_Sky_on_the_Verge_of_Falling'), ('late', '04x28_-_Beneath_a_Sky_on_the_Verge_of_Falling')}
# {('right', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('good', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('useless', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('enough', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('slow', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('true', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('careful', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('well', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('surprised', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('random', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('intuitive', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('strange', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('um', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('many', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('fast', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('unprepared', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('rid', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('bad', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('elite', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('invincible', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('actual', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('determined', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('only', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('about', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('fine', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('sure', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('personal', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('serious', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('suspicious', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('disgusting', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('great', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('able', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('ready', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('normal', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('huge', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('past', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('strong', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('exact', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('own', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('least', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('next', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('wrong', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('tough', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('left', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('big', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('white', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('little', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('hungry', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('few', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('empty', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('first', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('scared', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('more', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('hard', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('old', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('clear', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('correct', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('single', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('intense', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo'), ('unconscious', '04x22_-_The__G__in_Guts_-_The__G__in_Gozzo')}
# {('serious', '04x21_5_-_Determination'), ('insane', '04x21_5_-_Determination'), ('silent', '04x21_5_-_Determination'), ('strong', '04x21_5_-_Determination'), ('bright', '04x21_5_-_Determination'), ('judicial', '04x21_5_-_Determination'), ('naked', '04x21_5_-_Determination'), ('simple', '04x21_5_-_Determination'), ('few', '04x21_5_-_Determination'), ('unbelievable', '04x21_5_-_Determination'), ('alone', '04x21_5_-_Determination'), ('gentle', '04x21_5_-_Determination'), ('weak', '04x21_5_-_Determination'), ('more', '04x21_5_-_Determination'), ('old', '04x21_5_-_Determination'), ('solid', '04x21_5_-_Determination'), ('lucky', '04x21_5_-_Determination'), ('passionate', '04x21_5_-_Determination'), ('single', '04x21_5_-_Determination'), ('useless', '04x21_5_-_Determination'), ('enough', '04x21_5_-_Determination'), ('true', '04x21_5_-_Determination'), ('due', '04x21_5_-_Determination'), ('sharp', '04x21_5_-_Determination'), ('various', '04x21_5_-_Determination'), ('much', '04x21_5_-_Determination'), ('same', '04x21_5_-_Determination'), ('quiet', '04x21_5_-_Determination'), ('innocent', '04x21_5_-_Determination'), ('able', '04x21_5_-_Determination'), ('huge', '04x21_5_-_Determination'), ('next', '04x21_5_-_Determination'), ('dangerous', '04x21_5_-_Determination'), ('little', '04x21_5_-_Determination'), ('cheap', '04x21_5_-_Determination'), ('conscious', '04x21_5_-_Determination'), ('conflicted', '04x21_5_-_Determination'), ('clear', '04x21_5_-_Determination'), ('intense', '04x21_5_-_Determination'), ('good', '04x21_5_-_Determination'), ('fair', '04x21_5_-_Determination'), ('prepared', '04x21_5_-_Determination'), ('panicked', '04x21_5_-_Determination'), ('impulsive', '04x21_5_-_Determination'), ('strange', '04x21_5_-_Determination'), ('long', '04x21_5_-_Determination'), ('possible', '04x21_5_-_Determination'), ('sure', '04x21_5_-_Determination'), ('great', '04x21_5_-_Determination'), ('least', '04x21_5_-_Determination'), ('wrong', '04x21_5_-_Determination'), ('internal', '04x21_5_-_Determination'), ('helpless', '04x21_5_-_Determination'), ('utmost', '04x21_5_-_Determination'), ('likely', '04x21_5_-_Determination'), ('damn', '04x21_5_-_Determination'), ('new', '04x21_5_-_Determination'), ('whole', '04x21_5_-_Determination'), ('honorable', '04x21_5_-_Determination'), ('rid', '04x21_5_-_Determination'), ('real', '04x21_5_-_Determination'), ('main', '04x21_5_-_Determination'), ('usual', '04x21_5_-_Determination'), ('invisible', '04x21_5_-_Determination'), ('high', '04x21_5_-_Determination'), ('ready', '04x21_5_-_Determination'), ('golden', '04x21_5_-_Determination'), ('own', '04x21_5_-_Determination'), ('fierce', '04x21_5_-_Determination'), ('open', '04x21_5_-_Determination'), ('young', '04x21_5_-_Determination'), ('absolute', '04x21_5_-_Determination'), ('dear', '04x21_5_-_Determination'), ('juvenile', '04x21_5_-_Determination'), ('rich', '04x21_5_-_Determination'), ('guilty', '04x21_5_-_Determination'), ('minded', '04x21_5_-_Determination'), ('important', '04x21_5_-_Determination'), ('formidable', '04x21_5_-_Determination'), ('powerful', '04x21_5_-_Determination'), ('hooky', '04x21_5_-_Determination'), ('blonde', '04x21_5_-_Determination'), ('right', '04x21_5_-_Determination'), ('naïve', '04x21_5_-_Determination'), ('wealthy', '04x21_5_-_Determination'), ('alive', '04x21_5_-_Determination'), ('horrifying', '04x21_5_-_Determination'), ('final', '04x21_5_-_Determination'), ('filthy', '04x21_5_-_Determination'), ('only', '04x21_5_-_Determination'), ('cold', '04x21_5_-_Determination'), ('unforgivable', '04x21_5_-_Determination')}
# {('famous', '04x29_-_Get_to_the_Roman_Colosseum__-_Verso_il_Colosseo_di_Roma'), ('long', '04x29_-_Get_to_the_Roman_Colosseum__-_Verso_il_Colosseo_di_Roma'), ('human', '04x29_-_Get_to_the_Roman_Colosseum__-_Verso_il_Colosseo_di_Roma'), ('dead', '04x29_-_Get_to_the_Roman_Colosseum__-_Verso_il_Colosseo_di_Roma'), ('viral', '04x29_-_Get_to_the_Roman_Colosseum__-_Verso_il_Colosseo_di_Roma'), ('same', '04x29_-_Get_to_the_Roman_Colosseum__-_Verso_il_Colosseo_di_Roma'), ('quiet', '04x29_-_Get_to_the_Roman_Colosseum__-_Verso_il_Colosseo_di_Roma'), ('innocent', '04x29_-_Get_to_the_Roman_Colosseum__-_Verso_il_Colosseo_di_Roma'), ('able', '04x29_-_Get_to_the_Roman_Colosseum__-_Verso_il_Colosseo_di_Roma'), ('healthy', '04x29_-_Get_to_the_Roman_Colosseum__-_Verso_il_Colosseo_di_Roma'), ('internal', '04x29_-_Get_to_the_Roman_Colosseum__-_Verso_il_Colosseo_di_Roma'), ('particular', '04x29_-_Get_to_the_Roman_Colosseum__-_Verso_il_Colosseo_di_Roma'), ('entomopathogenic', '04x29_-_Get_to_the_Roman_Colosseum__-_Verso_il_Colosseo_di_Roma'), ('little', '04x29_-_Get_to_the_Roman_Colosseum__-_Verso_il_Colosseo_di_Roma'), ('similar', '04x29_-_Get_to_the_Roman_Colosseum__-_Verso_il_Colosseo_di_Roma'), ('unknown', '04x29_-_Get_to_the_Roman_Colosseum__-_Verso_il_Colosseo_di_Roma'), ('good', '04x29_-_Get_to_the_Roman_Colosseum__-_Verso_il_Colosseo_di_Roma'), ('most', '04x29_-_Get_to_the_Roman_Colosseum__-_Verso_il_Colosseo_di_Roma'), ('damn', '04x29_-_Get_to_the_Roman_Colosseum__-_Verso_il_Colosseo_di_Roma'), ('rare', '04x29_-_Get_to_the_Roman_Colosseum__-_Verso_il_Colosseo_di_Roma'), ('well', '04x29_-_Get_to_the_Roman_Colosseum__-_Verso_il_Colosseo_di_Roma'), ('superior', '04x29_-_Get_to_the_Roman_Colosseum__-_Verso_il_Colosseo_di_Roma'), ('low', '04x29_-_Get_to_the_Roman_Colosseum__-_Verso_il_Colosseo_di_Roma'), ('fine', '04x29_-_Get_to_the_Roman_Colosseum__-_Verso_il_Colosseo_di_Roma'), ('excellent', '04x29_-_Get_to_the_Roman_Colosseum__-_Verso_il_Colosseo_di_Roma'), ('sure', '04x29_-_Get_to_the_Roman_Colosseum__-_Verso_il_Colosseo_di_Roma'), ('suspicious', '04x29_-_Get_to_the_Roman_Colosseum__-_Verso_il_Colosseo_di_Roma'), ('own', '04x29_-_Get_to_the_Roman_Colosseum__-_Verso_il_Colosseo_di_Roma'), ('least', '04x29_-_Get_to_the_Roman_Colosseum__-_Verso_il_Colosseo_di_Roma'), ('wrong', '04x29_-_Get_to_the_Roman_Colosseum__-_Verso_il_Colosseo_di_Roma'), ('later', '04x29_-_Get_to_the_Roman_Colosseum__-_Verso_il_Colosseo_di_Roma'), ('young', '04x29_-_Get_to_the_Roman_Colosseum__-_Verso_il_Colosseo_di_Roma'), ('absolute', '04x29_-_Get_to_the_Roman_Colosseum__-_Verso_il_Colosseo_di_Roma'), ('berserk', '04x29_-_Get_to_the_Roman_Colosseum__-_Verso_il_Colosseo_di_Roma'), ('important', '04x29_-_Get_to_the_Roman_Colosseum__-_Verso_il_Colosseo_di_Roma'), ('elderly', '04x29_-_Get_to_the_Roman_Colosseum__-_Verso_il_Colosseo_di_Roma'), ('former', '04x29_-_Get_to_the_Roman_Colosseum__-_Verso_il_Colosseo_di_Roma'), ('unconscious', '04x29_-_Get_to_the_Roman_Colosseum__-_Verso_il_Colosseo_di_Roma'), ('right', '04x29_-_Get_to_the_Roman_Colosseum__-_Verso_il_Colosseo_di_Roma'), ('such', '04x29_-_Get_to_the_Roman_Colosseum__-_Verso_il_Colosseo_di_Roma'), ('perfect', '04x29_-_Get_to_the_Roman_Colosseum__-_Verso_il_Colosseo_di_Roma'), ('new', '04x29_-_Get_to_the_Roman_Colosseum__-_Verso_il_Colosseo_di_Roma'), ('whole', '04x29_-_Get_to_the_Roman_Colosseum__-_Verso_il_Colosseo_di_Roma'), ('close', '04x29_-_Get_to_the_Roman_Colosseum__-_Verso_il_Colosseo_di_Roma'), ('main', '04x29_-_Get_to_the_Roman_Colosseum__-_Verso_il_Colosseo_di_Roma'), ('invincible', '04x29_-_Get_to_the_Roman_Colosseum__-_Verso_il_Colosseo_di_Roma'), ('sardinian', '04x29_-_Get_to_the_Roman_Colosseum__-_Verso_il_Colosseo_di_Roma'), ('open', '04x29_-_Get_to_the_Roman_Colosseum__-_Verso_il_Colosseo_di_Roma'), ('previous', '04x29_-_Get_to_the_Roman_Colosseum__-_Verso_il_Colosseo_di_Roma'), ('elite', '04x29_-_Get_to_the_Roman_Colosseum__-_Verso_il_Colosseo_di_Roma'), ('meticulous', '04x29_-_Get_to_the_Roman_Colo ...
# ...
# {('fate', '04x19_-_White_Album_-_White_Ice'), ('due', '04x19_-_White_Album_-_White_Ice'), ('pointless', '04x19_-_White_Album_-_White_Ice'), ('low', '04x19_-_White_Album_-_White_Ice'), ('close', '04x19_-_White_Album_-_White_Ice'), ('much', '04x19_-_White_Album_-_White_Ice'), ('long', '04x19_-_White_Album_-_White_Ice'), ('bad', '04x19_-_White_Album_-_White_Ice'), ('main', '04x19_-_White_Album_-_White_Ice'), ('worried', '04x19_-_White_Album_-_White_Ice'), ('fine', '04x19_-_White_Album_-_White_Ice'), ('excellent', '04x19_-_White_Album_-_White_Ice'), ('only', '04x19_-_White_Album_-_White_Ice'), ('possible', '04x19_-_White_Album_-_White_Ice'), ('hidden', '04x19_-_White_Album_-_White_Ice'), ('sure', '04x19_-_White_Album_-_White_Ice'), ('same', '04x19_-_White_Album_-_White_Ice'), ('frozen', '04x19_-_White_Album_-_White_Ice'), ('reckless', '04x19_-_White_Album_-_White_Ice'), ('bent', '04x19_-_White_Album_-_White_Ice'), ('impossible', '04x19_-_White_Album_-_White_Ice'), ('normal', '04x19_-_White_Album_-_White_Ice'), ('gentler', '04x19_-_White_Album_-_White_Ice'), ('insane', '04x19_-_White_Album_-_White_Ice'), ('able', '04x19_-_White_Album_-_White_Ice'), ('More', '04x19_-_White_Album_-_White_Ice'), ('willing', '04x19_-_White_Album_-_White_Ice'), ('great', '04x19_-_White_Album_-_White_Ice'), ('strong', '04x19_-_White_Album_-_White_Ice'), ('own', '04x19_-_White_Album_-_White_Ice'), ('least', '04x19_-_White_Album_-_White_Ice'), ('next', '04x19_-_White_Album_-_White_Ice'), ('lukewarm', '04x19_-_White_Album_-_White_Ice'), ('wrong', '04x19_-_White_Album_-_White_Ice'), ('bright', '04x19_-_White_Album_-_White_Ice'), ('true', '04x19_-_White_Album_-_White_Ice'), ('internal', '04x19_-_White_Album_-_White_Ice'), ('dangerous', '04x19_-_White_Album_-_White_Ice'), ('futile', '04x19_-_White_Album_-_White_Ice'), ('bored', '04x19_-_White_Album_-_White_Ice'), ('young', '04x19_-_White_Album_-_White_Ice'), ('weak', '04x19_-_White_Album_-_White_Ice'), ('gentle', '04x19_-_White_Album_-_White_Ice'), ('few', '04x19_-_White_Album_-_White_Ice'), ('odd', '04x19_-_White_Album_-_White_Ice'), ('more', '04x19_-_White_Album_-_White_Ice'), ('immediate', '04x19_-_White_Album_-_White_Ice'), ('solid', '04x19_-_White_Album_-_White_Ice'), ('full', '04x19_-_White_Album_-_White_Ice'), ('conscious', '04x19_-_White_Album_-_White_Ice'), ('lucky', '04x19_-_White_Album_-_White_Ice'), ('skilled', '04x19_-_White_Album_-_White_Ice'), ('determined', '04x19_-_White_Album_-_White_Ice'), ('unknown', '04x19_-_White_Album_-_White_Ice'), ('happy', '04x19_-_White_Album_-_White_Ice'), ('right', '04x19_-_White_Album_-_White_Ice'), ('shallow', '04x19_-_White_Album_-_White_Ice'), ('other', '04x19_-_White_Album_-_White_Ice'), ('useless', '04x19_-_White_Album_-_White_Ice'), ('short', '04x19_-_White_Album_-_White_Ice'), ('interesting', '04x19_-_White_Album_-_White_Ice'), ('perfect', '04x19_-_White_Album_-_White_Ice'), ('crazy', '04x19_-_White_Album_-_White_Ice'), ('enough', '04x19_-_White_Album_-_White_Ice'), ('well', '04x19_-_White_Album_-_White_Ice'), ('optimistic', '04x19_-_White_Album_-_White_Ice')}
# {('hooky', '04x10_-_Hitman_Team'), ('loud', '04x10_-_Hitman_Team'), ('small', '04x10_-_Hitman_Team'), ('right', '04x10_-_Hitman_Team'), ('clean', '04x10_-_Hitman_Team'), ('harmless', '04x10_-_Hitman_Team'), ('powerless', '04x10_-_Hitman_Team'), ('whole', '04x10_-_Hitman_Team'), ('close', '04x10_-_Hitman_Team'), ('bad', '04x10_-_Hitman_Team'), ('only', '04x10_-_Hitman_Team'), ('light', '04x10_-_Hitman_Team'), ('last', '04x10_-_Hitman_Team'), ('late', '04x10_-_Hitman_Team'), ('impossible', '04x10_-_Hitman_Team'), ('lamer', '04x10_-_Hitman_Team'), ('serious', '04x10_-_Hitman_Team'), ('silent', '04x10_-_Hitman_Team'), ('weird', '04x10_-_Hitman_Team'), ('underwater', '04x10_-_Hitman_Team'), ('-', '04x10_-_Hitman_Team'), ("li'l", '04x10_-_Hitman_Team'), ('other', '04x10_-_Hitman_Team'), ('useless', '04x10_-_Hitman_Team'), ('enough', '04x10_-_Hitman_Team'), ('thirsty', '04x10_-_Hitman_Team'), ('heavy', '04x10_-_Hitman_Team'), ('sharp', '04x10_-_Hitman_Team'), ('various', '04x10_-_Hitman_Team'), ('many', '04x10_-_Hitman_Team'), ('much', '04x10_-_Hitman_Team'), ('dead', '04x10_-_Hitman_Team'), ('same', '04x10_-_Hitman_Team'), ('normal', '04x10_-_Hitman_Team'), ('cold', '04x10_-_Hitman_Team'), ('able', '04x10_-_Hitman_Team'), ('huge', '04x10_-_Hitman_Team'), ('next', '04x10_-_Hitman_Team'), ('little', '04x10_-_Hitman_Team'), ('cheap', '04x10_-_Hitman_Team'), ('few', '04x10_-_Hitman_Team'), ('\\pos(,)\\shad\\c&hedefef&}"punishment', '04x10_-_Hitman_Team'), ('tiny', '04x10_-_Hitman_Team'), ('more', '04x10_-_Hitman_Team'), ('glad', '04x10_-_Hitman_Team'), ('okay', '04x10_-_Hitman_Team'), ('good', '04x10_-_Hitman_Team'), ('fair', '04x10_-_Hitman_Team'), ('stupid', '04x10_-_Hitman_Team'), ('crazy', '04x10_-_Hitman_Team'), ('strange', '04x10_-_Hitman_Team'), ('long', '04x10_-_Hitman_Team'), ('possible', '04x10_-_Hitman_Team'), ('sure', '04x10_-_Hitman_Team'), ('about', '04x10_-_Hitman_Team'), ('least', '04x10_-_Hitman_Team'), ('wrong', '04x10_-_Hitman_Team'), ('internal', '04x10_-_Hitman_Team'), ('big', '04x10_-_Hitman_Team'), ('worth', '04x10_-_Hitman_Team'), ('intense', '04x10_-_Hitman_Team'), ('delicious', '04x10_-_Hitman_Team'), ('perfect', '04x10_-_Hitman_Team'), ('damn', '04x10_-_Hitman_Team'), ('new', '04x10_-_Hitman_Team'), ('smart', '04x10_-_Hitman_Team'), ('wonderful', '04x10_-_Hitman_Team'), ('main', '04x10_-_Hitman_Team'), ('worried', '04x10_-_Hitman_Team'), ('usual', '04x10_-_Hitman_Team'), ('fine', '04x10_-_Hitman_Team'), ('modern', '04x10_-_Hitman_Team'), ('tired', '04x10_-_Hitman_Team'), ('own', '04x10_-_Hitman_Team'), ('creepy', '04x10_-_Hitman_Team'), ('dear', '04x10_-_Hitman_Team'), ('rich', '04x10_-_Hitman_Team'), ('hard', '04x10_-_Hitman_Team'), ('flashbackinternal', '04x10_-_Hitman_Team')}
# {('-', '04x33_-_His_Name_Is_Diavolo'), ('weak', '04x33_-_His_Name_Is_Diavolo'), ('first', '04x33_-_His_Name_Is_Diavolo'), ('more', '04x33_-_His_Name_Is_Diavolo'), ('bizarre', '04x33_-_His_Name_Is_Diavolo'), ('sinister', '04x33_-_His_Name_Is_Diavolo'), ('old', '04x33_-_His_Name_Is_Diavolo'), ('similar', '04x33_-_His_Name_Is_Diavolo'), ('hard', '04x33_-_His_Name_Is_Diavolo'), ('surprising', '04x33_-_His_Name_Is_Diavolo'), ('second', '04x33_-_His_Name_Is_Diavolo'), ('incredible', '04x33_-_His_Name_Is_Diavolo'), ('victorious', '04x33_-_His_Name_Is_Diavolo'), ('safe', '04x33_-_His_Name_Is_Diavolo'), ('important', '04x33_-_His_Name_Is_Diavolo'), ('sorry', '04x33_-_His_Name_Is_Diavolo'), ('okay', '04x33_-_His_Name_Is_Diavolo'), ('selfish', '04x33_-_His_Name_Is_Diavolo'), ('other', '04x33_-_His_Name_Is_Diavolo'), ('horrible', '04x33_-_His_Name_Is_Diavolo'), ('good', '04x33_-_His_Name_Is_Diavolo'), ('a*s', '04x33_-_His_Name_Is_Diavolo'), ('small', '04x33_-_His_Name_Is_Diavolo'), ('trusted', '04x33_-_His_Name_Is_Diavolo'), ('right', '04x33_-_His_Name_Is_Diavolo'), ('unusual', '04x33_-_His_Name_Is_Diavolo'), ('new', '04x33_-_His_Name_Is_Diavolo'), ('dark', '04x33_-_His_Name_Is_Diavolo'), ('enough', '04x33_-_His_Name_Is_Diavolo'), ('stupid', '04x33_-_His_Name_Is_Diavolo'), ('surefire', '04x33_-_His_Name_Is_Diavolo'), ('slight', '04x33_-_His_Name_Is_Diavolo'), ('careful', '04x33_-_His_Name_Is_Diavolo'), ('handsome', '04x33_-_His_Name_Is_Diavolo'), ('presumptuous', '04x33_-_His_Name_Is_Diavolo'), ('close', '04x33_-_His_Name_Is_Diavolo'), ('many', '04x33_-_His_Name_Is_Diavolo'), ('strange', '04x33_-_His_Name_Is_Diavolo'), ('much', '04x33_-_His_Name_Is_Diavolo'), ('mental', '04x33_-_His_Name_Is_Diavolo'), ('efficient', '04x33_-_His_Name_Is_Diavolo'), ('bad', '04x33_-_His_Name_Is_Diavolo'), ('main', '04x33_-_His_Name_Is_Diavolo'), ('long', '04x33_-_His_Name_Is_Diavolo'), ('excellent', '04x33_-_His_Name_Is_Diavolo'), ('useful', '04x33_-_His_Name_Is_Diavolo'), ('sure', '04x33_-_His_Name_Is_Diavolo'), ('fine', '04x33_-_His_Name_Is_Diavolo'), ('same', '04x33_-_His_Name_Is_Diavolo'), ('few', '04x33_-_His_Name_Is_Diavolo'), ('last', '04x33_-_His_Name_Is_Diavolo'), ('cold', '04x33_-_His_Name_Is_Diavolo'), ('impossible', '04x33_-_His_Name_Is_Diavolo'), ('\\c&h&\\c&hcc&}rumble', '04x33_-_His_Name_Is_Diavolo'), ('great', '04x33_-_His_Name_Is_Diavolo'), ('ready', '04x33_-_His_Name_Is_Diavolo'), ('able', '04x33_-_His_Name_Is_Diavolo'), ('ominous', '04x33_-_His_Name_Is_Diavolo'), ('complete', '04x33_-_His_Name_Is_Diavolo'), ('friggin', '04x33_-_His_Name_Is_Diavolo'), ('murderous', '04x33_-_His_Name_Is_Diavolo'), ('wrong', '04x33_-_His_Name_Is_Diavolo'), ('tired', '04x33_-_His_Name_Is_Diavolo'), ('mysterious', '04x33_-_His_Name_Is_Diavolo'), ('internal', '04x33_-_His_Name_Is_Diavolo'), ('next', '04x33_-_His_Name_Is_Diavolo'), ('big', '04x33_-_His_Name_Is_Diavolo'), ('little', '04x33_-_His_Name_Is_Diavolo'), ('young', '04x33_-_His_Name_Is_Diavolo'), ('certain', '04x33_-_His_Name_Is_Diavolo')}
# {('detailed', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('ordinary', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('close', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('fast', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('dead', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('bad', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('main', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('sure', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('same', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('possible', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('only', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('impossible', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('sound', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('last', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('outside', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('able', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('ready', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('funny', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('sudden', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('emerald', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('wet', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('sensitive', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('own', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('internal', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('wrong', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('coastal', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('different', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('left', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('weird', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('sardinian', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('dangerous', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('big', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('little', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('simple', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('young', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('weak', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('open', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('few', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('more', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('rich', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('opposite', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('hard', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('second', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('former', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('good', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('fresh', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('hey', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('right', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('unthinkable', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('naïve', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('useless', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('most', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('cautious', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('relative', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('new', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('alive', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('slow', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('true', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('beautiful', '04x24_-_Notorious_B_I_G_-_Notorious_Chase'), ('careful', '04x24_-_Notorious_B_I_G_-_Notorious_Chase')}

# %% [markdown]
# ### Let's try dataframes to store these relations of word-form to unit
# Dataframes, supporteed by the pandas library in Python, facilitate handling data in spreadsheet / CSV / TSV format.
# We want to output some data to a TSV (tab-separated values file) so we can send it to network visualization software.
#
# We'll need to open a terminal and  **pip install pandas** (or python3.12 -m pip install pandas) to get dataframes working.

# %%
import pandas as pd

def wordCollector(words, unit):
    wordList = []
    nodeAtts = []
    unitList = []
    for token in words:
        if token.pos_ == "ADJ":
            wordList.append(token.lemma_)
            nodeAtts.append(token.pos_)
            unitList.append(unit)

    data = {
        'word': wordList,
        'nodeType': nodeAtts,
        'unit': unitList
    }
    df = pd.DataFrame(data)
    return df

for file in os.listdir(collPath):
    if file.endswith(".txt"):
        filepath = f"{collPath}/{file}"
        name, extension = os.path.splitext(file)
        with open(filepath, 'r', encoding='utf8') as f:
            readFile = f.read()
            spacyRead = nlp(readFile)
            myDataFrame = wordCollector(spacyRead, name)
            print(myDataFrame)

# %% [markdown]
# ## Write the dataframes to an output TSV file
# TSV means **tab-separated-values**. We'll use the tab character as a separator.
# The other popular alternative is the CSV: **comma-separated-values**, which uses the comma as a separator.
# You can use either one for our network data.
#
# I'm going to output some "node attributes" for tne network. In a network visualization, we'll want to be able to quickly distinguish the word nodes from the unit nodes (possibly by shape), and providing a qualifier or "node attribute" in the dataframe will be helpful.
# We can add other kinds of node attributes perhaps as numerical ranges (see below).

# %%
import pandas as pd

def wordCollector(words, unit):
    wordList = []
    nodeAtts = []
    unitList = []
    for token in words:
        if token.pos_ == "ADJ":
            wordList.append(token.lemma_)
            nodeAtts.append(token.pos_)
            unitList.append(unit)

    data = {
        'word': wordList,
        'nodeType': nodeAtts,
        'unit': unitList
    }
    df = pd.DataFrame(data)
    return df
    # This is returning a separate dataframe for every source text file. 

# We need to consolidate all the dataframes into one file. Collect all dataframes here!
allDataFrames = []

for file in os.listdir(collPath):
    if file.endswith(".txt"):
        filepath = f"{collPath}/{file}"
        name, extension = os.path.splitext(file)
        with open(filepath, 'r', encoding='utf8') as f:
            readFile = f.read()
            spacyRead = nlp(readFile)
            myDataFrame = wordCollector(spacyRead, name)
            # Add each individual dataframe as it comes out into the list of dataframes!
            allDataFrames.append(myDataFrame)

# Make an output filepath
outputFilePath = 'jojo-network-data.tsv'
# Turn the list of dataframes into one dataframe:
fullDataFrame = pd.concat(allDataFrames, ignore_index=True)
# print(fullDataFrame)

# Note, since Pandas knows how to open and write files line by line, we can skip that open() step we used last time.
fullDataFrame.to_csv(outputFilePath, sep='\t', index=False)
print('I just saved a dataframe as a TSV file.')
# Go check your filestash for the file.

# %% [markdown]
# Changed the outputFilePath

# %% [markdown]
# ### Something to try...
# * Try developing this to return synsets from WordNet.
# * Add an Ambiguity metric to count the number of synsets it belongs to.
# * Output this as a second "node attribute" qualifier to the Part of Speech. We could use that to color-code the words by ambiguity...

# %%
# This time, with Wordnet data!
import pandas as pd
import nltk
from nltk.corpus import wordnet as wn

def wordCollector(words, unit):
    wordList = []
    nodeAtts = []
    synsetCounts = []
    unitList = []
    for token in words:
        if token.pos_ == "ADJ":
            synsets = len(wn.synsets(token.lemma_))
            # We should be able to look up and count those synsets right here!          
            wordList.append(token.lemma_)
            nodeAtts.append(token.pos_)
            synsetCounts.append(synsets)
            unitList.append(unit)
                          
    data = {
        'word': wordList,
        'nodeType': nodeAtts,
        'synsetCount': synsetCounts,
        'unit': unitList
    }
    
    df = pd.DataFrame(data)
    # ebb: Let's simplify the TSV data: 
    # We want one line for each distinct word, and to COUNT the word occurrences in line with the other info on its synsets and unit. 
    # groupby helps with this in pandas:
    df = (df.groupby(['word', 'nodeType', 'synsetCount', 'unit'], as_index=False)
            .size()   # ebb: .size() will deliver the number of times a word is used in the file!
            .rename(columns={'size': 'count'})) # ebb: This gives you a new column for the count of the words in the file.
        # ebb: We can use that for the edge thickness: count of the times a word is used. Should simplify your network visualization!
    return df
    # This is returning a separate dataframe for every source text file. 

# We need to consolidate all the dataframes into one file. Collect all dataframes here!
allDataFrames = []

for file in os.listdir(collPath):
    if file.endswith(".txt"):
        filepath = f"{collPath}/{file}"
        name, extension = os.path.splitext(file)
        with open(filepath, 'r', encoding='utf8') as f:
            readFile = f.read()
            spacyRead = nlp(readFile)
            myDataFrame = wordCollector(spacyRead, name)
            # Add each individual dataframe as it comes out into the list of dataframes!
            allDataFrames.append(myDataFrame)

# Make an output filepath
outputFilePath = 'jojo-network-data.tsv'
# Turn the list of dataframes into one dataframe:
fullDataFrame = pd.concat(allDataFrames, ignore_index=True)

# Note, since Pandas knows how to open and write files line by line, we can skip that open() step we used last time.
fullDataFrame.to_csv(outputFilePath, sep='\t', index=False)
print('I just saved a NEW dataframe as a NEW TSV file.')
# Go check your filestash for the file.
# Out:
# I just saved a NEW dataframe as a NEW TSV file.

# %% [markdown]
# ## What will we do with this fancy TSV?
#
# We can analyze it as a **network** of data using network analysis. You could try importing your TSV into kumu.io, but we're going to introduce Cytoscape, which is a very powerful, artful method with lots of visualization options.
#
# To view the data we extracted in this notebook as an SVG export from Cytoscape, see <https://raw.githubusercontent.com/newtfire/textAnalysis-Hub/refs/heads/main/Class-Examples/Python/readFileCollections-examples/network-analysis-via-python/networkData-2.svg>

# %% [markdown]
# ## Your Turn!
# Adapt this notebook to explore one or more of your project files and prepare some network data of your own.
#
# * Output a CSV or TSV of data from your project for import into our network visualization software.
# * [Install Cytoscape](https://cytoscape.org/) on your computer and check to make sure it is working.
#      * Cytoscape now comes bundled with its own Java, so you should be good to go for running it (much like oXygen). If you have trouble, work through the [Troubleshooting](https://cytoscape.org/troubleshooting.html) guide first. Bring questions to class or via Canvas!
#      * After you install Cytoscape, see if you can also install the yFiles Layout Algorithms. Open Cytoscape, go to **Layout → Install yFiles**, which directs you to an App store to download it and apply it to Cytoscape.
