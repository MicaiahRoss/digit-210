# %% [markdown]
# # Reading File Directories and Exploring WordNet
#
# This notebook provides some guidance on working with file directories for a text corpus. It's also introducing some things we can explore with the WordNet dictionary accessible through NLTK.
#
# Read about [Wordnet in Chapter 2, section 5.2](https://www.nltk.org/book/ch02.html#wordnet) of the NLTK book. Wordnet is used in NLP to investigate different forms and senses of meaning that a word might possibly have: we can determine levels of potential ambiguity by working with it. Here's some [more introductory reading](https://mbrenndoerfer.com/writing/history-wordnet-semantic-network) about it.
#
# Credits: Some of our explanations are distilled from [David Birnbaum's introductory Wordnet notebook](https://github.com/djbpitt/wordnet/blob/master/Wordnet.ipynb) that we used to explore ambiguity of spooky words in previous student projects like:
# * This project on [H. P. Lovecraft](https://newtfire.org/eldritch/)
# * This project on Poe and Lovecraft's [Weird Fiction](https://mo-wright.github.io/weirdfiction/svg.html) from Spring 2025

# %%
# Imports
import os
import nltk
from nltk.corpus import wordnet as wn

# %%
# SMOKE TEST: Explore Wordnet for specific words.
wn.synsets('clear')
# Out:
# [Synset('clear.n.01'),
#  Synset('open.n.01'),
#  Synset('unclutter.v.01'),
#  Synset('clear.v.02'),
#  Synset('clear_up.v.04'),
#  Synset('authorize.v.01'),
#  Synset('clear.v.05'),
#  Synset('pass.v.09'),
#  Synset('clear.v.07'),
#  Synset('clear.v.08'),
#  Synset('clear.v.09'),
#  Synset('clear.v.10'),
#  Synset('clear.v.11'),
#  Synset('clear.v.12'),
#  Synset('net.v.02'),
#  Synset('net.v.01'),
#  Synset('gain.v.08'),
#  Synset('clear.v.16'),
#  Synset('clear.v.17'),
#  Synset('acquit.v.01'),
#  Synset('clear.v.19'),
#  Synset('clear.v.20'),
#  Synset('clear.v.21'),
#  Synset('clear.v.22'),
#  Synset('clear.v.23'),
#  Synset('clear.v.24'),
#  Synset('clear.a.01'),
#  Synset('clear.s.01'),
#  Synset('clear.s.02'),
#  Synset('clear.a.04'),
#  Synset('clear.s.03'),
#  Synset('clear.s.04'),
#  Synset('clean.s.02'),
#  Synset('clear.s.06'),
#  Synset('clear.s.07'),
#  Synset('well-defined.a.02'),
#  Synset('clear.a.11'),
#  Synset('clean.s.01'),
#  Synset('clear.s.09'),
#  Synset('clear.s.10'),
#  Synset('clear.s.11'),
#  Synset('absolved.s.01'),
#  Synset('clear.s.13'),
#  Synset('clear.r.01'),
#  Synset('clearly.r.04')]

# %% [markdown]
# ### Look at some synset data from WordNet
# Choose one of the synsets by its identifier, and lets explore what you can see with it.
# In the next couple of cells we explore how WordNet shares information:
#
# Wordnet shows:
# * A representative word that stands for set of meanings (a "synset"). There may be other representative words, and that same representative word might be used in different senses (and have multiple synsets).
# * A part of speech (POS) identifier, like “n” for ‘noun’ or “v” for ‘verb’.
# * A two-digit number that distinguishes different synsets that may have the same head word and the same POS, but that convey different meaning. For example, the synsets 'ghost.n.01' and 'ghost.n.02' are two different nominal meanings that can be expressed by the lexeme “ghost.”
#
# In WordNet you can request:
# * the available **lemmas** which mean "lexemes" or the available set of words associated with a particular synset.
# * the **definition** associated with a synset

# %%
wn.synset('acquit.v.01').lemmas()
# Out:
# [Lemma('acquit.v.01.acquit'),
#  Lemma('acquit.v.01.assoil'),
#  Lemma('acquit.v.01.clear'),
#  Lemma('acquit.v.01.discharge'),
#  Lemma('acquit.v.01.exonerate'),
#  Lemma('acquit.v.01.exculpate')]

# %%
# For every lem in one of the synsets, isolate just the names without the extra stuff:
for lem in wn.synset('acquit.v.01').lemmas():
    print(lem.name())
# Out:
# acquit
# assoil
# clear
# discharge
# exonerate
# exculpate

# %%
# Here we'll just return the count of the available lemmas for each synset for "clear"
# In this output we're just surveying the data as lists:
for synset in wn.synsets('clear'):
    print(synset, ": ", synset.lemma_names(), ": ", len(synset.lemma_names()))
# Out:
# Synset('clear.n.01') :  ['clear'] :  1
# Synset('open.n.01') :  ['open', 'clear'] :  2
# Synset('unclutter.v.01') :  ['unclutter', 'clear'] :  2
# Synset('clear.v.02') :  ['clear'] :  1
# Synset('clear_up.v.04') :  ['clear_up', 'clear', 'light_up', 'brighten'] :  4
# Synset('authorize.v.01') :  ['authorize', 'authorise', 'pass', 'clear'] :  4
# Synset('clear.v.05') :  ['clear'] :  1
# Synset('pass.v.09') :  ['pass', 'clear'] :  2
# Synset('clear.v.07') :  ['clear'] :  1
# Synset('clear.v.08') :  ['clear'] :  1
# Synset('clear.v.09') :  ['clear', 'top'] :  2
# Synset('clear.v.10') :  ['clear', 'clear_up', 'shed_light_on', 'crystallize', 'crystallise', 'crystalize', 'crystalise', 'straighten_out', 'sort_out', 'enlighten', 'illuminate', 'elucidate'] :  12
# Synset('clear.v.11') :  ['clear'] :  1
# Synset('clear.v.12') :  ['clear'] :  1
# Synset('net.v.02') :  ['net', 'clear'] :  2
# Synset('net.v.01') :  ['net', 'sack', 'sack_up', 'clear'] :  4
# Synset('gain.v.08') :  ['gain', 'take_in', 'clear', 'make', 'earn', 'realize', 'realise', 'pull_in', 'bring_in'] :  9
# Synset('clear.v.16') :  ['clear'] :  1
# Synset('clear.v.17') :  ['clear'] :  1
# Synset('acquit.v.01') :  ['acquit', 'assoil', 'clear', 'discharge', 'exonerate', 'exculpate'] :  6
# Synset('clear.v.19') :  ['clear', 'solve'] :  2
# Synset('clear.v.20') :  ['clear'] :  1
# Synset('clear.v.21') :  ['clear'] :  1
# Synset('clear.v.22') :  ['clear'] :  1
# Synset('clear.v.23') :  ['clear'] :  1
# Synset('clear.v.24') :  ['clear', 'clear_up'] :  2
# Synset('clear.a.01') :  ['clear'] :  1
# Synset('clear.s.01') :  ['clear'] :  1
# Synset('clear.s.02') :  ['clear', 'open'] :  2
# Synset('clear.a.04') :  ['clear'] :  1
# Synset('clear.s.03') :  ['clear'] :  1
# Synset('clear.s.04') :  ['clear'] :  1
# Synset('clean.s.02') :  ['clean', 'clear', 'light', 'unclouded'] :  4
# Synset('clear.s.06') :  ['clear', 'unmortgaged'] :  2
# Synset('clear.s.07') :  ['clear', 'clean-cut', 'clear-cut'] :  3
# Synset('well-defined.a.02') :  ['well-defined', 'clear'] :  2
# Synset('clear.a.11') :  ['clear'] :  1
# Synset('clean.s.01') :  ['clean', 'clear'] :  2
# Synset('clear.s.09') :  ['clear'] :  1
# Synset('clear.s.10') :  ['clear'] :  1
# Synset('clear.s.11') :  ['clear', 'decipherable', 'readable'] :  3
# Synset('absolved.s.01') :  ['absolved', 'clear', 'cleared', 'exculpated', 'exonerated', 'vindicated'] :  6
# Synset('clear.s.13') :  ['clear', 'percipient'] :  2
# Synset('clear.r.01') :  ['clear', 'all_the_way'] :  2
# Synset('clearly.r.04') :  ['clearly', 'clear'] :  2

# %%
# Ask for the definitions and part of speech available for a word lemma names in WordNet
for synset in wn.synsets('clear'):
    print(synset.lemma_names(), ": Part of Speech: ", synset.pos(), ": Definition: ", synset.definition())
# Out:
# ['clear'] : Part of Speech:  n : Definition:  the state of being free of suspicion
# ['open', 'clear'] : Part of Speech:  n : Definition:  a clear or unobstructed space or expanse of land or water
# ['unclutter', 'clear'] : Part of Speech:  v : Definition:  rid of obstructions
# ['clear'] : Part of Speech:  v : Definition:  make a way or path by removing objects
# ['clear_up', 'clear', 'light_up', 'brighten'] : Part of Speech:  v : Definition:  become clear
# ['authorize', 'authorise', 'pass', 'clear'] : Part of Speech:  v : Definition:  grant authorization or clearance for
# ['clear'] : Part of Speech:  v : Definition:  remove
# ['pass', 'clear'] : Part of Speech:  v : Definition:  go unchallenged; be approved
# ['clear'] : Part of Speech:  v : Definition:  be debited and credited to the proper bank accounts
# ['clear'] : Part of Speech:  v : Definition:  go away or disappear
# ['clear', 'top'] : Part of Speech:  v : Definition:  pass by, over, or under without making contact
# ['clear', 'clear_up', 'shed_light_on', 'crystallize', 'crystallise', 'crystalize', 'crystalise', 'straighten_out', 'sort_out', 'enlighten', 'illuminate', 'elucidate'] : Part of Speech:  v : Definition:  make free from confusion or ambiguity; make clear
# ['clear'] : Part of Speech:  v : Definition:  free from payment of customs duties, as of a shipment
# ['clear'] : Part of Speech:  v : Definition:  clear from impurities, blemishes, pollution, etc.
# ['net', 'clear'] : Part of Speech:  v : Definition:  yield as a net profit
# ['net', 'sack', 'sack_up', 'clear'] : Part of Speech:  v : Definition:  make as a net profit
# ['gain', 'take_in', 'clear', 'make', 'earn', 'realize', 'realise', 'pull_in', 'bring_in'] : Part of Speech:  v : Definition:  earn on some commercial or business transaction; earn as salary or wages
# ['clear'] : Part of Speech:  v : Definition:  sell
# ['clear'] : Part of Speech:  v : Definition:  pass an inspection or receive authorization
# ['acquit', 'assoil', 'clear', 'discharge', 'exonerate', 'exculpate'] : Part of Speech:  v : Definition:  pronounce not guilty of criminal charges
# ['clear', 'solve'] : Part of Speech:  v : Definition:  settle, as of a debt
# ['clear'] : Part of Speech:  v : Definition:  make clear, bright, light, or translucent
# ['clear'] : Part of Speech:  v : Definition:  rid of instructions or data
# ['clear'] : Part of Speech:  v : Definition:  remove (people) from a building
# ['clear'] : Part of Speech:  v : Definition:  remove the occupants of
# ['clear', 'clear_up'] : Part of Speech:  v : Definition:  free (the throat) by making a rasping sound
# ['clear'] : Part of Speech:  a : Definition:  readily apparent to the mind
# ['clear'] : Part of Speech:  s : Definition:  free from confusion or doubt
# ['clear', 'open'] : Part of Speech:  s : Definition:  affording free passage or view
# ['clear'] : Part of Speech:  a : Definition:  allowing light to pass through
# ['clear'] : Part of Speech:  s : Definition:  free from contact or proximity or connection
# ['clear'] : Part of Speech:  s : Definition:  characterized by freedom from troubling thoughts (especially guilt)
# ['clean', 'clear', 'light', 'unclouded'] : Part of Speech:  s : Definition:  (of sound or color) free from anything that dulls or dims
# ['clear', 'unmortgaged'] : Part of Speech:  s : Definition:  (especially of a title) free from any encumbrance or limitation that presents a question of fact or law
# ['clear', 'clean-cut', 'clear-cut'] : Part of Speech:  s : Definition:  clear and distinct to the senses; easily perceptible
# ['well-defined', 'clear'] : Part of Speech:  a : Definition:  accurately stated or described
# ['clear'] : Part of Speech:  a : Definition:  free from clouds or mist or haze
# ['clean', 'clear'] : Part of Speech:  s : Definition:  free of restrictions or qualifications
# ['clear'] : Part of Speech:  s : Definition:  free from flaw or blemish or impurity
# ['clear'] : Part of Speech:  s : Definition:  clear of charges or deductions
# ['clear', 'decipherable', 'readable'] : Part of Speech:  s : Definition:  easily deciphered
# ['absolved', 'clear', 'cleared', 'exculpated', 'exonerated', 'vindicated'] : Part of Speech:  s : Definition:  freed from any question of guilt
# ['clear', 'percipient'] : Part of Speech:  s : Definition:  characterized by ease and quickness in perceiving
# ['clear', 'all_the_way'] : Part of Speech:  r : Definition:  completely
# ['clearly', 'clear'] : Part of Speech:  r : Definition:  in an easily perceptible manner

# %% [markdown]
# ## Ambiguity from WordNet's point of view
# When words are ambiguous, they can multiple shades of meaning or different ways we could interpret them. How we decide on the meaning depends on the context of the words. WordNet can't tell you everything about how you could interpret every word in your project, but when words are available in its vast database, you can explore how many synsets (or possible meaningful interpretations) it has on file for that word. You can find which words depend the most on specific contexts for their meaning.
#
# To find out WordNet's sense of how ambiguous a word is, you could just count the number of available synsets for it with Python's **len()**.
# Note: when you want ALL the synsets, use **wn.synsets** (plural)

# %%
jojo_words = ['stand', 'power', 'dio', 'fight', 'kill', 'time', 'world', 'giorno']
for w in jojo_words:
    synsets = len(wn.synsets(w))
    print("The word ", w, "belongs to ", synsets, "synsets in WordNet.")
# Out:
# The word  stand belongs to  24 synsets in WordNet.
# The word  power belongs to  10 synsets in WordNet.
# The word  dio belongs to  0 synsets in WordNet.
# The word  fight belongs to  9 synsets in WordNet.
# The word  kill belongs to  17 synsets in WordNet.
# The word  time belongs to  15 synsets in WordNet.
# The word  world belongs to  9 synsets in WordNet.
# The word  giorno belongs to  0 synsets in WordNet.

# %% [markdown]
# Changed ```spooky_words``` to ```jojo_words```
#
# I also changed the words to ones that are more meaningful in the texts.

# %% [markdown]
# ### WordNet's morphy: for inflected forms like plural vs. singular
# Wordnet won't have an entry for plural forms of words (for example). For other things like -ing words, those tend to have their own WordNet entry.
#
# When working with project data, **run your word tokens through Wordnet's morphy in case they need to be looked up in a lemmatized form**
# `wn.morphy('ghosts')`. Try it out on various word forms:

# %%
wn.morphy('cries')
# Out:
# 'cry'

# %% [markdown]
# ### A Workflow for projects exploring ambiguity
# * Start by isolating a set of words of interest from your project. (One idea: Use nltk's pos tagger to identify all the verbs in your files and retrieve a set of them).
# * Deliver them to WordNet to retrieve their synset counts
# * Output the information on each distinct word from Python to a simple XML, TSV, or JSON (We'll probably use XML)
# * Options:
#     * Use the frequency distribution plotting in Python to see how frequently ambiguous words are used in your corpus (plotting is a bit limited)
#     * Write XSLT to map that information back into your XML files: We can use this to **instantiate** the uses of ambiguous words: retrieve counts of how frequently they appear in the text, and plot with SVGs of your own design. (You could make an SVG representing info about the most ambiguous words. You could also make specific SVGs for ambiguous words of interest to show how they're distributed throughout your texts... what would be interesting to visualize?

# %% [markdown]
# ## Part of Speech (and other related kinds of) Tagging
# NLTK (and spacY and other language models) offer Part of Speech tagging. We could use this to collect sets of distinct verbs, nouns, adjectives.
# * We could learn more about the words in a set by sending them to WordNet.
# * We could also look at words as a network: How often do specific characters rely on a word of interest? Which characters share a word of interest? Or which words of interest are shared by say, male vs. female characters?  (Here's [a student project](http://bamfs.obdurodon.org/allFilms_Results.xhtml) that explored a collection of colorful swear words used by characters in Quentin Tarantino's films.)
#
# In our Text Analysis class, you didn't spend time marking specific words, but you could do that using regex search and replace over your texts. But you could also get some help from POS tagging from NLTK, and mapping that information back to your XML files for further analysis. So let's explore that.  We'll look at POS (part of speech) tagging, but note that it's related to Named Entity Recognition and sentiment analysis.
#
# (Full disclosure: We like POS for reasons of interesting patterns it can display without overdetermining what the data means in context. You can show interesting patterns, especially by working with POS tagging together with WordNet analyses.)

# %% [markdown]
# ## How to get NLTK to do POS tagging
# * Let's open a file, tokenize it, prepare it for nltk to analyze.
# * Then apply the .pos tagger
# * What we see in the output is a list of tuples

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag

filepath = 'jojo/04x36_-_Diavolo_Surfaces.txt'
f = open(filepath, 'r', encoding='utf8').read()
# Make a list of tokens in your text. 
# tokenList = f.split()
tokenList = word_tokenize(f)
# How is NLTK's word_tokenize() different from just splitting on spaces? Here's an example of how it's different: 
# Look for "don't" in the output of this cell and see how it's split.
print(tokenList)
# Out:
# ['Bruno', ':', 'So', 'there', 'you', 'are', '...', 'Boss', '...', 'Bruno', ':', 'That', "'s", 'where', '...', 'you', 'were', '...', 'Bruno', ':', 'And', 'that', "'s", '...', 'whose', 'body', 'you', "'re", 'using', '.', 'Bruno', ':', 'The', 'moment', 'I', 'got', 'tired', 'and', 'could', 'feel', 'my', 'soul', 'being', 'sucked', 'out', ',', 'Bruno', ':', 'you', 'said', 'you', 'had', 'to', 'go', 'because', 'things', 'were', 'going', 'south', '...', 'Bruno', ':', 'It', "'s", 'true', '...', 'JoJo-main', ':', ',', 'If', 'you', "'re", 'there', ',', 'Boss', '...', 'JoJo-main', ':', ',', 'We', "'re", 'going', 'to', 'win', 'for', 'sure', '...', 'Bruno', ':', 'But', '...', 'Dopp', ':', 'I', "'m", 'so', 'lonely', '...', 'Dopp', ':', 'Could', 'you', '...', 'call', 'me', 'again', '...', 'JoJo-main', ':', ',', 'like', 'you', 'always', 'have', '?', 'Dopp', ':', 'Boss', '...', 'No_one_can_escap', ',', 'Op', 'subs', ':', 'No', 'one', 'can', 'escape', 'the', 'fate', 'that', 'was', 'chosen', 'for', 'them', '.', 'No_one_can_escap', ',', 'Op', 'subs', ':', 'All', 'that', 'remains', 'is', 'the', 'end', ',', 'where', 'you', 'will', 'all', 'perish', '.', 'No_one_can_escap', ',', 'Op', 'subs', ':', 'Eternal', 'greatness', 'exists', 'only', 'within', 'myself', '.', 'No_one_can_escap', ',', 'Op', 'subs', ':', 'Sing', 'a', 'song', 'of', 'sorrow', 'in', 'a', 'world', 'where', 'time', 'has', 'vanished', '.', 'JoJo-EpTitle', ',', 'Sign', ':', 'Episodio', 'Diavolo', 'Surfaces', 'Turtle', ':', 'Mista', '!', 'Hurry', 'up', 'and', 'pierce', 'your', 'Stand', 'with', 'this', 'arrow', '!', 'Mista', ':', 'What', "'s", 'going', 'on', '?', 'Requiem', "'s", 'suddenly', 'heading', 'toward', 'us', '.', 'Dia', ':', 'Giorno', '!', 'Stop', 'Requiem', '!', 'Gio', ':', 'I', 'ca', "n't", '!', 'It', "'s", 'too', 'far', 'away', '!', 'Crunch', ',', 'Sfx', ':', '{', '\\c', '&', 'HCCF', '&', '\\c', '&', 'HB', '&', '}', 'Crack', 'Trish', ':', 'Wha', '—', 'Trish', ':', 'My', 'g', '*', 'n', '...', 'Dia', ':', 'What', 'are', 'you', 'doing', ',', 'Mista', '?', '!', 'Mista', ':', 'It', "'s", 'because', 'you', "'re", 'touching', 'the', 'arrow', '!', 'Trish', ':', 'No', 'way', '!', 'Why', 'is', 'this', '...', 'Gio', ':', 'Let', 'go', 'of', 'it', ',', 'Mr.', 'Polnareff', '!', 'Gio', ':', 'Let', 'go', 'of', 'the', 'arrow', '!', 'Trish', ':', 'Glad', 'I', 'took', 'that', 'cop', "'s", 'Beretta', 'just', 'in', 'case', '.', 'Trish', ':', 'But', 'what', 'the', 'hell', ',', 'b', '*', 'll', '*', 'ts', '?', 'Trish', ':', 'Why', "'d", 'my', 'revolver', 'break', 'all', 'of', 'a', 'sudden', '?', 'Five', ':', 'M-Maybe', 'the', 'boss', 'got', 'close', '?', 'B', '*', 'llet', ':', 'You', 'dumbass', '!', 'Think', 'before', 'you', 'talk', ',', 'Number', 'Five', '!', 'B', '*', 'llet', ':', 'Are', 'you', 'saying', 'you', 'saw', 'someone', 'coming', 'close', 'to', 'us', 'in', 'this', 'big', ',', 'open', 'space', '?', 'B', '*', 'llet', ':', 'We', 'did', "n't", 'see', 'anyone', 'at', 'the', 'moment', 'the', 'revolver', 'broke', '.', 'B', '*', 'llet', ':', 'It', "'s", 'metal', 'fatigue', '.', 'JoJo-main', ':', ',', 'It', "'s", 'because', 'he', "'s", 'been', 'overusing', 'the', 'g', '*', 'n.', 'B', '*', 'llet', ':', 'The', 'axis', 'of', 'the', 'cylinder', 'broke', '.', 'B', '*', 'llet', ':', 'We', 'have', "n't", 'had', 'a', 'chance', 'to', 'doany', 'maintenance', 'or', 'inspections', '!', 'B', '*', 'llet', ':', 'H-Hey', '!', 'Trish', ':', 'What', 'the', 'hell', 'is', 'this', 'thing', "'s", 'problem', '?', 'It', "'s", 'heading', 'toward', 'm-me', '!', 'Turtle', ':', 'No', ',', 'Mista', '.', 'It', "'s", 'heading', 'towards', 'me', '.', 'Turtle', ':', 'Even', 'though', 'it', 'has', 'the', 'arrow', 'back', '...', 'Gio', ':', 'Golden', 'Wind', '!', 'Crunch', ',', 'Sfx', ':', '{', '\\c', '&', 'HCBBC', '&', '\\c', '&', 'HEB', '&', '}', 'Batoom', 'Turtle', ':', 'Requiem', 'intends', 'to', 'finish', 'me', 'because', 'I', 'touched', 'the', 'arrow', '.', 'Gio', ':', 'Mista', ',', 'run', '!', 'Mista', ':', 'Reload', ',', 'b', ' ...

# %%
# Reduce the complexity by: 1) lowercasing them, and 2) returning the set() of words (remove multiple of the same value)
lowercaseTokens = [token.lower() for token in tokenList]
uniqueTokens = set(lowercaseTokens)
print(uniqueTokens)
# Out:
# {'n', 'blast', 'did', 'saw', 'detect', 'dopp', 'creatures', 'looks', 'take', 'differently', 'else', 'hiding', 'all', 'flew', 'square', 'beyond', 'limbs', 'big', 'play', 'lost', 'jojo-internal/narrator', 'of', '{', 'sure', 'h', 'op', 'jojo-main', 'out', 'took', 'dia', 'get', 'lling', 'space', 'hccf', 'narancia', 'moving', 'luck', 'before', 'hcbbc', 'lady', 'definitively', 'llet', 'their', 'farther', 'call', 'or', 'n.', 'fatigue', 'revealed', 'perish', 'inspections', 'towards', 'heading', 'clear', 'shoot', 'figured', 'almost', '.-billion-year', 'head', 'change', 'return', 'appear', '}', 'chance', 'six', 'beings', 'sweat', 'eternal', 'first', 'new', 'surpass', 'have', 'own', 'ability', 'intends', 'sudden', 'ca', 'damn', 'brief', 'through', 'golden', 'doing', 'is', 'stop', 'swapped', 'understand', 'itself', 'confirming', "'d", 'bucciarati', 'stopped', 'course', 'close', 'blow', 'thing', 'giovanna', 'actually', 'still', '!', 'thrown', 'sign', 'colosseum', 'at', 'team', 'sun', 'wasting', 'number', 'back', 'stretching', 'live', 'disappear', 'overusing', 'wind', 'o-oh', 'doany', 'viewer', 'rushing', 'hey', 'part', 'gum', 'currently', 'certain', 'well', 'unless', 'organization', 'both', 'heb', 'everyone', 'manifest', '\\an\\pos', 'surfaces', 'are', 'ended', 'touch', 'predicting', 'immense', 'movements', 'bruno', 'jojo-eptitle', 'five', 'any', 'tore', 'has', 'find', 'to', 'hcffb', 'betray', 'i-i', 'ones', 'something', 'used', 'wo', 'ever', 'starting', 'gets', 'diagram', 'closer', 'past', 'few', 'opposite', 'coming', 'they', 'front', 'greatness', 'whose', 'which', 'civilian', 'hfd', 'beretta', 'yeah', 'frightening', 'sec', 'control', 'by', 'away', 'was', 'for', 'swap', 'prelude', 'need', 'him', 'spread', 'ago', 'g', 'vanished', 'far', 'let', 'souls', 'where', 'realizing', 'vacant', 'cornered', 'fine', 'hurry', 'you', 'h-hey', 'mind', 'sfx', 'touching', 'instead', 'hours', 'toward', 'right', 'if', 'meters', 'sucked', 'eliminated', 'one', 'really', 'personalities', 'were', 'only', 'possible', 'waiting', 'i-it', 'case', 'complete', 'predicts', 'be', ':', 'stay', 'boss', 'important', '\\c', 'll', 'places', '...', 'bring', 'due', 'somewhere', 'things', 'unparalleled', 'doppio', 'b', 'disappearing', 'finish', 'arrow', 'glad', 'moves', 'zipper', 'fate', 'instantly', 'matter', 'blood', 'my', 'myself', 'how', 'hd', 'polnareff', 'from', 'shut', 'fit', 'flying', 'wha', 'catch', 'closest', 'mean', 'blessing', 'droplets', 'put', 'like', 'deflect', 'what', 'this', 'elastic', 'different', 'touched', 'us', 'crimson', 'throw', 'makes', 'piece', 'would', 'died', "n't", 'granted', 'two', 'never', 'there', 'episodio', 'motive', 'broken', 'on', '—', 'win', 'attacking', 'been', 'then', 'yourselves', 'over', 'appeared', 'thanks', 'possessing', 'shall', 'inhabited', 'definitely', 'location', 'an', 'reason', 'passed', 'so', 'your', 'might', 'leap', 'being', 'tired', '(', 'gone', 'admit', 'said', 'though', 'getting', 'finished', 'figure', 'remember', 'means', 'sing', 'reload', 'around', 'see', 'also', 'attacked', 'slice', 'hb', 'someone', 'it', 'happened', 'become', 'cop', 'm-maybe', 'obtain', 'stuck', 'm-me', 'not', 'danger', 'barely', 'gave', 'plus', 'run', 'history', 'situation', 'its', 'surely', 'dodge', 'keeps', 'mass', 'b-but', 'despite', 'within', 'cartridge', 'throwing', 'many', 'brace', 'daughter', 'however', 'exactly', 'rookie', 'who_swapped_with', 'guess', 'know', '?', 'moment', 'possessed', 'chosen', 'slowly', 'fired', 'seems', 'smell', 'depending', 'destroy', 'matching', 'expectations', 'move', 'stretched', 'able', 'mine', 'end', 'got', 'song', 'dying', ')', 'mention', 'tear', 'weak', '.', 'he', 'good', 'underling', 'me', 'his', 'lled', 'revolver', 'sense', 'land', 'truly', '*', 'body', ',', 'grovel', 'had', 'lonely', 'life', 'avoid', 'should', "'m", 'answer', 'conscious', 'using', 'fully', 'trying', 't.', 'predicted', 'okay', 'mista', 'sorrow', 'trish', 'grab', 'south', 'angered', 'exists', 'range', 'correct', 'air', 'attack', 'wh-what', 'losing', ' ...

# %%
# Let's try out the NLTK POS tagger on the uniqueTokens
pos_tag(uniqueTokens)
# Out:
# [('n', 'JJ'),
#  ('blast', 'NN'),
#  ('did', 'VBD'),
#  ('saw', 'NN'),
#  ('detect', 'NN'),
#  ('dopp', 'NN'),
#  ('creatures', 'VBZ'),
#  ('looks', 'NNS'),
#  ('take', 'VBP'),
#  ('differently', 'RB'),
#  ('else', 'RB'),
#  ('hiding', 'VBG'),
#  ('all', 'DT'),
#  ('flew', 'NNS'),
#  ('square', 'VBP'),
#  ('beyond', 'IN'),
#  ('limbs', 'NNS'),
#  ('big', 'JJ'),
#  ('play', 'NN'),
#  ('lost', 'VBD'),
#  ('jojo-internal/narrator', 'NN'),
#  ('of', 'IN'),
#  ('{', '('),
#  ('sure', 'JJ'),
#  ('h', 'NN'),
#  ('op', 'IN'),
#  ('jojo-main', 'NN'),
#  ('out', 'IN'),
#  ('took', 'VBD'),
#  ('dia', 'NN'),
#  ('get', 'NN'),
#  ('lling', 'VBG'),
#  ('space', 'NN'),
#  ('hccf', 'NN'),
#  ('narancia', 'IN'),
#  ('moving', 'VBG'),
#  ('luck', 'NN'),
#  ('before', 'IN'),
#  ('hcbbc', 'JJ'),
#  ('lady', 'NN'),
#  ('definitively', 'RB'),
#  ('llet', 'VBD'),
#  ('their', 'PRP$'),
#  ('farther', 'NN'),
#  ('call', 'NN'),
#  ('or', 'CC'),
#  ('n.', 'JJ'),
#  ('fatigue', 'NN'),
#  ('revealed', 'VBD'),
#  ('perish', 'JJ'),
#  ('inspections', 'NNS'),
#  ('towards', 'NNS'),
#  ('heading', 'VBG'),
#  ('clear', 'JJ'),
#  ('shoot', 'NN'),
#  ('figured', 'VBD'),
#  ('almost', 'RB'),
#  ('.-billion-year', 'JJ'),
#  ('head', 'NN'),
#  ('change', 'NN'),
#  ('return', 'NN'),
#  ('appear', 'VBP'),
#  ('}', ')'),
#  ('chance', 'NN'),
#  ('six', 'CD'),
#  ('beings', 'NNS'),
#  ('sweat', 'VBP'),
#  ('eternal', 'JJ'),
#  ('first', 'JJ'),
#  ('new', 'JJ'),
#  ('surpass', 'NN'),
#  ('have', 'VBP'),
#  ('own', 'VBN'),
#  ('ability', 'NN'),
#  ('intends', 'VBZ'),
#  ('sudden', 'JJ'),
#  ('ca', 'MD'),
#  ('damn', 'VB'),
#  ('brief', 'JJ'),
#  ('through', 'IN'),
#  ('golden', 'JJ'),
#  ('doing', 'VBG'),
#  ('is', 'VBZ'),
#  ('stop', 'VBN'),
#  ('swapped', 'NN'),
#  ('understand', 'VB'),
#  ('itself', 'PRP'),
#  ('confirming', 'VBG'),
#  ("'d", 'MD'),
#  ('bucciarati', 'VB'),
#  ('stopped', 'VBD'),
#  ('course', 'NN'),
#  ('close', 'RB'),
#  ('blow', 'JJ'),
#  ('thing', 'NN'),
#  ('giovanna', 'NN'),
#  ('actually', 'RB'),
#  ('still', 'RB'),
#  ('!', '.'),
#  ('thrown', 'JJ'),
#  ('sign', 'NN'),
#  ('colosseum', 'NN'),
#  ('at', 'IN'),
#  ('team', 'NN'),
#  ('sun', 'NN'),
#  ('wasting', 'VBG'),
#  ('number', 'NN'),
#  ('back', 'RB'),
#  ('stretching', 'VBG'),
#  ('live', 'JJ'),
#  ('disappear', 'NN'),
#  ('overusing', 'VBG'),
#  ('wind', 'IN'),
#  ('o-oh', 'JJ'),
#  ('doany', 'NN'),
#  ('viewer', 'NN'),
#  ('rushing', 'VBG'),
#  ('hey', 'JJ'),
#  ('part', 'NN'),
#  ('gum', 'NN'),
#  ('currently', 'RB'),
#  ('certain', 'JJ'),
#  ('well', 'RB'),
#  ('unless', 'IN'),
#  ('organization', 'NN'),
#  ('both', 'DT'),
#  ('heb', 'VBP'),
#  ('everyone', 'NN'),
#  ('manifest', 'JJS'),
#  ('\\an\\pos', 'NN'),
#  ('surfaces', 'NNS'),
#  ('are', 'VBP'),
#  ('ended', 'VBN'),
#  ('touch', 'RB'),
#  ('predicting', 'VBG'),
#  ('immense', 'JJ'),
#  ('movements', 'NNS'),
#  ('bruno', 'IN'),
#  ('jojo-eptitle', 'JJ'),
#  ('five', 'CD'),
#  ('any', 'DT'),
#  ('tore', 'NN'),
#  ('has', 'VBZ'),
#  ('find', 'VBN'),
#  ('to', 'TO'),
#  ('hcffb', 'VB'),
#  ('betray', 'JJ'),
#  ('i-i', 'JJ'),
#  ('ones', 'NNS'),
#  ('something', 'NN'),
#  ('used', 'VBN'),
#  ('wo', 'MD'),
#  ('ever', 'RB'),
#  ('starting', 'VBG'),
#  ('gets', 'VBZ'),
#  ('diagram', 'RB'),
#  ('closer', 'RBR'),
#  ('past', 'JJ'),
#  ('few', 'JJ'),
#  ('opposite', 'NNS'),
#  ('coming', 'VBG'),
#  ('they', 'PRP'),
#  ('front', 'JJ'),
#  ('greatness', 'NN'),
#  ('whose', 'WP$'),
#  ('which', 'WDT'),
#  ('civilian', 'JJ'),
#  ('hfd', 'NN'),
#  ('beretta', 'NN'),
#  ('yeah', 'NN'),
#  ('frightening', 'VBG'),
#  ('sec', 'NNS'),
#  ('control', 'NN'),
#  ('by', 'IN'),
#  ('away', 'NN'),
#  ('was', 'VBD'),
#  ('for', 'IN'),
#  ('swap', 'NN'),
#  ('prelude', 'VBP'),
#  ('need', 'VBP'),
#  ('him', 'PRP'),
#  ('spread', 'VB'),
#  ('ago', 'RB'),
#  ('g', 'NN'),
#  ('vanished', 'VBD'),
#  ('far', 'RB'),
#  ('let', 'JJ'),
#  ('souls', 'NNS'),
#  ('where', 'WRB'),
#  ('realizing', 'VBG'),
#  ('vacant', 'NN'),
#  ('cornered', 'VBD'),
#  ('fine', 'JJ'),
#  ('hurry', 'NN'),
#  ('you', 'PRP'),
#  ('h-hey', 'VBP'),
#  ('mind', 'JJ'),
#  ('sfx', 'JJ'),
#  ('touching', 'VBG'),
#  ('instead', 'RB'),
#  ('hours', 'NNS'),
#  ('toward', 'IN'),
#  ('right', 'JJ'),
#  ('if', 'IN'),
#  ('meters', 'NNS'),
#  ('sucked', 'VBD'),
#  ('eliminated', 'JJ'),
#  ('one', 'CD'),
#  ('really', 'RB'),
#  ('personalities', 'NNS'),
#  ('were', 'VBD'),
#  ('only', 'RB'),
#  ('possible', 'JJ'),
#  ('waiting', 'VBG'),
#  ('i-it', 'JJ'),
#  ('case', 'NN'),
#  ('complete', 'JJ'),
#  ('predicts', 'NNS'),
#  ('be', 'VB'),
#  (':', ':'),
#  ('stay', 'VB'),
#  ('boss', 'IN'),
#  ('important', 'JJ'),
#  ('\\c', 'NNP'),
#  ('ll', 'NN'),
#  ('places', 'NNS'),
#  ('...', ':'),
#  ('bring', 'NN'),
#  ('due', 'JJ'),
#  ('somewhere', 'RB'),
#  ('things', 'NNS'),
#  ('unparalleled', 'VBD'),
#  ('doppio', 'NN'),
#  ('b', 'NN'),
#  ('disappearing', 'VBG'),
#  ('finish', 'JJ'),
#  ('arrow', 'NN'),
#  ('glad', 'NN'),
#  ('moves', 'VBZ'),
#  ('zipper', 'JJR'),
#  ('fate', 'NN'),
#  ('instantly', 'RB'),
#  ('matter', 'RB'),
#  ('blood', 'NN'),
#  ('my', 'PRP$'),
#  ('myself', 'PRP'),
#  ('how', 'WRB'),
#  ('hd', 'JJ'),
#  ('polnareff', 'NN'),
#  ('from', 'IN'),
#  ('shut', 'JJ'),
#  ('fit', 'JJ'),
#  ('flying', 'VBG'),
#  ('wha', 'JJ'),
#  ('catch', 'NN'),
#  ('closest', 'JJS'),
#  ('mean', 'JJ'),
#  ('blessing', 'VBG'),
#  ('droplets', 'NNS'),
#  ('put', 'VBP'),
#  ('like', 'IN'),
#  ('deflect', 'NN'),
#  ('what', 'WP'),
#  ('this', 'DT'),
#  ('elastic', 'JJ'),
#  ('different', 'JJ'),
#  ('touched', 'VBD'),
#  ('us', 'PRP'),
#  ('crimson', 'JJ'),
#  ('throw', 'NN'),
#  ('makes', 'VBZ'),
#  ('piece', 'RB'),
#  ('would', 'MD'),
#  ('died', 'VB'),
#  ("n't", 'RB'),
#  ('granted', 'VBN'),
#  ('two', 'CD'),
#  ('never', 'RB'),
#  ('there', 'EX'),
#  ('episodio', 'JJ'),
#  ('motive', 'NN'),
#  ('broken', 'VBN'),
#  ('on', 'IN'),
#  ('—', 'NNP'),
#  ('win', 'VBP'),
#  ('attacking', 'VBG'),
#  ('been', 'VBN'),
#  ('then', 'RB'),
#  ('yourselves', 'VBZ'),
#  ('over', 'RP'),
#  ('appeared', 'JJ'),
#  ('thanks', 'NNS'),
#  ('possessing', 'VBG'),
#  ('shall', 'MD'),
#  ('inhabited', 'VBN'),
#  ('definitely', 'RB'),
#  ('location', 'NN'),
#  ('an', 'DT'),
#  ('reason', 'NN'),
#  ('passed', 'VBD'),
#  ('so', 'RB'),
#  ('your', 'PRP$'),
#  ('might', 'MD'),
#  ('leap', 'VB'),
#  ('being', 'VBG'),
#  ('tired', 'VBN'),
#  ('(', '('),
#  ('gone', 'VBN'),
#  ('admit', 'NN'),
#  ('said', 'VBD'),
#  ('though', 'IN'),
#  ('getting', 'VBG'),
#  ('finished', 'VBN'),
#  ('figure', 'NN'),
#  ('remember', 'NN'),
#  ('means', 'VBZ'),
#  ('sing', 'VBG'),
#  ('reload', 'NN'),
#  ('around', 'IN'),
#  ('see', 'NN'),
#  ('also', 'RB'),
#  ('attacked', 'VBD'),
#  ('slice', 'NN'),
#  ('hb', 'NN'),
#  ('someone', 'NN'),
#  ('it', 'PRP'),
#  ('happened', 'VBD'),
#  ('become', 'JJ'),
#  ('cop', 'JJ'),
#  ('m-maybe', 'JJ'),
#  ('obtain', 'VB'),
#  ('stuck', 'JJ'),
#  ('m-me', 'JJ'),
#  ('not', 'RB'),
#  ('danger', 'RBR'),
#  ('barely', 'RB'),
#  ('gave', 'VBD'),
#  ('plus', 'CC'),
#  ('run', 'JJ'),
#  ('history', 'NN'),
#  ('situation', 'NN'),
#  ('its', 'PRP$'),
#  ('surely', 'RB'),
#  ('dodge', 'JJ'),
#  ('keeps', 'NNS'),
#  ('mass', 'VBP'),
#  ('b-but', 'JJ'),
#  ('despite', 'IN'),
#  ('within', 'IN'),
#  ('cartridge', 'NN'),
#  ('throwing', 'VBG'),
#  ('many', 'JJ'),
#  ('brace', 'NN'),
#  ('daughter', 'NN'),
#  ('however', 'RB'),
#  ('exactly', 'RB'),
#  ('rookie', 'VBP'),
#  ('who_swapped_with', 'JJ'),
#  ('guess', 'NN'),
#  ('know', 'VB'),
#  ('?', '.'),
#  ('moment', 'NN'),
#  ('possessed', 'VBD'),
#  ('chosen', 'VBN'),
#  ('slowly', 'RB'),
#  ('fired', 'VBN'),
#  ('seems', 'VBZ'),
#  ('smell', 'VBP'),
#  ('depending', 'VBG'),
#  ('destroy', 'NN'),
#  ('matching', 'VBG'),
#  ('expectations', 'NNS'),
#  ('move', 'VBP'),
#  ('stretched', 'VBN'),
#  ('able', 'JJ'),
#  ('mine', 'JJ'),
#  ('end', 'NN'),
#  ('got', 'VBD'),
#  ('song', 'JJ'),
#  ('dying', 'VBG'),
#  (')', ')'),
#  ('mention', 'NN'),
#  ('tear', 'JJ'),
#  ('weak', 'JJ'),
#  ('.', '.'),
#  ('he', 'PRP'),
#  ('good', 'JJ'),
#  ('underling', 'VBG'),
#  ('me', 'PRP'),
#  ('his', 'PRP$'),
#  ('lled', 'VBD'),
#  ('revolver', 'NN'),
#  ('sense', 'NN'),
#  ('land', 'NN'),
#  ('truly', 'RB'),
#  ('*', 'NNP'),
#  ('body', 'NN'),
#  (',', ','),
#  ('grovel', 'NN'),
#  ('had', 'VBD'),
#  ('lonely', 'JJ'),
#  ('life', 'NN'),
#  ('avoid', 'NN'),
#  ('should', 'MD'),
#  ("'m", 'VBP'),
#  ('answer', 'VB'),
#  ('conscious', 'JJ'),
#  ('using', 'VBG'),
#  ('fully', 'RB'),
#  ('trying', 'VBG'),
#  ('t.', 'NN'),
#  ('predicted', 'VBD'),
#  ('okay', 'JJ'),
#  ('mista', 'NN'),
#  ('sorrow', 'NN'),
#  ('trish', 'JJ'),
#  ('grab', 'NN'),
#  ('south', 'NN'),
#  ('angered', 'VBD'),
#  ('exists', 'NNS'),
#  ('range', 'VBP'),
#  ('correct', 'JJ'),
#  ('air', 'NN'),
#  ('attack', 'IN'),
#  ('wh-what', 'WP'),
#  ('losing', 'VBG'),
#  ('yes', 'NNS'),
#  ('use', 'VBP'),
#  ('secrets', 'NNS'),
#  ('left', 'VBD'),
#  ('that', 'IN'),
#  ('increase', 'NN'),
#  ('chewing', 'VBG'),
#  ('aware', 'JJ'),
#  ('shooting', 'VBG'),
#  ('total', 'JJ'),
#  ('particles', 'NNS'),
#  ('pain', 'VBP'),
#  ('anyone', 'NN'),
#  ('trash', 'NN'),
#  ('off', 'IN'),
#  ('loose', 'JJ'),
#  ('but', 'CC'),
#  ('problem', 'NN'),
#  ('start', 'NN'),
#  ('figuring', 'VBG'),
#  ('brought', 'NN'),
#  ('could', 'MD'),
#  ('oh', 'VB'),
#  ('hand', 'NN'),
#  ('nor', 'CC'),
#  ('them', 'PRP'),
#  ('meaning', 'VBG'),
#  ('dumbass', 'NN'),
#  ('born', 'VBN'),
#  ('method', 'NN'),
#  ('yourself', 'PRP'),
#  ('even', 'RB'),
#  ('a', 'DT'),
#  ('heads', 'NNS'),
#  ('axis', 'RB'),
#  ('just', 'RB'),
#  ('whether', 'IN'),
#  ('made', 'VBN'),
#  ('hesitate', 'NN'),
#  ('will', 'MD'),
#  ('no', 'DT'),
#  ('soul', 'JJ'),
#  ('wait', 'NN'),
#  ('does', 'VBZ'),
#  ('least', 'RBS'),
#  ('behind', 'IN'),
#  ('stand', 'JJ'),
#  ('make', 'VBP'),
#  ('light', 'NN'),
#  ('more', 'JJR'),
#  ('batoom', 'NN'),
#  ('actual', 'JJ'),
#  ('up', 'RB'),
#  ('force', 'NN'),
#  ('metal', 'NN'),
#  ('king', 'VBG'),
#  ("'ll", 'MD'),
#  ('advantage', 'VB'),
#  ('inhabiting', 'VBG'),
#  ('feel', 'VB'),
#  ('quietly', 'RB'),
#  ('shots', 'JJ'),
#  ('world', 'NN'),
#  ('too', 'RB'),
#  ('always', 'RB'),
#  ('another', 'DT'),
#  ('trajectory', 'NN'),
#  ('each', 'DT'),
#  ('imminent', 'JJ'),
#  ('fear', 'NN'),
#  ('again', 'RB'),
#  ('must', 'MD'),
#  ("'re", 'VBP'),
#  ('because', 'IN'),
#  ('shadow', 'JJ'),
#  ('rid', 'JJ'),
#  ('becoming', 'VBG'),
#  ('keep', 'JJ'),
#  ('h-he', 'JJ'),
#  ('travel', 'NN'),
#  ('true', 'JJ'),
#  ('think', 'NN'),
#  ('cylinder', 'NN'),
#  ('either', 'DT'),
#  ('priority', 'NN'),
#  ('genuinely', 'RB'),
#  ('hell', 'VB'),
#  ('na', 'TO'),
#  ('basically', 'RB'),
#  ('feet', 'NNS'),
#  ('ease', 'VBP'),
#  ('dreamed', 'VBN'),
#  ('climb', 'NN'),
#  ('crimsonhad', 'VBD'),
#  ('break', 'JJ'),
#  ('gon', 'NN'),
#  ('remains', 'VBZ'),
#  ('defeat', 'NN'),
#  ('after', 'IN'),
#  ('returned', 'VBN'),
#  ('tell', 'NN'),
#  ('broke', 'VBD'),
#  ('giorno', 'JJ'),
#  ('very', 'RB'),
#  ('in', 'IN'),
#  ('destroyed', 'JJ'),
#  ('ants', 'NNS'),
#  ('foolish', 'JJ'),
#  ('firstso', 'RB'),
#  ('now', 'RB'),
#  ('apart', 'RB'),
#  ('arm', 'NN'),
#  ('going', 'VBG'),
#  ('power', 'NN'),
#  ('confirm', 'NN'),
#  ('happen', 'VB'),
#  ('crunch', 'NN'),
#  ('saying', 'VBG'),
#  ('farthest', 'JJS'),
#  ('k', 'NN'),
#  ('second', 'JJ'),
#  ('time', 'NN'),
#  ('happening', 'VBG'),
#  ('hef', 'JJ'),
#  ('match', 'NN'),
#  ('staying', 'VBG'),
#  ('do', 'VBP'),
#  ('with', 'IN'),
#  ('knock', 'NN'),
#  ('booooom', 'NN'),
#  ('come', 'VBP'),
#  ('picked', 'VBN'),
#  ('diavolo', 'JJ'),
#  ('requiem', 'NN'),
#  ('running', 'VBG'),
#  ('who', 'WP'),
#  ('empty', 'VBP'),
#  ('other', 'JJ'),
#  ('earlier', 'JJR'),
#  ('subs', 'NNS'),
#  ('crack', 'VBP'),
#  ('without', 'IN'),
#  ('unleashed', 'JJ'),
#  ('no_one_can_escap', 'NN'),
#  ('spicy', 'NN'),
#  ('already', 'RB'),
#  ('grasp', 'VBZ'),
#  ('we', 'PRP'),
#  ('gio', 'JJ'),
#  ('way', 'NN'),
#  ('here', 'RB'),
#  ('place', 'VBZ'),
#  ('eyes', 'NNS'),
#  ('told', 'VBD'),
#  ('pierce', 'NN'),
#  ('why', 'WRB'),
#  ('started', 'VBD'),
#  ('bull', 'NN'),
#  ('hbe', 'NN'),
#  ('softer', 'NN'),
#  ('moles', 'NNS'),
#  ('maintenance', 'NN'),
#  ("'ve", 'VBP'),
#  ('these', 'DT'),
#  ('\\pos', 'NNS'),
#  ('look', 'VBP'),
#  ('correctly', 'RB'),
#  ('together', 'RB'),
#  ('than', 'IN'),
#  ('open', 'JJ'),
#  ('fall', 'NN'),
#  ('learned', 'VBD'),
#  ('rest', 'JJ'),
#  ('overcome', 'NN'),
#  ('and', 'CC'),
#  ('mo', 'NN'),
#  ('i', 'NN'),
#  ('suddenly', 'RB'),
#  ('distance', 'NN'),
#  ('stays', 'NNS'),
#  ('turtle', 'RB'),
#  ('go', 'VBP'),
#  ('predictions', 'NNS'),
#  ('into', 'IN'),
#  ('mr.', 'JJ'),
#  ('escape', 'JJ'),
#  ('w-wait', 'JJ'),
#  ('takes', 'VBZ'),
#  ('mystery', 'NN'),
#  ('observation', 'NN'),
#  ('the', 'DT'),
#  ('direction', 'NN'),
#  ('enough', 'JJ'),
#  ('talk', 'NN'),
#  ('man', 'NN'),
#  ('stares', 'VBZ'),
#  ('as', 'IN'),
#  ('identity', 'NN'),
#  ('emperor', 'VBP'),
#  ('much', 'RB'),
#  ("'s", 'POS'),
#  ('hidden', 'NN'),
#  ('when', 'WRB'),
#  ('ts', 'NN'),
#  ('listen', 'VBZ'),
#  ('sh', 'NNS'),
#  ('can', 'MD'),
#  ('parts', 'NNS'),
#  ('freely', 'RB'),
#  ('existence', 'VBP'),
#  ('gift', 'NN'),
#  ('found', 'VBD'),
#  ('d-do', 'JJ'),
#  ('erases', 'NNS'),
#  ('skipped', 'VBD'),
#  ('\\an\\fs\\pos', 'NNP'),
#  ('berserk', 'NN'),
#  ('blind', 'IN'),
#  ('fact', 'NN'),
#  ('&', 'CC'),
#  ('soon', 'RB'),
#  ('check', 'VB')]

# %% [markdown]
# ### Wait...what is that POS category?
# Find out what a category is by asking NLTK:
# `nltk.help.upenn_tagset('VBZ')`

# %%
nltk.download('tagsets_json')
# Out:
# [nltk_data] Downloading package tagsets_json to
# [nltk_data]     /Users/micaiahross/nltk_data...
# [nltk_data]   Unzipping help/tagsets_json.zip.
# True

# %%
nltk.help.upenn_tagset('JJ')
# Out:
# JJ: adjective or numeral, ordinal
#     third ill-mannered pre-war regrettable oiled calamitous first separable
#     ectoplasmic battery-powered participatory fourth still-to-be-named
#     multilingual multi-disciplinary ...

# %% [markdown]
# We can limit our list of words of interest by asking for words of a particular kind, isolating them by POS

# %%
POStagged = pos_tag(uniqueTokens)
tagsIwant = ['VB', 'VBD', 'VBZ']
# This is a Python list comprehension that'll help us with our list of tuples [(word, tag), (word, tag), ...]
shortList = [word for word, tag in POStagged if tag in tagsIwant]
setList = set(shortList)
print(len(setList))
print(shortList)

# Fancy string formatting (not super useful here, just reviewing it): 
# f'My short list is {shortList} and it is this long: {len(shortList)}'
# Out:
# 101
# ['n', 'big', 'sure', 'hcbbc', 'n.', 'perish', 'clear', '.-billion-year', 'eternal', 'first', 'new', 'sudden', 'brief', 'golden', 'blow', 'thrown', 'live', 'o-oh', 'hey', 'certain', 'immense', 'jojo-eptitle', 'betray', 'i-i', 'past', 'few', 'front', 'civilian', 'let', 'fine', 'mind', 'sfx', 'right', 'eliminated', 'possible', 'i-it', 'complete', 'important', 'due', 'finish', 'hd', 'shut', 'fit', 'wha', 'mean', 'elastic', 'different', 'crimson', 'episodio', 'appeared', 'become', 'cop', 'm-maybe', 'stuck', 'm-me', 'run', 'dodge', 'b-but', 'many', 'who_swapped_with', 'able', 'mine', 'song', 'tear', 'weak', 'good', 'lonely', 'conscious', 'okay', 'trish', 'correct', 'aware', 'total', 'loose', 'soul', 'stand', 'actual', 'shots', 'imminent', 'shadow', 'rid', 'keep', 'h-he', 'true', 'break', 'giorno', 'destroyed', 'foolish', 'second', 'hef', 'diavolo', 'other', 'unleashed', 'gio', 'open', 'rest', 'mr.', 'escape', 'w-wait', 'enough', 'd-do']

# %% [markdown]
# Changed the tags to things that give more meaningful results with my text.

# %% [markdown]
# ## Send them to WordNet for synset lookup
#
# * Use list comprehension
# * Use wn.morphy to simplify the word to its synset lemma form
# * While we're at it, let's sort the shortList using `sorted()`.
# * We noticed that WordNet has its own parts of speech, and they're a lot simpler than NLTK's.
#     * WordNet's parts of speech are ADJ, ADJ_SAT, ADV, NOUN, VERB:  'a', 's', 'r', 'n', 'v'
#     * We also noticed that NLTK's part of speech tagging is rather shockingly unreliable on our texts.
#     * We wonder if spaCy might be better, or if we really need to train the models on our texts by tagging them ourselves.
#     * You might want to just make a list of all the words that have the same ending, like our [-ing smoke test](https://github.com/newtfire/textAnalysis-Hub/blob/main/Class-Examples/Python/orient-ing.py) from the NLTK book intro in our first Python assignment.

# %%
for w in sorted(shortList):
    lemma = wn.morphy(w)
    # I don't think we need the next line, but it's a fallback if there's no WordNet lemmas: 
    lemma = lemma if lemma else w 
    print(f"Word: {w} | Wordnet Lemma: {lemma}")
    synsets = wn.synsets(lemma)
    pos = {synset.pos() for synset in synsets}
    if synsets:
       
        
        print(f" Word: {w}, POS-according-to-WordNet {pos} Number of Synsets (Ambiguity): {len(synsets)}") 
              
        
        # for syn in synsets:
        #   print(f"  Synset: {syn.name()}, Definition: {syn.definition()}}")
# Out:
# Word: .-billion-year | Wordnet Lemma: .-billion-year
# Word: able | Wordnet Lemma: able
#  Word: able, POS-according-to-WordNet {'s', 'a'} Number of Synsets (Ambiguity): 4
# Word: actual | Wordnet Lemma: actual
#  Word: actual, POS-according-to-WordNet {'s', 'a'} Number of Synsets (Ambiguity): 5
# Word: appeared | Wordnet Lemma: appear
#  Word: appeared, POS-according-to-WordNet {'v'} Number of Synsets (Ambiguity): 7
# Word: aware | Wordnet Lemma: aware
#  Word: aware, POS-according-to-WordNet {'a'} Number of Synsets (Ambiguity): 2
# Word: b-but | Wordnet Lemma: b-but
# Word: become | Wordnet Lemma: become
#  Word: become, POS-according-to-WordNet {'v'} Number of Synsets (Ambiguity): 4
# Word: betray | Wordnet Lemma: betray
#  Word: betray, POS-according-to-WordNet {'v'} Number of Synsets (Ambiguity): 6
# Word: big | Wordnet Lemma: big
#  Word: big, POS-according-to-WordNet {'s', 'a', 'r'} Number of Synsets (Ambiguity): 17
# Word: blow | Wordnet Lemma: blow
#  Word: blow, POS-according-to-WordNet {'v', 'n'} Number of Synsets (Ambiguity): 29
# Word: break | Wordnet Lemma: break
#  Word: break, POS-according-to-WordNet {'v', 'n'} Number of Synsets (Ambiguity): 75
# Word: brief | Wordnet Lemma: brief
#  Word: brief, POS-according-to-WordNet {'v', 'n', 's'} Number of Synsets (Ambiguity): 6
# Word: certain | Wordnet Lemma: certain
#  Word: certain, POS-according-to-WordNet {'s', 'a'} Number of Synsets (Ambiguity): 7
# Word: civilian | Wordnet Lemma: civilian
#  Word: civilian, POS-according-to-WordNet {'n', 'a'} Number of Synsets (Ambiguity): 2
# Word: clear | Wordnet Lemma: clear
#  Word: clear, POS-according-to-WordNet {'n', 'r', 'v', 'a', 's'} Number of Synsets (Ambiguity): 45
# Word: complete | Wordnet Lemma: complete
#  Word: complete, POS-according-to-WordNet {'v', 's', 'a'} Number of Synsets (Ambiguity): 10
# Word: conscious | Wordnet Lemma: conscious
#  Word: conscious, POS-according-to-WordNet {'s', 'a'} Number of Synsets (Ambiguity): 3
# Word: cop | Wordnet Lemma: cop
#  Word: cop, POS-according-to-WordNet {'v', 'n'} Number of Synsets (Ambiguity): 3
# Word: correct | Wordnet Lemma: correct
#  Word: correct, POS-according-to-WordNet {'v', 's', 'a'} Number of Synsets (Ambiguity): 12
# Word: crimson | Wordnet Lemma: crimson
#  Word: crimson, POS-according-to-WordNet {'v', 'n', 's'} Number of Synsets (Ambiguity): 5
# Word: d-do | Wordnet Lemma: d-do
# Word: destroyed | Wordnet Lemma: destroy
#  Word: destroyed, POS-according-to-WordNet {'v'} Number of Synsets (Ambiguity): 4
# Word: diavolo | Wordnet Lemma: diavolo
# Word: different | Wordnet Lemma: different
#  Word: different, POS-according-to-WordNet {'s', 'a'} Number of Synsets (Ambiguity): 5
# Word: dodge | Wordnet Lemma: dodge
#  Word: dodge, POS-according-to-WordNet {'v', 'n'} Number of Synsets (Ambiguity): 6
# Word: due | Wordnet Lemma: due
#  Word: due, POS-according-to-WordNet {'n', 'a', 'r', 's'} Number of Synsets (Ambiguity): 7
# Word: elastic | Wordnet Lemma: elastic
#  Word: elastic, POS-according-to-WordNet {'n', 'a', 's'} Number of Synsets (Ambiguity): 4
# Word: eliminated | Wordnet Lemma: eliminate
#  Word: eliminated, POS-according-to-WordNet {'v'} Number of Synsets (Ambiguity): 7
# Word: enough | Wordnet Lemma: enough
#  Word: enough, POS-according-to-WordNet {'n', 'r', 's'} Number of Synsets (Ambiguity): 3
# Word: episodio | Wordnet Lemma: episodio
# Word: escape | Wordnet Lemma: escape
#  Word: escape, POS-according-to-WordNet {'v', 'n'} Number of Synsets (Ambiguity): 15
# Word: eternal | Wordnet Lemma: eternal
#  Word: eternal, POS-according-to-WordNet {'s'} Number of Synsets (Ambiguity): 2
# Word: few | Wordnet Lemma: few
#  Word: few, POS-according-to-WordNet {'n', 'a'} Number of Synsets (Ambiguity): 2
# Word: fine | Wordnet Lemma: fine
#  Word: fine, POS-according-to-WordNet {'n', 'r', 'v', 'a', 's'} Number of Synsets (Ambiguity): 10
# Word: finish | Wordnet Lemma: finish
#  Word: finish, POS-according-to-WordNet {'v', 'n'} Number of Synsets (Ambiguity): 15
# Word: first | Wordnet Lemma: first
#  Word: first, POS-according-to-WordNet {'n', 'a', 'r', 's'} Number of Synsets (Ambiguity): 16
# Word: fit | Wordnet Lemma: fit
#  Word: fit, POS-according-to-WordNet {'v', 'n', 'a', 's'} Number of Synsets (Ambiguity): 16
# Word: foolish | Wordnet Lemma: foolish
#  Word: foolish, POS-according-to-WordNet {'s', 'a'} Number of Synsets (Ambiguity): 2
# Word: front | Wordnet Lemma: front
#  Word: front, POS-according-to-WordNet {'v', 'n', 'a'} Number of Synsets (Ambiguity): 13
# Word: gio | Wordnet Lemma: gio
# Word: giorno | Wordnet Lemma: giorno
# Word: golden | Wordnet Lemma: golden
#  Word: golden, POS-according-to-WordNet {'s'} Number of Synsets (Ambiguity): 6
# Word: good | Wordnet Lemma: good
#  Word: good, POS-according-to-WordNet {'n', 'a', 'r', 's'} Number of Synsets (Ambiguity): 27
# Word: h-he | Wordnet Lemma: h-he
# Word: hcbbc | Wordnet Lemma: hcbbc
# Word: hd | Wordnet Lemma: hd
# Word: hef | Wordnet Lemma: hef
# Word: hey | Wordnet Lemma: hey
# Word: i-i | Wordnet Lemma: i-i
# Word: i-it | Wordnet Lemma: i-it
# Word: immense | Wordnet Lemma: immense
#  Word: immense, POS-according-to-WordNet {'s'} Number of Synsets (Ambiguity): 1
# Word: imminent | Wordnet Lemma: imminent
#  Word: imminent, POS-according-to-WordNet {'s'} Number of Synsets (Ambiguity): 1
# Word: important | Wordnet Lemma: important
#  Word: important, POS-according-to-WordNet {'s', 'a'} Number of Synsets (Ambiguity): 5
# Word: jojo-eptitle | Wordnet Lemma: jojo-eptitle
# Word: keep | Wordnet Lemma: keep
#  Word: keep, POS-according-to-WordNet {'v', 'n'} Number of Synsets (Ambiguity): 25
# Word: let | Wordnet Lemma: let
#  Word: let, POS-according-to-WordNet {'v', 'n'} Number of Synsets (Ambiguity): 8
# Word: live | Wordnet Lemma: live
#  Word: live, POS-according-to-WordNet {'v', 's', 'a', 'r'} Number of Synsets (Ambiguity): 19
# Word: lonely | Wordnet Lemma: lonely
#  Word: lonely, POS-according-to-WordNet {'s'} Number of Synsets (Ambiguity): 4
# Word: loose | Wordnet Lemma: loose
#  Word: loose, POS-according-to-WordNet {'v', 's', 'a', 'r'} Number of Synsets (Ambiguity): 18
# Word: m-maybe | Wordnet Lemma: m-maybe
# Word: m-me | Wordnet Lemma: m-me
# Word: many | Wordnet Lemma: many
#  Word: many, POS-according-to-WordNet {'a'} Number of Synsets (Ambiguity): 1
# Word: mean | Wordnet Lemma: mean
#  Word: mean, POS-according-to-WordNet {'v', 'n', 's'} Number of Synsets (Ambiguity): 16
# Word: mind | Wordnet Lemma: mind
#  Word: mind, POS-according-to-WordNet {'v', 'n'} Number of Synsets (Ambiguity): 13
# Word: mine | Wordnet Lemma: mine
#  Word: mine, POS-according-to-WordNet {'v', 'n'} Number of Synsets (Ambiguity): 4
# Word: mr. | Wordnet Lemma: mr.
#  Word: mr., POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 1
# Word: n | Wordnet Lemma: n
#  Word: n, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 5
# Word: n. | Wordnet Lemma: n.
# Word: new | Wordnet Lemma: new
#  Word: new, POS-according-to-WordNet {'s', 'a', 'r'} Number of Synsets (Ambiguity): 12
# Word: o-oh | Wordnet Lemma: o-oh
# Word: okay | Wordnet Lemma: okay
#  Word: okay, POS-according-to-WordNet {'v', 'n', 'r', 's'} Number of Synsets (Ambiguity): 4
# Word: open | Wordnet Lemma: open
#  Word: open, POS-according-to-WordNet {'v', 'n', 'a', 's'} Number of Synsets (Ambiguity): 36
# Word: other | Wordnet Lemma: other
#  Word: other, POS-according-to-WordNet {'s', 'a'} Number of Synsets (Ambiguity): 4
# Word: past | Wordnet Lemma: past
#  Word: past, POS-according-to-WordNet {'n', 'a', 'r', 's'} Number of Synsets (Ambiguity): 6
# Word: perish | Wordnet Lemma: perish
#  Word: perish, POS-according-to-WordNet {'v'} Number of Synsets (Ambiguity): 1
# Word: possible | Wordnet Lemma: possible
#  Word: possible, POS-according-to-WordNet {'n', 'a'} Number of Synsets (Ambiguity): 4
# Word: rest | Wordnet Lemma: rest
#  Word: rest, POS-according-to-WordNet {'v', 'n'} Number of Synsets (Ambiguity): 18
# Word: rid | Wordnet Lemma: rid
#  Word: rid, POS-according-to-WordNet {'v'} Number of Synsets (Ambiguity): 1
# Word: right | Wordnet Lemma: right
#  Word: right, POS-according-to-WordNet {'n', 'r', 'v', 'a', 's'} Number of Synsets (Ambiguity): 36
# Word: run | Wordnet Lemma: run
#  Word: run, POS-according-to-WordNet {'v', 'n'} Number of Synsets (Ambiguity): 57
# Word: second | Wordnet Lemma: second
#  Word: second, POS-according-to-WordNet {'n', 'r', 'v', 'a', 's'} Number of Synsets (Ambiguity): 15
# Word: sfx | Wordnet Lemma: sfx
# Word: shadow | Wordnet Lemma: shadow
#  Word: shadow, POS-according-to-WordNet {'v', 'n'} Number of Synsets (Ambiguity): 12
# Word: shots | Wordnet Lemma: shot
#  Word: shots, POS-according-to-WordNet {'v', 'n', 's'} Number of Synsets (Ambiguity): 38
# Word: shut | Wordnet Lemma: shut
#  Word: shut, POS-according-to-WordNet {'v', 'a'} Number of Synsets (Ambiguity): 5
# Word: song | Wordnet Lemma: song
#  Word: song, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 6
# Word: soul | Wordnet Lemma: soul
#  Word: soul, POS-according-to-WordNet {'n'} Number of Synsets (Ambiguity): 5
# Word: stand | Wordnet Lemma: stand
#  Word: stand, POS-according-to-WordNet {'v', 'n'} Number of Synsets (Ambiguity): 24
# Word: stuck | Wordnet Lemma: stick
#  Word: stuck, POS-according-to-WordNet {'v', 'n'} Number of Synsets (Ambiguity): 25
# Word: sudden | Wordnet Lemma: sudden
#  Word: sudden, POS-according-to-WordNet {'a'} Number of Synsets (Ambiguity): 1
# Word: sure | Wordnet Lemma: sure
#  Word: sure, POS-according-to-WordNet {'s', 'a', 'r'} Number of Synsets (Ambiguity): 10
# Word: tear | Wordnet Lemma: tear
#  Word: tear, POS-according-to-WordNet {'v', 'n'} Number of Synsets (Ambiguity): 9
# Word: thrown | Wordnet Lemma: throw
#  Word: thrown, POS-according-to-WordNet {'v', 'n'} Number of Synsets (Ambiguity): 20
# Word: total | Wordnet Lemma: total
#  Word: total, POS-according-to-WordNet {'v', 'n', 's'} Number of Synsets (Ambiguity): 7
# Word: trish | Wordnet Lemma: trish
# Word: true | Wordnet Lemma: true
#  Word: true, POS-according-to-WordNet {'n', 'r', 'v', 'a', 's'} Number of Synsets (Ambiguity): 15
# Word: unleashed | Wordnet Lemma: unleash
#  Word: unleashed, POS-according-to-WordNet {'v'} Number of Synsets (Ambiguity): 3
# Word: w-wait | Wordnet Lemma: w-wait
# Word: weak | Wordnet Lemma: weak
#  Word: weak, POS-according-to-WordNet {'s', 'a'} Number of Synsets (Ambiguity): 12
# Word: wha | Wordnet Lemma: wha
# Word: who_swapped_with | Wordnet Lemma: who_swapped_with

# %%
def write_output(filename, data):
    o = open(filename, "w", encoding="utf-8")
    for line in data:
        o.write(str(line) + "\n")
    o.close()

results = []
for w in sorted(shortList):
    lemma = wn.morphy(w)
    lemma = lemma if lemma else w
    synsets = wn.synsets(lemma)
    if synsets:
        results.append(f"{w} | lemma: {lemma} | synsets: {len(synsets)}")

write_output("jojo_wordnet.txt", results)
print("saved!")
# Out:
# saved!

# %% [markdown]
# Added a code block actually output and write the file. I got some pretty interesting results. For example, Break has 75 synsets, which is a very ambigious word.
