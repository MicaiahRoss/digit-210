# %% [markdown]
# ## Part of Speech Tagging is Weird
#
# NLTK shows us some weird part of speech tagging. We might decide that it's just a bit unreliable here. In this notebook, we're going to compare the part of speech tagging from NLTK with a newer library called spaCy that's used widely in industry for natural language processing (NLP). We'll also practice preparing some simple files for output.
#
# ### Installs
# For the code in this notebook, you'll need to do a couple of new pip installs in your activated virtual environment (.venv) in your shell:
#
# * `pip install spacy`
# * `pip install pygal`
#
# ### Language Models
# Like NLTK's collections that we downloaded, [spaCy has trained language models](https://spacy.io/usage/models) to download. You download these in your Python script after you import spacy, and after you download once, you don't need to do it again (so you can comment out the download line). We're going to try the medium and large models in English. (It's good to know that both spaCy and NLTK have resources for NLP on other languages, too!)

# %%
import spacy

# %% [markdown]
# ### Downloading language models
# To work with spaCy's pre-trained language models, you need to download them to you virtual environment. There are:
# * en_core_web_sm (smallest--not as much info as the others)
# * **en_core_web_md** (Pretty good date here, size: 34 MB )
# * **en_core_web_lg** (Lots of data here, size: 400 MB.)
# Note that the LARGEST  one will have the most data and probably be the most reliable.

# %%
# CAN YOU SKIP THIS???
# After you download a model into your virtual environment for the first time, you can comment out the download line.
# spaCy's medium and large models will give us the best results for NLP tagging.
# nlp = spacy.cli.download("en_core_web_sm")
# nlp = spacy.cli.download("en_core_web_md")
nlp = spacy.cli.download("en_core_web_lg")
# Out:
# Collecting en-core-web-lg==3.8.0
#   Downloading en_core_web_lg-3.8.0-py3-none-any.whl (400.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.7/400.7 MB 60.0 MB/s  0:00:06:00:0100:01
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %% [markdown]
# ### Load the model
# Now we redefine the nlp variable to LOAD the model you downloaded.

# %%
nlp = spacy.load("en_core_web_lg")

# %%
filepath = 'jojo/04x36_-_Diavolo_Surfaces.txt'
f = open(filepath, 'r', encoding='utf8').read()

# %% [markdown]
# ## spaCy Part of Speech Tagging
# spaCy needs to read the str() of our text to generate a dictionary of information on each word.
# So we go back to our opened file!

# %%
# We used nlp as our variable for the spaCy operations. 
# f is our variable for the source file. spaCy doesn't tell you how it tokenizes or what it's doing (sigh). 
spacyRead = nlp(f)
for token in spacyRead:
    print(token.text, "---->", token.pos_, ":::::", token.lemma_)
# Out:
# Bruno ----> PROPN ::::: Bruno
# : ----> PUNCT ::::: :
# So ----> ADV ::::: so
# there ----> PRON ::::: there
# you ----> PRON ::::: you
# are ----> AUX ::::: be
# ... ----> PUNCT ::::: ...
# Boss ----> NOUN ::::: boss
# ... ----> SYM ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Bruno ----> PROPN ::::: Bruno
# : ----> PUNCT ::::: :
# That ----> PRON ::::: that
# 's ----> AUX ::::: be
# where ----> SCONJ ::::: where
# ... ----> PUNCT ::::: ...
# you ----> PRON ::::: you
# were ----> AUX ::::: be
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Bruno ----> PROPN ::::: Bruno
# : ----> PUNCT ::::: :
# And ----> CCONJ ::::: and
# that ----> PRON ::::: that
# 's ----> AUX ::::: be
# ... ----> PUNCT ::::: ...
# whose ----> DET ::::: whose
# body ----> NOUN ::::: body
# you ----> PRON ::::: you
# 're ----> AUX ::::: be
# using ----> VERB ::::: use
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Bruno ----> PROPN ::::: Bruno
# : ----> PUNCT ::::: :
# The ----> DET ::::: the
# moment ----> NOUN ::::: moment
# I ----> PRON ::::: I
# got ----> VERB ::::: get
# tired ----> ADJ ::::: tired
# and ----> CCONJ ::::: and
# could ----> AUX ::::: could
# feel ----> VERB ::::: feel
# my ----> PRON ::::: my
# soul ----> NOUN ::::: soul
# being ----> AUX ::::: be
# sucked ----> VERB ::::: suck
# out ----> ADP ::::: out
# , ----> PUNCT ::::: ,
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Bruno ----> PROPN ::::: Bruno
# : ----> PUNCT ::::: :
# you ----> PRON ::::: you
# said ----> VERB ::::: say
# you ----> PRON ::::: you
# had ----> VERB ::::: have
# to ----> PART ::::: to
# go ----> VERB ::::: go
# because ----> SCONJ ::::: because
# things ----> NOUN ::::: thing
# were ----> AUX ::::: be
# going ----> VERB ::::: go
# south ----> ADV ::::: south
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Bruno ----> PROPN ::::: Bruno
# : ----> PUNCT ::::: :
# It ----> PRON ::::: it
# 's ----> AUX ::::: be
# true ----> ADJ ::::: true
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# JoJo ----> PROPN ::::: JoJo
# - ----> PUNCT ::::: -
# main ----> ADJ ::::: main
# : ----> PUNCT ::::: :
# , ----> PUNCT ::::: ,
# If ----> SCONJ ::::: if
# you ----> PRON ::::: you
# 're ----> AUX ::::: be
# there ----> ADV ::::: there
# , ----> PUNCT ::::: ,
# Boss ----> PROPN ::::: Boss
# ... ----> SYM ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# JoJo ----> PROPN ::::: JoJo
# - ----> PUNCT ::::: -
# main ----> ADJ ::::: main
# : ----> PUNCT ::::: :
# , ----> PUNCT ::::: ,
# We ----> PRON ::::: we
# 're ----> AUX ::::: be
# going ----> VERB ::::: go
# to ----> PART ::::: to
# win ----> VERB ::::: win
# for ----> ADP ::::: for
# sure ----> ADJ ::::: sure
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Bruno ----> PROPN ::::: Bruno
# : ----> PUNCT ::::: :
# But ----> CCONJ ::::: but
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Dopp ----> PROPN ::::: Dopp
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# so ----> ADV ::::: so
# lonely ----> ADJ ::::: lonely
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Dopp ----> PROPN ::::: Dopp
# : ----> PUNCT ::::: :
# Could ----> AUX ::::: could
# you ----> PRON ::::: you
# ... ----> PUNCT ::::: ...
# call ----> VERB ::::: call
# me ----> PRON ::::: I
# again ----> ADV ::::: again
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# JoJo ----> PROPN ::::: JoJo
# - ----> PUNCT ::::: -
# main ----> ADJ ::::: main
# : ----> PUNCT ::::: :
# , ----> PUNCT ::::: ,
# like ----> INTJ ::::: like
# you ----> PRON ::::: you
# always ----> ADV ::::: always
# have ----> VERB ::::: have
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Dopp ----> PROPN ::::: Dopp
# : ----> PUNCT ::::: :
# Boss ----> PROPN ::::: Boss
# ... ----> SYM ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# No_one_can_escap ----> PROPN ::::: No_one_can_escap
# , ----> PUNCT ::::: ,
# Op ----> PROPN ::::: Op
# subs ----> NOUN ::::: sub
# : ----> PUNCT ::::: :
# No ----> DET ::::: no
# one ----> NOUN ::::: one
# can ----> AUX ::::: can
# escape ----> VERB ::::: escape
# the ----> DET ::::: the
# fate ----> NOUN ::::: fate
# that ----> PRON ::::: that
# was ----> AUX ::::: be
# chosen ----> VERB ::::: choose
# for ----> ADP ::::: for
# them ----> PRON ::::: they
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# No_one_can_escap ----> PROPN ::::: No_one_can_escap
# , ----> PUNCT ::::: ,
# Op ----> PROPN ::::: Op
# subs ----> NOUN ::::: sub
# : ----> PUNCT ::::: :
# All ----> PRON ::::: all
# that ----> PRON ::::: that
# remains ----> VERB ::::: remain
# is ----> AUX ::::: be
# the ----> DET ::::: the
# end ----> NOUN ::::: end
# , ----> PUNCT ::::: ,
# where ----> SCONJ ::::: where
# you ----> PRON ::::: you
# will ----> AUX ::::: will
# all ----> ADV ::::: all
# perish ----> VERB ::::: perish
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# No_one_can_escap ----> PROPN ::::: No_one_can_escap
# , ----> PUNCT ::::: ,
# Op ----> PROPN ::::: Op
# subs ----> NOUN ::::: sub
# : ----> PUNCT ::::: :
# Eternal ----> ADJ ::::: eternal
# greatness ----> NOUN ::::: greatness
# exists ----> VERB ::::: exist
# only ----> ADV ::::: only
# within ----> ADP ::::: within
# myself ----> PRON ::::: myself
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# No_one_can_escap ----> PROPN ::::: No_one_can_escap
# , ----> PUNCT ::::: ,
# Op ----> PROPN ::::: Op
# subs ----> NOUN ::::: sub
# : ----> PUNCT ::::: :
# Sing ----> VERB ::::: sing
# a ----> DET ::::: a
# song ----> NOUN ::::: song
# of ----> ADP ::::: of
# sorrow ----> NOUN ::::: sorrow
# in ----> ADP ::::: in
# a ----> DET ::::: a
# world ----> NOUN ::::: world
# where ----> SCONJ ::::: where
# time ----> NOUN ::::: time
# has ----> AUX ::::: have
# vanished ----> VERB ::::: vanish
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# JoJo ----> PROPN ::::: JoJo
# - ----> PUNCT ::::: -
# EpTitle ----> PROPN ::::: EpTitle
# , ----> PUNCT ::::: ,
# Sign ----> NOUN ::::: sign
# : ----> PUNCT ::::: :
# Episodio ----> PROPN ::::: Episodio
#   ----> SPACE :::::
# Diavolo ----> PROPN ::::: Diavolo
# Surfaces ----> PROPN ::::: Surfaces
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Turtle ----> PROPN ::::: Turtle
# : ----> PUNCT ::::: :
# Mista ----> PROPN ::::: Mista
# ! ----> PUNCT ::::: !
# Hurry ----> VERB ::::: hurry
# up ----> ADP ::::: up
# and ----> CCONJ ::::: and
# pierce ----> VERB ::::: pierce
# your ----> PRON ::::: your
# Stand ----> NOUN ::::: stand
# with ----> ADP ::::: with
# this ----> DET ::::: this
# arrow ----> NOUN ::::: arrow
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Mista ----> PROPN ::::: Mista
# : ----> PUNCT ::::: :
# What ----> PRON ::::: what
# 's ----> AUX ::::: be
# going ----> VERB ::::: go
# on ----> ADP ::::: on
# ? ----> PUNCT ::::: ?
# Requiem ----> PROPN ::::: Requiem
# 's ----> PART ::::: 's
# suddenly ----> ADV ::::: suddenly
# heading ----> VERB ::::: head
# toward ----> ADP ::::: toward
# us ----> PRON ::::: we
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Dia ----> PROPN ::::: Dia
# : ----> PUNCT ::::: :
# Giorno ----> PROPN ::::: Giorno
# ! ----> PUNCT ::::: !
# Stop ----> VERB ::::: stop
# Requiem ----> PROPN ::::: Requiem
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Gio ----> PROPN ::::: Gio
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# ca ----> AUX ::::: can
# n't ----> PART ::::: not
# ! ----> PUNCT ::::: !
# It ----> PRON ::::: it
# 's ----> AUX ::::: be
# too ----> ADV ::::: too
# far ----> ADV ::::: far
# away ----> ADV ::::: away
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Crunch ----> PROPN ::::: Crunch
# , ----> PUNCT ::::: ,
# Sfx ----> PROPN ::::: Sfx
# : ----> PUNCT ::::: :
# { ----> PUNCT ::::: {
# \c&HCCF&\c&HB&}Crack ----> PROPN ::::: \c&HCCF&\c&HB&}Crack
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Trish ----> PROPN ::::: Trish
# : ----> PUNCT ::::: :
# Wha ----> PROPN ::::: Wha
# — ----> PUNCT ::::: —
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Trish ----> PROPN ::::: Trish
# : ----> PUNCT ::::: :
# My ----> PRON ::::: my
# g*n ----> PROPN ::::: g*n
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Dia ----> PROPN ::::: Dia
# : ----> PUNCT ::::: :
# What ----> PRON ::::: what
# are ----> AUX ::::: be
# you ----> PRON ::::: you
# doing ----> VERB ::::: do
# , ----> PUNCT ::::: ,
# Mista ----> PROPN ::::: Mista
# ? ----> PUNCT ::::: ?
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Mista ----> PROPN ::::: Mista
# : ----> PUNCT ::::: :
# It ----> PRON ::::: it
# 's ----> AUX ::::: be
# because ----> SCONJ ::::: because
# you ----> PRON ::::: you
# 're ----> AUX ::::: be
# touching ----> VERB ::::: touch
# the ----> DET ::::: the
# arrow ----> NOUN ::::: arrow
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Trish ----> PROPN ::::: Trish
# : ----> PUNCT ::::: :
# No ----> DET ::::: no
# way ----> NOUN ::::: way
# ! ----> PUNCT ::::: !
# Why ----> SCONJ ::::: why
# is ----> AUX ::::: be
# this ----> PRON ::::: this
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Gio ----> PROPN ::::: Gio
# : ----> PUNCT ::::: :
# Let ----> VERB ::::: let
# go ----> VERB ::::: go
# of ----> ADP ::::: of
# it ----> PRON ::::: it
# , ----> PUNCT ::::: ,
# Mr. ----> PROPN ::::: Mr.
# Polnareff ----> PROPN ::::: Polnareff
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Gio ----> PROPN ::::: Gio
# : ----> PUNCT ::::: :
# Let ----> VERB ::::: let
# go ----> VERB ::::: go
# of ----> ADP ::::: of
# the ----> DET ::::: the
# arrow ----> NOUN ::::: arrow
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Trish ----> PROPN ::::: Trish
# : ----> PUNCT ::::: :
# Glad ----> PROPN ::::: Glad
# I ----> PRON ::::: I
# took ----> VERB ::::: take
# that ----> DET ::::: that
# cop ----> NOUN ::::: cop
# 's ----> PART ::::: 's
# Beretta ----> PROPN ::::: Beretta
# just ----> ADV ::::: just
# in ----> ADP ::::: in
# case ----> NOUN ::::: case
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Trish ----> PROPN ::::: Trish
# : ----> PUNCT ::::: :
# But ----> CCONJ ::::: but
# what ----> PRON ::::: what
# the ----> DET ::::: the
# hell ----> NOUN ::::: hell
# , ----> PUNCT ::::: ,
# b*ll*ts ----> PROPN ::::: b*ll*ts
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Trish ----> PROPN ::::: Trish
# : ----> PUNCT ::::: :
# Why ----> SCONJ ::::: why
# 'd ----> AUX ::::: would
# my ----> PRON ::::: my
# revolver ----> NOUN ::::: revolver
# break ----> NOUN ::::: break
# all ----> PRON ::::: all
# of ----> ADP ::::: of
# a ----> ADV ::::: a
# sudden ----> ADJ ::::: sudden
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Five ----> NUM ::::: five
# : ----> PUNCT ::::: :
# M ----> PROPN ::::: M
# - ----> PUNCT ::::: -
# Maybe ----> ADV ::::: maybe
# the ----> DET ::::: the
# boss ----> NOUN ::::: boss
# got ----> VERB ::::: get
# close ----> ADJ ::::: close
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# B*llet ----> PROPN ::::: B*llet
# : ----> PUNCT ::::: :
# You ----> PRON ::::: you
# dumbass ----> ADV ::::: dumbass
# ! ----> PUNCT ::::: !
# Think ----> VERB ::::: think
# before ----> SCONJ ::::: before
# you ----> PRON ::::: you
# talk ----> VERB ::::: talk
# , ----> PUNCT ::::: ,
# Number ----> PROPN ::::: Number
# Five ----> PROPN ::::: Five
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# B*llet ----> PROPN ::::: B*llet
# : ----> PUNCT ::::: :
# Are ----> AUX ::::: be
# you ----> PRON ::::: you
# saying ----> VERB ::::: say
# you ----> PRON ::::: you
# saw ----> VERB ::::: see
# someone ----> PRON ::::: someone
# coming ----> VERB ::::: come
# close ----> ADV ::::: close
# to ----> ADP ::::: to
# us ----> PRON ::::: we
# in ----> ADP ::::: in
# this ----> DET ::::: this
# big ----> ADJ ::::: big
# , ----> PUNCT ::::: ,
# open ----> ADJ ::::: open
# space ----> NOUN ::::: space
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# B*llet ----> VERB ::::: b*llet
# : ----> PUNCT ::::: :
# We ----> PRON ::::: we
# did ----> AUX ::::: do
# n't ----> PART ::::: not
# see ----> VERB ::::: see
# anyone ----> PRON ::::: anyone
# at ----> ADP ::::: at
# the ----> DET ::::: the
# moment ----> NOUN ::::: moment
# the ----> DET ::::: the
# revolver ----> NOUN ::::: revolver
# broke ----> VERB ::::: break
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# B*llet ----> PROPN ::::: B*llet
# : ----> PUNCT ::::: :
# It ----> PRON ::::: it
# 's ----> AUX ::::: be
# metal ----> NOUN ::::: metal
# fatigue ----> NOUN ::::: fatigue
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# JoJo ----> PROPN ::::: JoJo
# - ----> PUNCT ::::: -
# main ----> ADJ ::::: main
# : ----> PUNCT ::::: :
# , ----> PUNCT ::::: ,
# It ----> PRON ::::: it
# 's ----> AUX ::::: be
# because ----> SCONJ ::::: because
# he ----> PRON ::::: he
# 's ----> AUX ::::: be
# been ----> AUX ::::: be
# overusing ----> VERB ::::: overuse
# the ----> DET ::::: the
# g*n ----> PROPN ::::: g*n
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# B*llet ----> PROPN ::::: B*llet
# : ----> PUNCT ::::: :
# The ----> DET ::::: the
# axis ----> NOUN ::::: axis
# of ----> ADP ::::: of
# the ----> DET ::::: the
# cylinder ----> NOUN ::::: cylinder
# broke ----> VERB ::::: break
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# B*llet ----> PROPN ::::: B*llet
# : ----> PUNCT ::::: :
# We ----> PRON ::::: we
# have ----> AUX ::::: have
# n't ----> PART ::::: not
# had ----> VERB ::::: have
# a ----> DET ::::: a
# chance ----> NOUN ::::: chance
# to ----> PART ::::: to
# doany ----> VERB ::::: doany
# maintenance ----> NOUN ::::: maintenance
# or ----> CCONJ ::::: or
# inspections ----> NOUN ::::: inspection
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# B*llet ----> PROPN ::::: B*llet
# : ----> PUNCT ::::: :
# H ----> PROPN ::::: H
# - ----> PUNCT ::::: -
# Hey ----> PROPN ::::: Hey
# ! ----> PROPN ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Trish ----> PROPN ::::: Trish
# : ----> PUNCT ::::: :
# What ----> PRON ::::: what
# the ----> DET ::::: the
# hell ----> NOUN ::::: hell
# is ----> AUX ::::: be
# this ----> DET ::::: this
# thing ----> NOUN ::::: thing
# 's ----> PART ::::: 's
# problem ----> NOUN ::::: problem
# ? ----> PUNCT ::::: ?
# It ----> PRON ::::: it
# 's ----> AUX ::::: be
# heading ----> VERB ::::: head
# toward ----> ADP ::::: toward
# m ----> NOUN ::::: m
# - ----> PUNCT ::::: -
# me ----> PRON ::::: I
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Turtle ----> PROPN ::::: Turtle
# : ----> PUNCT ::::: :
# No ----> INTJ ::::: no
# , ----> PUNCT ::::: ,
# Mista ----> PROPN ::::: Mista
# . ----> PUNCT ::::: .
# It ----> PRON ::::: it
# 's ----> AUX ::::: be
# heading ----> VERB ::::: head
# towards ----> ADP ::::: towards
# me ----> PRON ::::: I
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Turtle ----> NOUN ::::: turtle
# : ----> PUNCT ::::: :
# Even ----> ADV ::::: even
# though ----> SCONJ ::::: though
# it ----> PRON ::::: it
# has ----> AUX ::::: have
# the ----> DET ::::: the
# arrow ----> NOUN ::::: arrow
# back ----> ADV ::::: back
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Gio ----> PROPN ::::: Gio
# : ----> PUNCT ::::: :
# Golden ----> PROPN ::::: Golden
# Wind ----> PROPN ::::: Wind
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Crunch ----> PROPN ::::: Crunch
# , ----> PUNCT ::::: ,
# Sfx ----> PROPN ::::: Sfx
# : ----> PUNCT ::::: :
# { ----> PUNCT ::::: {
# \c&HCBBC&\c&HEB&}Batoom ----> PROPN ::::: \c&HCBBC&\c&HEB&}Batoom
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Turtle ----> NOUN ::::: turtle
# : ----> PUNCT ::::: :
# Requiem ----> PROPN ::::: Requiem
# intends ----> VERB ::::: intend
# to ----> PART ::::: to
# finish ----> VERB ::::: finish
# me ----> PRON ::::: I
# because ----> SCONJ ::::: because
# I ----> PRON ::::: I
# touched ----> VERB ::::: touch
# the ----> DET ::::: the
# arrow ----> NOUN ::::: arrow
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Gio ----> PROPN ::::: Gio
# : ----> PUNCT ::::: :
# Mista ----> PROPN ::::: Mista
# , ----> PUNCT ::::: ,
# run ----> NOUN ::::: run
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Mista ----> PROPN ::::: Mista
# : ----> PUNCT ::::: :
# Reload ----> VERB ::::: reload
# , ----> PUNCT ::::: ,
# b*ll*ts ----> NOUN ::::: b*ll*ts
# ! ----> PUNCT ::::: !
# Reload ----> VERB ::::: reload
# the ----> DET ::::: the
# g*n ----> PROPN ::::: g*n
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# B*llet ----> PROPN ::::: B*llet
# : ----> PUNCT ::::: :
# This ----> PRON ::::: this
# is ----> AUX ::::: be
# n't ----> PART ::::: not
# a ----> DET ::::: a
# revolver ----> NOUN ::::: revolver
# ! ----> PUNCT ::::: !
# We ----> PRON ::::: we
# need ----> VERB ::::: need
# another ----> DET ::::: another
# cartridge ----> NOUN ::::: cartridge
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# B*llet ----> PROPN ::::: B*llet
# : ----> PUNCT ::::: :
# It ----> PRON ::::: it
# 'll ----> AUX ::::: will
# take ----> VERB ::::: take
# time ----> NOUN ::::: time
# to ----> PART ::::: to
# reload ----> VERB ::::: reload
# it ----> PRON ::::: it
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Turtle ----> NOUN ::::: turtle
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# - ----> PUNCT ::::: -
# It ----> PRON ::::: it
# 's ----> AUX ::::: be
# no ----> DET ::::: no
# use ----> NOUN ::::: use
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# JoJo ----> PROPN ::::: JoJo
# - ----> PUNCT ::::: -
# main ----> ADJ ::::: main
# : ----> PUNCT ::::: :
# , ----> PUNCT ::::: ,
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# finished ----> VERB ::::: finish
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Trish ----> PROPN ::::: Trish
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# throwing ----> VERB ::::: throw
# it ----> PRON ::::: it
# ! ----> PUNCT ::::: !
# Catch ----> VERB ::::: catch
# it ----> PRON ::::: it
# , ----> PUNCT ::::: ,
# Giorno ----> PROPN ::::: Giorno
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Trish ----> PROPN ::::: Trish
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# gon ----> VERB ::::: go
# na ----> PART ::::: to
# throw ----> VERB ::::: throw
# the ----> DET ::::: the
# turtle ----> NOUN ::::: turtle
# to ----> ADP ::::: to
# you ----> PRON ::::: you
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Trish ----> PROPN ::::: Trish
# : ----> PUNCT ::::: :
# Mr. ----> PROPN ::::: Mr.
# Polnareff ----> PROPN ::::: Polnareff
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Trish ----> PROPN ::::: Trish
# : ----> PUNCT ::::: :
# You ----> PRON ::::: you
# okay ----> INTJ ::::: okay
# , ----> PUNCT ::::: ,
# Mr. ----> PROPN ::::: Mr.
# Polnareff ----> PROPN ::::: Polnareff
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Mista ----> PROPN ::::: Mista
# : ----> PUNCT ::::: :
# He ----> PRON ::::: he
# 's ----> AUX ::::: be
# okay ----> ADJ ::::: okay
# . ----> PUNCT ::::: .
# B ----> NOUN ::::: b
# - ----> PUNCT ::::: -
# But ----> CCONJ ::::: but
# ... ----> PUNCT ::::: ...
# how ----> SCONJ ::::: how
# ? ----> ADP ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Turtle ----> PROPN ::::: Turtle
# : ----> PUNCT ::::: :
# Mista ----> PROPN ::::: Mista
# , ----> PUNCT ::::: ,
# do ----> AUX ::::: do
# you ----> PRON ::::: you
# remember ----> VERB ::::: remember
# what ----> PRON ::::: what
# I ----> PRON ::::: I
# said ----> VERB ::::: say
# back ----> ADV ::::: back
# at ----> ADP ::::: at
# the ----> DET ::::: the
# Colosseum ----> PROPN ::::: Colosseum
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Turtle ----> NOUN ::::: turtle
# : ----> PUNCT ::::: :
# There ----> PRON ::::: there
# 's ----> VERB ::::: be
# still ----> ADV ::::: still
# more ----> ADJ ::::: more
# to ----> ADP ::::: to
# Requiem ----> PROPN ::::: Requiem
# 's ----> PART ::::: 's
# ability ----> NOUN ::::: ability
# that ----> PRON ::::: that
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# not ----> PART ::::: not
# aware ----> ADJ ::::: aware
# of ----> ADP ::::: of
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Turtle ----> PROPN ::::: Turtle
# : ----> PUNCT ::::: :
# But ----> CCONJ ::::: but
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# starting ----> VERB ::::: start
# to ----> PART ::::: to
# understand ----> VERB ::::: understand
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Turtle ----> NOUN ::::: turtle
# : ----> PUNCT ::::: :
# Requiem ----> PROPN ::::: Requiem
# stopped ----> VERB ::::: stop
# because ----> SCONJ ::::: because
# the ----> DET ::::: the
# starting ----> NOUN ::::: starting
# time ----> NOUN ::::: time
# has ----> AUX ::::: have
# come ----> VERB ::::: come
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Trish ----> PROPN ::::: Trish
# : ----> PUNCT ::::: :
# The ----> DET ::::: the
# starting ----> NOUN ::::: starting
# time ----> NOUN ::::: time
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Turtle ----> NOUN ::::: turtle
# : ----> PUNCT ::::: :
# Yes ----> INTJ ::::: yes
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Turtle ----> PROPN ::::: Turtle
# : ----> PUNCT ::::: :
# It ----> PRON ::::: it
# 's ----> AUX ::::: be
# because ----> SCONJ ::::: because
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# JoJo ----> PROPN ::::: JoJo
# - ----> PUNCT ::::: -
# main ----> ADJ ::::: main
# : ----> PUNCT ::::: :
# , ----> PUNCT ::::: ,
# my ----> PRON ::::: my
# body ----> NOUN ::::: body
# has ----> AUX ::::: have
# started ----> VERB ::::: start
# to ----> PART ::::: to
# change ----> VERB ::::: change
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Turtle ----> PROPN ::::: Turtle
# : ----> PUNCT ::::: :
# That ----> PRON ::::: that
# 's ----> AUX ::::: be
# why ----> SCONJ ::::: why
# it ----> PRON ::::: it
# stopped ----> VERB ::::: stop
# trying ----> VERB ::::: try
# to ----> PART ::::: to
# k*ll ----> VERB ::::: k*ll
# me ----> PRON ::::: I
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Turtle ----> PROPN ::::: Turtle
# : ----> PUNCT ::::: :
# This ----> PRON ::::: this
# is ----> AUX ::::: be
# Requiem ----> PROPN ::::: Requiem
# 's ----> PART ::::: 's
# true ----> ADJ ::::: true
# motive ----> NOUN ::::: motive
# , ----> PUNCT ::::: ,
# now ----> ADV ::::: now
# that ----> SCONJ ::::: that
# it ----> PRON ::::: it
# 's ----> AUX ::::: be
# gone ----> VERB ::::: go
# berserk ----> ADJ ::::: berserk
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Turtle ----> PROPN ::::: Turtle
# : ----> PUNCT ::::: :
# The ----> DET ::::: the
# ability ----> NOUN ::::: ability
# to ----> PART ::::: to
# make ----> VERB ::::: make
# beings ----> NOUN ::::: being
# swap ----> VERB ::::: swap
# souls ----> NOUN ::::: soul
# , ----> PUNCT ::::: ,
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Turtle ----> PROPN ::::: Turtle
# : ----> PUNCT ::::: :
# meaning ----> VERB ::::: mean
# the ----> DET ::::: the
# ability ----> NOUN ::::: ability
# that ----> PRON ::::: that
# makes ----> VERB ::::: make
# them ----> PRON ::::: they
# start ----> VERB ::::: start
# to ----> PART ::::: to
# change ----> VERB ::::: change
# into ----> ADP ::::: into
# something ----> PRON ::::: something
# else ----> ADV ::::: else
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Turtle ----> PROPN ::::: Turtle
# : ----> PUNCT ::::: :
# The ----> DET ::::: the
# prelude ----> NOUN ::::: prelude
# is ----> AUX ::::: be
# over ----> ADV ::::: over
# , ----> PUNCT ::::: ,
# and ----> CCONJ ::::: and
# the ----> DET ::::: the
# actual ----> ADJ ::::: actual
# piece ----> NOUN ::::: piece
# is ----> AUX ::::: be
# now ----> ADV ::::: now
# starting ----> VERB ::::: start
# to ----> PART ::::: to
# play ----> VERB ::::: play
# , ----> PUNCT ::::: ,
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# JoJo ----> PROPN ::::: JoJo
# - ----> PUNCT ::::: -
# main ----> ADJ ::::: main
# : ----> PUNCT ::::: :
# , ----> PUNCT ::::: ,
# so ----> ADV ::::: so
# it ----> PRON ::::: it
# gave ----> VERB ::::: give
# up ----> ADP ::::: up
# on ----> ADP ::::: on
# k*lling ----> VERB ::::: k*lle
# me ----> PRON ::::: I
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Turtle ----> PROPN ::::: Turtle
# : ----> PUNCT ::::: :
# The ----> DET ::::: the
# .-billion ----> NOUN ::::: .-billion
# - ----> PUNCT ::::: -
# year ----> NOUN ::::: year
# history ----> NOUN ::::: history
# of ----> ADP ::::: of
# this ----> DET ::::: this
# world ----> NOUN ::::: world
# 's ----> PART ::::: 's
# creatures ----> NOUN ::::: creature
# is ----> AUX ::::: be
# starting ----> VERB ::::: start
# to ----> PART ::::: to
# change ----> VERB ::::: change
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Turtle ----> PROPN ::::: Turtle
# : ----> PUNCT ::::: :
# into ----> ADP ::::: into
# something ----> PRON ::::: something
# else ----> ADV ::::: else
# within ----> ADP ::::: within
# a ----> DET ::::: a
# matter ----> NOUN ::::: matter
# of ----> ADP ::::: of
# hours ----> NOUN ::::: hour
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Turtle ----> PROPN ::::: Turtle
# : ----> PUNCT ::::: :
# All ----> PRON ::::: all
# of ----> ADP ::::: of
# it ----> PRON ::::: it
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# King ----> PROPN ::::: King
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# see ----> VERB ::::: see
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# JoJo ----> PROPN ::::: JoJo
# - ----> PUNCT ::::: -
# internal ----> ADJ ::::: internal
# / ----> SYM ::::: /
# narrator ----> NOUN ::::: narrator
# : ----> PUNCT ::::: :
# , ----> PUNCT ::::: ,
# So ----> ADV ::::: so
# that ----> PRON ::::: that
# 's ----> AUX ::::: be
# what ----> PRON ::::: what
# makes ----> VERB ::::: make
# Requiem ----> PROPN ::::: Requiem
# so ----> ADV ::::: so
# truly ----> ADV ::::: truly
# frightening ----> ADJ ::::: frightening
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# King ----> NOUN ::::: king
# : ----> PUNCT ::::: :
# However ----> ADV ::::: however
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# King ----> NOUN ::::: king
# : ----> PUNCT ::::: :
# Thanks ----> NOUN ::::: thank
# to ----> ADP ::::: to
# them ----> PRON ::::: they
# , ----> PUNCT ::::: ,
# I ----> PRON ::::: I
# was ----> AUX ::::: be
# able ----> ADJ ::::: able
# to ----> PART ::::: to
# see ----> VERB ::::: see
# it ----> PRON ::::: it
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# King ----> PROPN ::::: King
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# starting ----> VERB ::::: start
# to ----> PART ::::: to
# understand ----> VERB ::::: understand
# the ----> DET ::::: the
# answer ----> NOUN ::::: answer
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# King ----> PROPN ::::: King
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# close ----> ADJ ::::: close
# to ----> ADP ::::: to
# figuring ----> VERB ::::: figure
# out ----> ADP ::::: out
# how ----> SCONJ ::::: how
# to ----> PART ::::: to
# get ----> VERB ::::: get
# that ----> DET ::::: that
# arrow ----> NOUN ::::: arrow
# from ----> ADP ::::: from
# Requiem ----> PROPN ::::: Requiem
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# King ----> PROPN ::::: King
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# realizing ----> VERB ::::: realize
# the ----> DET ::::: the
# method ----> NOUN ::::: method
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Trish ----> PROPN ::::: Trish
# : ----> PUNCT ::::: :
# Wh ----> PROPN ::::: Wh
# - ----> PUNCT ::::: -
# What ----> PRON ::::: what
# the ----> DET ::::: the
# hell ----> NOUN ::::: hell
# is ----> AUX ::::: be
# going ----> VERB ::::: go
# on ----> ADP ::::: on
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Trish ----> PROPN ::::: Trish
# : ----> PUNCT ::::: :
# What ----> PRON ::::: what
# 's ----> AUX ::::: be
# up ----> ADP ::::: up
# with ----> ADP ::::: with
# this ----> DET ::::: this
# ability ----> NOUN ::::: ability
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Trish ----> PROPN ::::: Trish
# : ----> PUNCT ::::: :
# How ----> SCONJ ::::: how
# far ----> ADV ::::: far
# has ----> AUX ::::: have
# this ----> DET ::::: this
# damn ----> ADJ ::::: damn
# thing ----> NOUN ::::: thing
# spread ----> VERB ::::: spread
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Mista ----> PROPN ::::: Mista
# : ----> PUNCT ::::: :
# It ----> PRON ::::: it
# does ----> AUX ::::: do
# n't ----> PART ::::: not
# look ----> VERB ::::: look
# like ----> SCONJ ::::: like
# they ----> PRON ::::: they
# 're ----> AUX ::::: be
# dying ----> VERB ::::: die
# or ----> CCONJ ::::: or
# in ----> ADP ::::: in
# pain ----> NOUN ::::: pain
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Mista ----> PROPN ::::: Mista
# : ----> PUNCT ::::: :
# Everyone ----> PRON ::::: everyone
# just ----> ADV ::::: just
# has ----> VERB ::::: have
# these ----> DET ::::: these
# vacant ----> ADJ ::::: vacant
# stares ----> NOUN ::::: stare
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Mista ----> PROPN ::::: Mista
# : ----> PUNCT ::::: :
# But ----> CCONJ ::::: but
# there ----> PRON ::::: there
# is ----> VERB ::::: be
# this ----> DET ::::: this
# fear ----> NOUN ::::: fear
# of ----> ADP ::::: of
# becoming ----> VERB ::::: become
# something ----> PRON ::::: something
# else ----> ADV ::::: else
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Mista ----> PROPN ::::: Mista
# : ----> PUNCT ::::: :
# The ----> DET ::::: the
# fear ----> NOUN ::::: fear
# that ----> PRON ::::: that
# , ----> PUNCT ::::: ,
# slowly ----> ADV ::::: slowly
# but ----> CCONJ ::::: but
# surely ----> ADV ::::: surely
# , ----> PUNCT ::::: ,
# both ----> CCONJ ::::: both
# my ----> PRON ::::: my
# body ----> NOUN ::::: body
# and ----> CCONJ ::::: and
# my ----> PRON ::::: my
# soul ----> NOUN ::::: soul
# are ----> AUX ::::: be
# going ----> VERB ::::: go
# to ----> PART ::::: to
# disappear ----> VERB ::::: disappear
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Dia ----> PROPN ::::: Dia
# : ----> PUNCT ::::: :
# Trish ----> PROPN ::::: Trish
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Mista ----> PROPN ::::: Mista
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# - ----> PUNCT ::::: -
# I'm ----> NOUN ::::: i'm
# fine ----> ADJ ::::: fine
# . ----> PUNCT ::::: .
# But ----> CCONJ ::::: but
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Turtle ----> NOUN ::::: turtle
# : ----> PUNCT ::::: :
# The ----> DET ::::: the
# starting ----> VERB ::::: start
# time ----> NOUN ::::: time
# is ----> AUX ::::: be
# imminent ----> ADJ ::::: imminent
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Turtle ----> PROPN ::::: Turtle
# : ----> PUNCT ::::: :
# It ----> PRON ::::: it
# will ----> AUX ::::: will
# happen ----> VERB ::::: happen
# differently ----> ADV ::::: differently
# for ----> ADP ::::: for
# each ----> PRON ::::: each
# of ----> ADP ::::: of
# us ----> PRON ::::: we
# , ----> PUNCT ::::: ,
# but ----> CCONJ ::::: but
# it ----> PRON ::::: it
# 'll ----> AUX ::::: will
# start ----> VERB ::::: start
# soon ----> ADV ::::: soon
# , ----> PUNCT ::::: ,
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# JoJo ----> PROPN ::::: JoJo
# - ----> PUNCT ::::: -
# main ----> ADJ ::::: main
# : ----> PUNCT ::::: :
# , ----> PUNCT ::::: ,
# for ----> ADP ::::: for
# all ----> PRON ::::: all
# of ----> ADP ::::: of
# us ----> PRON ::::: we
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Gio ----> PROPN ::::: Gio
# : ----> PUNCT ::::: :
# We ----> PRON ::::: we
# do ----> AUX ::::: do
# n't ----> PART ::::: not
# have ----> VERB ::::: have
# much ----> ADJ ::::: much
# time ----> NOUN ::::: time
# left ----> VERB ::::: leave
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# JoJo ----> PROPN ::::: JoJo
# - ----> PUNCT ::::: -
# main ----> ADJ ::::: main
# : ----> PUNCT ::::: :
# , ----> PUNCT ::::: ,
# That ----> PRON ::::: that
# 's ----> AUX ::::: be
# what ----> PRON ::::: what
# you ----> PRON ::::: you
# 're ----> AUX ::::: be
# saying ----> VERB ::::: say
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Mista ----> PROPN ::::: Mista
# : ----> PUNCT ::::: :
# Polnareff ----> PROPN ::::: Polnareff
# ! ----> PUNCT ::::: !
# This ----> PRON ::::: this
# is ----> AUX ::::: be
# happening ----> VERB ::::: happen
# because ----> SCONJ ::::: because
# you ----> PRON ::::: you
# brought ----> VERB ::::: bring
# the ----> DET ::::: the
# arrow ----> NOUN ::::: arrow
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Mista ----> PROPN ::::: Mista
# : ----> PUNCT ::::: :
# You ----> PRON ::::: you
# said ----> VERB ::::: say
# it ----> PRON ::::: it
# had ----> VERB ::::: have
# the ----> DET ::::: the
# power ----> NOUN ::::: power
# to ----> PART ::::: to
# defeat ----> VERB ::::: defeat
# the ----> DET ::::: the
# boss ----> NOUN ::::: boss
# , ----> PUNCT ::::: ,
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Mista ----> PROPN ::::: Mista
# : ----> PUNCT ::::: :
# but ----> CCONJ ::::: but
# instead ----> ADV ::::: instead
# , ----> PUNCT ::::: ,
# you ----> PRON ::::: you
# basically ----> ADV ::::: basically
# ended ----> VERB ::::: end
# us ----> PRON ::::: we
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Dia ----> PROPN ::::: Dia
# : ----> PUNCT ::::: :
# Stop ----> VERB ::::: stop
# ! ----> PUNCT ::::: !
# This ----> PRON ::::: this
# is ----> AUX ::::: be
# far ----> ADV ::::: far
# beyond ----> ADP ::::: beyond
# anyone ----> PRON ::::: anyone
# 's ----> PART ::::: 's
# expectations ----> NOUN ::::: expectation
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Dia ----> PROPN ::::: Dia
# : ----> PUNCT ::::: :
# It ----> PRON ::::: it
# 's ----> AUX ::::: be
# more ----> ADV ::::: more
# important ----> ADJ ::::: important
# that ----> SCONJ ::::: that
# we ----> PRON ::::: we
# find ----> VERB ::::: find
# a ----> DET ::::: a
# way ----> NOUN ::::: way
# to ----> PART ::::: to
# defeat ----> VERB ::::: defeat
# Requiem ----> PROPN ::::: Requiem
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# King ----> PROPN ::::: King
# : ----> PUNCT ::::: :
# That ----> PRON ::::: that
# 's ----> AUX ::::: be
# right ----> ADJ ::::: right
# . ----> PUNCT ::::: .
# Good ----> ADJ ::::: good
# . ----> PUNCT ::::: .
# Get ----> VERB ::::: get
# closer ----> ADV ::::: close
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# King ----> PROPN ::::: King
# : ----> PUNCT ::::: :
# Get ----> VERB ::::: get
# closer ----> ADJ ::::: close
# to ----> ADP ::::: to
# Requiem ----> PROPN ::::: Requiem
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# King ----> NOUN ::::: king
# : ----> PUNCT ::::: :
# If ----> SCONJ ::::: if
# we ----> PRON ::::: we
# get ----> VERB ::::: get
# closer ----> ADJ ::::: close
# , ----> PUNCT ::::: ,
# I ----> PRON ::::: I
# 'll ----> AUX ::::: will
# be ----> AUX ::::: be
# able ----> ADJ ::::: able
# to ----> PART ::::: to
# fully ----> ADV ::::: fully
# see ----> VERB ::::: see
# Requiem ----> PROPN ::::: Requiem
# 's ----> PART ::::: 's
# secrets ----> NOUN ::::: secret
# , ----> PUNCT ::::: ,
# because ----> SCONJ ::::: because
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# right ----> ADV ::::: right
# here ----> ADV ::::: here
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# King ----> PROPN ::::: King
# : ----> PUNCT ::::: :
# The ----> DET ::::: the
# arrow ----> NOUN ::::: arrow
# 's ----> PART ::::: 's
# power ----> NOUN ::::: power
# will ----> AUX ::::: will
# become ----> VERB ::::: become
# mine ----> PRON ::::: mine
# , ----> PUNCT ::::: ,
# and ----> CCONJ ::::: and
# the ----> DET ::::: the
# world ----> NOUN ::::: world
# will ----> AUX ::::: will
# grovel ----> VERB ::::: grovel
# at ----> ADP ::::: at
# my ----> PRON ::::: my
# feet ----> NOUN ::::: foot
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Dia ----> PROPN ::::: Dia
# : ----> PUNCT ::::: :
# After ----> ADP ::::: after
# it ----> PRON ::::: it
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# King ----> NOUN ::::: king
# : ----> PUNCT ::::: :
# Good ----> PROPN ::::: Good
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Gio ----> PROPN ::::: Gio
# : ----> PUNCT ::::: :
# Do ----> AUX ::::: do
# n't ----> PART ::::: not
# move ----> VERB ::::: move
# , ----> PUNCT ::::: ,
# Mista ----> PROPN ::::: Mista
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Gio ----> PROPN ::::: Gio
# : ----> PUNCT ::::: :
# Trish ----> PROPN ::::: Trish
# , ----> PUNCT ::::: ,
# Bucciarati ----> PROPN ::::: Bucciarati
# ! ----> PUNCT ::::: !
# Both ----> PRON ::::: both
# of ----> ADP ::::: of
# you ----> PRON ::::: you
# stay ----> VERB ::::: stay
# where ----> SCONJ ::::: where
# you ----> PRON ::::: you
# are ----> AUX ::::: be
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Gio ----> PROPN ::::: Gio
# : ----> PUNCT ::::: :
# Stay ----> VERB ::::: stay
# right ----> ADV ::::: right
# there ----> ADV ::::: there
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Trish ----> PROPN ::::: Trish
# : ----> PUNCT ::::: :
# Wha ----> PROPN ::::: Wha
# — ----> PUNCT ::::: —
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Gio ----> PROPN ::::: Gio
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# just ----> ADV ::::: just
# told ----> VERB ::::: tell
# you ----> PRON ::::: you
# not ----> PART ::::: not
# to ----> PART ::::: to
# move ----> VERB ::::: move
# , ----> PUNCT ::::: ,
# Mista ----> PROPN ::::: Mista
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Gio ----> PROPN ::::: Gio
# : ----> PUNCT ::::: :
# We ----> PRON ::::: we
# can ----> AUX ::::: can
# catch ----> VERB ::::: catch
# up ----> ADP ::::: up
# to ----> ADP ::::: to
# Requiem ----> PROPN ::::: Requiem
# in ----> ADP ::::: in
# a ----> DET ::::: a
# second ----> ADJ ::::: second
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Trish ----> PROPN ::::: Trish
# : ----> PUNCT ::::: :
# What ----> PRON ::::: what
# the ----> DET ::::: the
# hell ----> NOUN ::::: hell
# ? ----> PUNCT ::::: ?
# Shut ----> VERB ::::: shut
# up ----> ADP ::::: up
# , ----> PUNCT ::::: ,
# you ----> PRON ::::: you
# dumbass ----> VERB ::::: dumbass
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Mista ----> PROPN ::::: Mista
# : ----> PUNCT ::::: :
# My ----> PRON ::::: my
# body ----> NOUN ::::: body
# 's ----> AUX ::::: 's
# disappearing ----> VERB ::::: disappear
# already ----> ADV ::::: already
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Gio ----> PROPN ::::: Gio
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# picked ----> VERB ::::: pick
# up ----> ADP ::::: up
# your ----> PRON ::::: your
# revolver ----> NOUN ::::: revolver
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Gio ----> PROPN ::::: Gio
# : ----> PUNCT ::::: :
# The ----> DET ::::: the
# one ----> NOUN ::::: one
# that ----> PRON ::::: that
# you ----> PRON ::::: you
# said ----> VERB ::::: say
# broke ----> VERB ::::: break
# a ----> DET ::::: a
# moment ----> NOUN ::::: moment
# ago ----> ADV ::::: ago
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Gio ----> PROPN ::::: Gio
# : ----> PUNCT ::::: :
# This ----> DET ::::: this
# broken ----> ADJ ::::: broken
# part ----> NOUN ::::: part
# does ----> AUX ::::: do
# n't ----> PART ::::: not
# match ----> VERB ::::: match
# up ----> ADP ::::: up
# correctly ----> ADV ::::: correctly
# with ----> ADP ::::: with
# the ----> DET ::::: the
# rest ----> NOUN ::::: rest
# of ----> ADP ::::: of
# it ----> PRON ::::: it
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Gio ----> PROPN ::::: Gio
# : ----> PUNCT ::::: :
# If ----> SCONJ ::::: if
# it ----> PRON ::::: it
# just ----> ADV ::::: just
# broke ----> VERB ::::: break
# due ----> ADP ::::: due
# to ----> ADP ::::: to
# metal ----> NOUN ::::: metal
# fatigue ----> NOUN ::::: fatigue
# , ----> PUNCT ::::: ,
# they ----> PRON ::::: they
# should ----> AUX ::::: should
# still ----> ADV ::::: still
# fit ----> VERB ::::: fit
# together ----> ADV ::::: together
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Dia ----> PROPN ::::: Dia
# : ----> PUNCT ::::: :
# What ----> PRON ::::: what
# are ----> AUX ::::: be
# you ----> PRON ::::: you
# getting ----> VERB ::::: get
# at ----> ADP ::::: at
# , ----> PUNCT ::::: ,
# Giorno ----> PROPN ::::: Giorno
# ? ----> PROPN ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Gio ----> PROPN ::::: Gio
# : ----> PUNCT ::::: :
# Bucciarati ----> PROPN ::::: Bucciarati
# , ----> PUNCT ::::: ,
# I ----> PRON ::::: I
# need ----> VERB ::::: need
# you ----> PRON ::::: you
# to ----> PART ::::: to
# stay ----> VERB ::::: stay
# right ----> ADV ::::: right
# there ----> ADV ::::: there
# , ----> PUNCT ::::: ,
# too ----> ADV ::::: too
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Gio ----> PROPN ::::: Gio
# : ----> PUNCT ::::: :
# We ----> PRON ::::: we
# need ----> VERB ::::: need
# to ----> PART ::::: to
# keep ----> VERB ::::: keep
# a ----> DET ::::: a
# distance ----> NOUN ::::: distance
# from ----> ADP ::::: from
# each ----> DET ::::: each
# other ----> ADJ ::::: other
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Trish ----> PROPN ::::: Trish
# : ----> PUNCT ::::: :
# You ----> PRON ::::: you
# dumbass ----> ADV ::::: dumbass
# ! ----> PUNCT ::::: !
# Requiem ----> PROPN ::::: Requiem
# is ----> AUX ::::: be
# getting ----> VERB ::::: get
# away ----> ADP ::::: away
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Trish ----> PROPN ::::: Trish
# : ----> PUNCT ::::: :
# The ----> DET ::::: the
# b*ll*ts ----> PROPN ::::: b*ll*ts
# said ----> VERB ::::: say
# it ----> PRON ::::: it
# was ----> AUX ::::: be
# metal ----> NOUN ::::: metal
# fatigue ----> NOUN ::::: fatigue
# , ----> PUNCT ::::: ,
# so ----> SCONJ ::::: so
# it ----> PRON ::::: it
# 's ----> AUX ::::: be
# metal ----> NOUN ::::: metal
# fatigue ----> NOUN ::::: fatigue
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Trish ----> PROPN ::::: Trish
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# have ----> VERB ::::: have
# a ----> DET ::::: a
# new ----> ADJ ::::: new
# Beretta ----> PROPN ::::: Beretta
# , ----> PUNCT ::::: ,
# too ----> ADV ::::: too
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# B*llet ----> PROPN ::::: B*llet
# : ----> PUNCT ::::: :
# The ----> DET ::::: the
# parts ----> NOUN ::::: part
# are ----> AUX ::::: be
# n't ----> PART ::::: not
# matching ----> VERB ::::: match
# up ----> ADP ::::: up
# because ----> SCONJ ::::: because
# a ----> DET ::::: a
# piece ----> NOUN ::::: piece
# flew ----> VERB ::::: fly
# off ----> ADV ::::: off
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Gio ----> PROPN ::::: Gio
# : ----> PUNCT ::::: :
# That ----> PRON ::::: that
# could ----> AUX ::::: could
# be ----> AUX ::::: be
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Gio ----> PROPN ::::: Gio
# : ----> PUNCT ::::: :
# But ----> CCONJ ::::: but
# it ----> PRON ::::: it
# could ----> AUX ::::: could
# be ----> AUX ::::: be
# something ----> PRON ::::: something
# more ----> ADJ ::::: more
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Gio ----> PROPN ::::: Gio
# : ----> PUNCT ::::: :
# We ----> PRON ::::: we
# 'll ----> AUX ::::: will
# be ----> AUX ::::: be
# able ----> ADJ ::::: able
# to ----> PART ::::: to
# tell ----> VERB ::::: tell
# as ----> ADV ::::: as
# soon ----> ADV ::::: soon
# as ----> SCONJ ::::: as
# we ----> PRON ::::: we
# see ----> VERB ::::: see
# this ----> DET ::::: this
# lost ----> VERB ::::: lose
# piece ----> NOUN ::::: piece
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Gio ----> PROPN ::::: Gio
# : ----> PUNCT ::::: :
# Golden ----> PROPN ::::: Golden
# Wind ----> PROPN ::::: Wind
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# JoJo ----> PROPN ::::: JoJo
# - ----> PUNCT ::::: -
# main ----> ADJ ::::: main
# : ----> PUNCT ::::: :
# , ----> PUNCT ::::: ,
# I ----> PRON ::::: I
# gave ----> VERB ::::: give
# a ----> DET ::::: a
# part ----> NOUN ::::: part
# of ----> ADP ::::: of
# the ----> DET ::::: the
# g*n ----> PROPN ::::: g*n
# life ----> NOUN ::::: life
# and ----> CCONJ ::::: and
# let ----> VERB ::::: let
# it ----> PRON ::::: it
# loose ----> ADJ ::::: loose
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Gio ----> PROPN ::::: Gio
# : ----> PUNCT ::::: :
# Moles ----> NOUN ::::: mole
# are ----> AUX ::::: be
# basically ----> ADV ::::: basically
# blind ----> ADJ ::::: blind
# , ----> PUNCT ::::: ,
# but ----> CCONJ ::::: but
# their ----> PRON ::::: their
# sense ----> NOUN ::::: sense
# of ----> ADP ::::: of
# smell ----> NOUN ::::: smell
# is ----> AUX ::::: be
# unparalleled ----> ADJ ::::: unparalleled
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Gio ----> PROPN ::::: Gio
# : ----> PUNCT ::::: :
# Looks ----> VERB ::::: look
# like ----> SCONJ ::::: like
# it ----> PRON ::::: it
# 's ----> AUX ::::: be
# returned ----> VERB ::::: return
# , ----> PUNCT ::::: ,
# and ----> CCONJ ::::: and
# it ----> PRON ::::: it
# found ----> VERB ::::: find
# its ----> PRON ::::: its
# lost ----> ADJ ::::: lost
# piece ----> NOUN ::::: piece
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Crunch ----> PROPN ::::: Crunch
# , ----> PUNCT ::::: ,
# Sfx ----> PROPN ::::: Sfx
# : ----> PUNCT ::::: :
# { ----> PUNCT ::::: {
# \c&HBE&\c&HEF&}Fit ----> PROPN ::::: \c&HBE&\c&HEF&}Fit
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Trish ----> PROPN ::::: Trish
# : ----> PUNCT ::::: :
# H ----> PROPN ::::: H
# - ----> PUNCT ::::: -
# Hey ----> INTJ ::::: hey
# , ----> PUNCT ::::: ,
# wait ----> VERB ::::: wait
# a ----> DET ::::: a
# sec ----> PROPN ::::: sec
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# JoJo ----> PROPN ::::: JoJo
# - ----> PUNCT ::::: -
# main ----> ADJ ::::: main
# : ----> PUNCT ::::: :
# , ----> PUNCT ::::: ,
# Are ----> AUX ::::: be
# you ----> PRON ::::: you
# saying ----> VERB ::::: say
# someone ----> PRON ::::: someone
# just ----> ADV ::::: just
# used ----> VERB ::::: use
# immense ----> ADJ ::::: immense
# force ----> NOUN ::::: force
# to ----> PART ::::: to
# tear ----> VERB ::::: tear
# the ----> DET ::::: the
# g*n ----> PROPN ::::: g*n
# apart ----> ADV ::::: apart
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Trish ----> PROPN ::::: Trish
# : ----> PUNCT ::::: :
# Listen ----> VERB ::::: listen
# up ----> ADP ::::: up
# ! ----> PUNCT ::::: !
# The ----> DET ::::: the
# b*ll*ts ----> PROPN ::::: b*ll*ts
# and ----> CCONJ ::::: and
# I ----> PRON ::::: I
# are ----> AUX ::::: be
# very ----> ADV ::::: very
# clear ----> ADJ ::::: clear
# on ----> ADP ::::: on
# this ----> PRON ::::: this
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Trish ----> PROPN ::::: Trish
# : ----> PUNCT ::::: :
# There ----> PRON ::::: there
# 's ----> VERB ::::: be
# no ----> DET ::::: no
# one ----> NOUN ::::: one
# who ----> PRON ::::: who
# got ----> VERB ::::: get
# close ----> ADJ ::::: close
# to ----> ADP ::::: to
# me ----> PRON ::::: I
# in ----> ADP ::::: in
# this ----> DET ::::: this
# square ----> ADJ ::::: square
# — ----> PUNCT ::::: —
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Gio ----> PROPN ::::: Gio
# : ----> PUNCT ::::: :
# You ----> PRON ::::: you
# 're ----> AUX ::::: be
# exactly ----> ADV ::::: exactly
# right ----> ADJ ::::: right
# . ----> PUNCT ::::: .
# No ----> DET ::::: no
# one ----> NOUN ::::: one
# did ----> VERB ::::: do
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Gio ----> PROPN ::::: Gio
# : ----> PUNCT ::::: :
# That ----> PRON ::::: that
# 's ----> AUX ::::: be
# why ----> SCONJ ::::: why
# we ----> PRON ::::: we
# need ----> VERB ::::: need
# to ----> PART ::::: to
# stay ----> VERB ::::: stay
# apart ----> ADV ::::: apart
# from ----> ADP ::::: from
# each ----> DET ::::: each
# other ----> ADJ ::::: other
# , ----> PUNCT ::::: ,
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# JoJo ----> PROPN ::::: JoJo
# - ----> PUNCT ::::: -
# main ----> ADJ ::::: main
# : ----> PUNCT ::::: :
# , ----> PUNCT ::::: ,
# because ----> SCONJ ::::: because
# his ----> PRON ::::: his
# range ----> NOUN ::::: range
# is ----> AUX ::::: be
# only ----> ADV ::::: only
# a ----> DET ::::: a
# few ----> ADJ ::::: few
# meters ----> NOUN ::::: meter
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Dia ----> PROPN ::::: Dia
# : ----> PUNCT ::::: :
# Giorno ----> PROPN ::::: Giorno
# , ----> PUNCT ::::: ,
# you ----> PRON ::::: you
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Gio ----> PROPN ::::: Gio
# : ----> PUNCT ::::: :
# No ----> DET ::::: no
# one ----> NOUN ::::: one
# got ----> VERB ::::: get
# close ----> ADJ ::::: close
# to ----> ADP ::::: to
# Narancia ----> PROPN ::::: Narancia
# when ----> SCONJ ::::: when
# he ----> PRON ::::: he
# was ----> AUX ::::: be
# attacked ----> VERB ::::: attack
# , ----> PUNCT ::::: ,
# either ----> ADV ::::: either
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Gio ----> PROPN ::::: Gio
# : ----> PUNCT ::::: :
# No ----> DET ::::: no
# one ----> NOUN ::::: one
# ... ----> PUNCT ::::: ...
# other ----> ADJ ::::: other
# than ----> ADP ::::: than
# us ----> PRON ::::: we
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Gio ----> PROPN ::::: Gio
# : ----> PUNCT ::::: :
# Mr. ----> PROPN ::::: Mr.
# Polnareff ----> PROPN ::::: Polnareff
# , ----> PUNCT ::::: ,
# if ----> SCONJ ::::: if
# your ----> PRON ::::: your
# guess ----> NOUN ::::: guess
# is ----> AUX ::::: be
# correct ----> ADJ ::::: correct
# and ----> CCONJ ::::: and
# the ----> DET ::::: the
# boss ----> NOUN ::::: boss
# had ----> VERB ::::: have
# two ----> NUM ::::: two
# personalities ----> NOUN ::::: personality
# , ----> PUNCT ::::: ,
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Gio ----> PROPN ::::: Gio
# : ----> PUNCT ::::: :
# then ----> ADV ::::: then
# he ----> PRON ::::: he
# should ----> AUX ::::: should
# be ----> AUX ::::: be
# able ----> ADJ ::::: able
# to ----> PART ::::: to
# get ----> VERB ::::: get
# in ----> ADP ::::: in
# and ----> CCONJ ::::: and
# out ----> ADP ::::: out
# of ----> ADP ::::: of
# another ----> PRON ::::: another
# 's ----> PART ::::: 's
# mind ----> NOUN ::::: mind
# freely ----> ADV ::::: freely
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Gio ----> PROPN ::::: Gio
# : ----> PUNCT ::::: :
# Diavolo ----> PROPN ::::: Diavolo
# has ----> AUX ::::: have
# inhabited ----> VERB ::::: inhabit
# one ----> NUM ::::: one
# of ----> ADP ::::: of
# us ----> PRON ::::: we
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Trish ----> PROPN ::::: Trish
# : ----> PUNCT ::::: :
# Wha ----> PROPN ::::: Wha
# — ----> PUNCT ::::: —
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Gio ----> PROPN ::::: Gio
# : ----> PUNCT ::::: :
# If ----> SCONJ ::::: if
# he ----> PRON ::::: he
# stays ----> VERB ::::: stay
# hidden ----> ADJ ::::: hidden
# , ----> PUNCT ::::: ,
# Trish ----> PROPN ::::: Trish
# ca ----> AUX ::::: can
# n't ----> PART ::::: not
# detect ----> VERB ::::: detect
# his ----> PRON ::::: his
# existence ----> NOUN ::::: existence
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Gio ----> PROPN ::::: Gio
# : ----> PUNCT ::::: :
# The ----> DET ::::: the
# reason ----> NOUN ::::: reason
# he ----> PRON ::::: he
# 's ----> AUX ::::: be
# staying ----> AUX ::::: staying
# hidden ----> VERB ::::: hide
# now ----> ADV ::::: now
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# JoJo ----> PROPN ::::: JoJo
# - ----> PUNCT ::::: -
# main ----> ADJ ::::: main
# : ----> PUNCT ::::: :
# , ----> PUNCT ::::: ,
# is ----> AUX ::::: be
# because ----> SCONJ ::::: because
# he ----> PRON ::::: he
# 's ----> AUX ::::: be
# waiting ----> VERB ::::: wait
# for ----> SCONJ ::::: for
# us ----> PRON ::::: we
# to ----> PART ::::: to
# obtain ----> VERB ::::: obtain
# the ----> DET ::::: the
# ...
# is ----> AUX ::::: be
# good ----> ADJ ::::: good
# , ----> PUNCT ::::: ,
# so ----> ADV ::::: so
# far ----> ADV ::::: far
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Gio ----> PROPN ::::: Gio
# : ----> PUNCT ::::: :
# Let ----> VERB ::::: let
# 's ----> PRON ::::: us
# go ----> VERB ::::: go
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# JoJo ----> PROPN ::::: JoJo
# - ----> PUNCT ::::: -
# main ----> ADJ ::::: main
# : ----> PUNCT ::::: :
# , ----> PUNCT ::::: ,
# We ----> PRON ::::: we
# have ----> VERB ::::: have
# to ----> PART ::::: to
# hurry ----> VERB ::::: hurry
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Dia ----> PROPN ::::: Dia
# : ----> PUNCT ::::: :
# Blast ----> NOUN ::::: blast
# the ----> DET ::::: the
# arrow ----> NOUN ::::: arrow
# away ----> ADV ::::: away
# from ----> ADP ::::: from
# him ----> PRON ::::: he
# ! ----> PUNCT ::::: !
# Do ----> AUX ::::: do
# n't ----> PART ::::: not
# let ----> VERB ::::: let
# him ----> PRON ::::: he
# grab ----> VERB ::::: grab
# it ----> PRON ::::: it
# , ----> PUNCT ::::: ,
# Mista ----> PROPN ::::: Mista
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Trish ----> PROPN ::::: Trish
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# already ----> ADV ::::: already
# shooting ----> VERB ::::: shoot
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Trish ----> PROPN ::::: Trish
# : ----> PUNCT ::::: :
# They ----> PRON ::::: they
# made ----> VERB ::::: make
# it ----> PRON ::::: it
# through ----> ADP ::::: through
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# JoJo ----> PROPN ::::: JoJo
# - ----> PUNCT ::::: -
# main ----> ADJ ::::: main
# : ----> PUNCT ::::: :
# , ----> PUNCT ::::: ,
# Despite ----> SCONJ ::::: despite
# him ----> PRON ::::: he
# predicting ----> VERB ::::: predict
# their ----> PRON ::::: their
# movements ----> NOUN ::::: movement
# , ----> PUNCT ::::: ,
# we ----> PRON ::::: we
# 're ----> AUX ::::: be
# still ----> ADV ::::: still
# far ----> ADV ::::: far
# apart ----> ADV ::::: apart
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Trish ----> PROPN ::::: Trish
# : ----> PUNCT ::::: :
# He ----> PRON ::::: he
# can ----> AUX ::::: can
# only ----> ADV ::::: only
# knock ----> VERB ::::: knock
# the ----> DET ::::: the
# ones ----> NOUN ::::: one
# coming ----> VERB ::::: come
# at ----> ADP ::::: at
# him ----> PRON ::::: he
# out ----> ADP ::::: out
# of ----> ADP ::::: of
# their ----> PRON ::::: their
# trajectory ----> NOUN ::::: trajectory
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Trish ----> PROPN ::::: Trish
# : ----> PUNCT ::::: :
# The ----> DET ::::: the
# rest ----> NOUN ::::: rest
# of ----> ADP ::::: of
# you ----> PRON ::::: you
# knock ----> VERB ::::: knock
# that ----> DET ::::: that
# arrow ----> NOUN ::::: arrow
# back ----> ADV ::::: back
# and ----> CCONJ ::::: and
# bring ----> VERB ::::: bring
# it ----> PRON ::::: it
# to ----> ADP ::::: to
# me ----> PRON ::::: I
# , ----> PUNCT ::::: ,
# b*ll*ts ----> PROPN ::::: b*ll*ts
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Bull ----> PROPN ::::: Bull
# : ----> PUNCT ::::: :
# H ----> PROPN ::::: H
# - ----> PUNCT ::::: -
# He'd ----> PROPN ::::: He'd
# already ----> ADV ::::: already
# thrown ----> VERB ::::: throw
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Bull ----> PROPN ::::: Bull
# : ----> PUNCT ::::: :
# ... ----> PUNCT ::::: ...
# a ----> DET ::::: a
# civilian ----> NOUN ::::: civilian
# into ----> ADP ::::: into
# the ----> DET ::::: the
# air ----> NOUN ::::: air
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Bull ----> PROPN ::::: Bull
# : ----> PUNCT ::::: :
# He ----> PRON ::::: he
# figured ----> VERB ::::: figure
# out ----> ADP ::::: out
# the ----> DET ::::: the
# b*ll*ts ----> PROPN ::::: b*ll*ts
# would ----> AUX ::::: would
# land ----> VERB ::::: land
# and ----> CCONJ ::::: and
# returned ----> VERB ::::: return
# the ----> DET ::::: the
# arrow ----> NOUN ::::: arrow
# to ----> ADP ::::: to
# its ----> PRON ::::: its
# place ----> NOUN ::::: place
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# King ----> PROPN ::::: King
# : ----> PUNCT ::::: :
# The ----> DET ::::: the
# trash ----> NOUN ::::: trash
# ability ----> NOUN ::::: ability
# of ----> ADP ::::: of
# an ----> DET ::::: an
# underling ----> ADJ ::::: underling
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# King ----> NOUN ::::: king
# : ----> PUNCT ::::: :
# There ----> PRON ::::: there
# 's ----> VERB ::::: be
# no ----> DET ::::: no
# way ----> NOUN ::::: way
# your ----> PRON ::::: your
# weak ----> ADJ ::::: weak
# mind ----> NOUN ::::: mind
# can ----> AUX ::::: can
# surpass ----> VERB ::::: surpass
# Emperor ----> PROPN ::::: Emperor
# Crimson ----> PROPN ::::: Crimson
# 's ----> PART ::::: 's
# predictions ----> NOUN ::::: prediction
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# King ----> PROPN ::::: King
# : ----> PUNCT ::::: :
# You ----> PRON ::::: you
# will ----> AUX ::::: will
# not ----> PART ::::: not
# be ----> AUX ::::: be
# able ----> ADJ ::::: able
# to ----> PART ::::: to
# get ----> VERB ::::: get
# through ----> ADP ::::: through
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# King ----> PROPN ::::: King
# : ----> PUNCT ::::: :
# You ----> PRON ::::: you
# 're ----> AUX ::::: be
# still ----> ADV ::::: still
# just ----> ADV ::::: just
# trash ----> VERB ::::: trash
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# King ----> PROPN ::::: King
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# will ----> AUX ::::: will
# admit ----> VERB ::::: admit
# though ----> ADV ::::: though
# , ----> PUNCT ::::: ,
# Bucciarati ----> PROPN ::::: Bucciarati
# , ----> PUNCT ::::: ,
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# King ----> NOUN ::::: king
# : ----> PUNCT ::::: :
# your ----> PRON ::::: your
# team ----> NOUN ::::: team
# has ----> AUX ::::: have
# made ----> VERB ::::: make
# me ----> PRON ::::: I
# sweat ----> VERB ::::: sweat
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# King ----> PROPN ::::: King
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# never ----> ADV ::::: never
# dreamed ----> VERB ::::: dream
# you ----> PRON ::::: you
# would ----> AUX ::::: would
# be ----> AUX ::::: be
# foolish ----> ADJ ::::: foolish
# enough ----> ADV ::::: enough
# to ----> PART ::::: to
# betray ----> VERB ::::: betray
# the ----> DET ::::: the
# organization ----> NOUN ::::: organization
# , ----> PUNCT ::::: ,
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# King ----> NOUN ::::: king
# : ----> PUNCT ::::: :
# nor ----> CCONJ ::::: nor
# did ----> AUX ::::: do
# I ----> PRON ::::: I
# ever ----> ADV ::::: ever
# think ----> VERB ::::: think
# you ----> PRON ::::: you
# 'd ----> AUX ::::: would
# find ----> VERB ::::: find
# out ----> ADP ::::: out
# my ----> PRON ::::: my
# true ----> ADJ ::::: true
# identity ----> NOUN ::::: identity
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# King ----> NOUN ::::: king
# : ----> PUNCT ::::: :
# But ----> CCONJ ::::: but
# the ----> DET ::::: the
# fact ----> NOUN ::::: fact
# that ----> SCONJ ::::: that
# I ----> PRON ::::: I
# 've ----> AUX ::::: have
# been ----> AUX ::::: be
# able ----> ADJ ::::: able
# to ----> PART ::::: to
# figure ----> VERB ::::: figure
# out ----> ADP ::::: out
# this ----> DET ::::: this
# arrow ----> NOUN ::::: arrow
# 's ----> PART ::::: 's
# true ----> ADJ ::::: true
# power ----> NOUN ::::: power
# is ----> AUX ::::: be
# a ----> DET ::::: a
# blessing ----> NOUN ::::: blessing
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# King ----> NOUN ::::: king
# : ----> PUNCT ::::: :
# It ----> PRON ::::: it
# 's ----> AUX ::::: be
# a ----> DET ::::: a
# gift ----> NOUN ::::: gift
# granted ----> VERB ::::: grant
# to ----> ADP ::::: to
# me ----> PRON ::::: I
# by ----> ADP ::::: by
# fate ----> NOUN ::::: fate
# because ----> SCONJ ::::: because
# I ----> PRON ::::: I
# was ----> AUX ::::: be
# able ----> ADJ ::::: able
# to ----> PART ::::: to
# defeat ----> VERB ::::: defeat
# my ----> PRON ::::: my
# past ----> NOUN ::::: past
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Trish ----> PROPN ::::: Trish
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# need ----> VERB ::::: need
# a*mo ----> PROPN ::::: a*mo
# , ----> PUNCT ::::: ,
# b*ll*ts ----> PROPN ::::: b*ll*ts
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# B*llet ----> VERB ::::: b*llet
# : ----> PUNCT ::::: :
# We ----> PRON ::::: we
# told ----> VERB ::::: tell
# you ----> PRON ::::: you
# , ----> PUNCT ::::: ,
# Mista ----> PROPN ::::: Mista
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# B*llet ----> PROPN ::::: B*llet
# : ----> PUNCT ::::: :
# It ----> PRON ::::: it
# takes ----> VERB ::::: take
# time ----> NOUN ::::: time
# to ----> PART ::::: to
# reload ----> VERB ::::: reload
# that ----> DET ::::: that
# cartridge ----> NOUN ::::: cartridge
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Trish ----> PROPN ::::: Trish
# : ----> PUNCT ::::: :
# We ----> PRON ::::: we
# 're ----> AUX ::::: be
# finished ----> VERB ::::: finish
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# King ----> NOUN ::::: king
# : ----> PUNCT ::::: :
# Wh ----> PROPN ::::: Wh
# - ----> PUNCT ::::: -
# What ----> PRON ::::: what
# in ----> ADP ::::: in
# the ----> DET ::::: the
# world ----> NOUN ::::: world
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Mista ----> PROPN ::::: Mista
# : ----> PUNCT ::::: :
# Spicy ----> PROPN ::::: Spicy
# ... ----> PROPN ::::: ...
# Lady ----> PROPN ::::: Lady
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Trish ----> PROPN ::::: Trish
# : ----> PUNCT ::::: :
# You ----> PRON ::::: you
# did ----> AUX ::::: do
# n't ----> PART ::::: not
# deflect ----> VERB ::::: deflect
# Mista ----> PROPN ::::: Mista
# 's ----> PART ::::: 's
# b*ll*ts ----> NOUN ::::: b*ll*ts
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Trish ----> PROPN ::::: Trish
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# just ----> ADV ::::: just
# made ----> VERB ::::: make
# them ----> PRON ::::: they
# softer ----> ADJ ::::: soft
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Trish ----> PROPN ::::: Trish
# : ----> PUNCT ::::: :
# The ----> DET ::::: the
# b*ll*ts ----> NOUN ::::: b*ll*ts
# stretched ----> VERB ::::: stretch
# out ----> ADP ::::: out
# like ----> ADP ::::: like
# chewing ----> VERB ::::: chew
# gum ----> NOUN ::::: gum
# and ----> CCONJ ::::: and
# stuck ----> VERB ::::: stick
# to ----> ADP ::::: to
# your ----> PRON ::::: your
# hand ----> NOUN ::::: hand
# , ----> PUNCT ::::: ,
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Trish ----> PROPN ::::: Trish
# : ----> PUNCT ::::: :
# and ----> CCONJ ::::: and
# I ----> PRON ::::: I
# had ----> VERB ::::: have
# them ----> PRON ::::: they
# use ----> VERB ::::: use
# their ----> PRON ::::: their
# elastic ----> ADJ ::::: elastic
# force ----> NOUN ::::: force
# to ----> PART ::::: to
# return ----> VERB ::::: return
# and ----> CCONJ ::::: and
# blow ----> VERB ::::: blow
# through ----> ADP ::::: through
# it ----> PRON ::::: it
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# King ----> PROPN ::::: King
# : ----> PUNCT ::::: :
# Trish ----> PROPN ::::: Trish
# ... ----> PUNCT ::::: ...
# You ----> PRON ::::: you
# 're ----> AUX ::::: be
# still ----> ADV ::::: still
# conscious ----> ADJ ::::: conscious
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Trish ----> PROPN ::::: Trish
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# going ----> VERB ::::: go
# to ----> PART ::::: to
# overcome ----> VERB ::::: overcome
# this ----> PRON ::::: this
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Trish ----> PROPN ::::: Trish
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# not ----> PART ::::: not
# going ----> VERB ::::: go
# to ----> PART ::::: to
# live ----> VERB ::::: live
# in ----> ADP ::::: in
# fear ----> NOUN ::::: fear
# and ----> CCONJ ::::: and
# run ----> VERB ::::: run
# away ----> ADV ::::: away
# from ----> ADP ::::: from
# the ----> DET ::::: the
# fate ----> NOUN ::::: fate
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# JoJo ----> PROPN ::::: JoJo
# - ----> PUNCT ::::: -
# main ----> ADJ ::::: main
# : ----> PUNCT ::::: :
# , ----> PUNCT ::::: ,
# that ----> SCONJ ::::: that
# you ----> PRON ::::: you
# 've ----> AUX ::::: have
# passed ----> VERB ::::: pass
# on ----> ADP ::::: on
# to ----> ADP ::::: to
# me ----> PRON ::::: I
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Trish ----> PROPN ::::: Trish
# : ----> PUNCT ::::: :
# If ----> SCONJ ::::: if
# it ----> PRON ::::: it
# 's ----> AUX ::::: be
# in ----> ADP ::::: in
# my ----> PRON ::::: my
# way ----> NOUN ::::: way
# , ----> PUNCT ::::: ,
# I ----> PRON ::::: I
# 'll ----> AUX ::::: will
# just ----> ADV ::::: just
# climb ----> VERB ::::: climb
# over ----> ADP ::::: over
# it ----> PRON ::::: it
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Trish ----> PROPN ::::: Trish
# : ----> PUNCT ::::: :
# The ----> DET ::::: the
# arrow ----> NOUN ::::: arrow
# 's ----> AUX ::::: 's
# flying ----> VERB ::::: fly
# toward ----> ADP ::::: toward
# me ----> PRON ::::: I
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Trish ----> PROPN ::::: Trish
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# the ----> DET ::::: the
# closest ----> ADJ ::::: close
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Trish ----> PROPN ::::: Trish
# : ----> PUNCT ::::: :
# He ----> PRON ::::: he
# ca ----> AUX ::::: can
# n't ----> PART ::::: not
# get ----> VERB ::::: get
# past ----> ADP ::::: past
# me ----> PRON ::::: I
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Trish ----> PROPN ::::: Trish
# : ----> PUNCT ::::: :
# Even ----> ADV ::::: even
# if ----> SCONJ ::::: if
# he ----> PRON ::::: he
# predicts ----> VERB ::::: predict
# where ----> SCONJ ::::: where
# it ----> PRON ::::: it
# 'll ----> AUX ::::: will
# fall ----> VERB ::::: fall
# and ----> CCONJ ::::: and
# erases ----> VERB ::::: erase
# time ----> NOUN ::::: time
# , ----> PUNCT ::::: ,
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Trish ----> PROPN ::::: Trish
# : ----> PUNCT ::::: :
# I ----> PRON ::::: I
# 'm ----> AUX ::::: be
# still ----> ADV ::::: still
# closer ----> ADJ ::::: close
# to ----> ADP ::::: to
# it ----> PRON ::::: it
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# King ----> NOUN ::::: king
# : ----> PUNCT ::::: :
# If ----> SCONJ ::::: if
# only ----> ADV ::::: only
# ... ----> PUNCT ::::: ...
# My ----> PRON ::::: my
# daughter ----> NOUN ::::: daughter
# , ----> PUNCT ::::: ,
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# King ----> NOUN ::::: king
# : ----> PUNCT ::::: :
# if ----> SCONJ ::::: if
# only ----> ADV ::::: only
# you ----> PRON ::::: you
# had ----> AUX ::::: have
# n't ----> PART ::::: not
# been ----> AUX ::::: be
# born ----> VERB ::::: bear
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# King ----> NOUN ::::: king
# : ----> PUNCT ::::: :
# Fear ----> NOUN ::::: fear
# truly ----> ADV ::::: truly
# does ----> AUX ::::: do
# come ----> VERB ::::: come
# from ----> ADP ::::: from
# the ----> DET ::::: the
# past ----> NOUN ::::: past
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# King ----> PROPN ::::: King
# : ----> PUNCT ::::: :
# You ----> PRON ::::: you
# have ----> AUX ::::: have
# genuinely ----> ADV ::::: genuinely
# angered ----> VERB ::::: anger
# me ----> PRON ::::: I
# ! ----> PUNCT ::::: !
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Gio ----> PROPN ::::: Gio
# : ----> PUNCT ::::: :
# What ----> PRON ::::: what
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Crunch ----> PROPN ::::: Crunch
# , ----> PUNCT ::::: ,
# Sfx ----> PROPN ::::: Sfx
# : ----> PUNCT ::::: :
# { ----> PUNCT ::::: {
# \c&HFD&\c&H&}Booooom ----> PROPN ::::: \c&HFD&\c&H&}Booooom
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# King ----> PROPN ::::: King
# : ----> PUNCT ::::: :
# You ----> PRON ::::: you
# said ----> VERB ::::: say
# you ----> PRON ::::: you
# 'd ----> AUX ::::: would
# overcome ----> VERB ::::: overcome
# this ----> PRON ::::: this
# , ----> PUNCT ::::: ,
# did ----> VERB ::::: do
# you ----> PRON ::::: you
# not ----> PART ::::: not
# ? ----> PUNCT ::::: ?
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# King ----> NOUN ::::: king
# : ----> PUNCT ::::: :
# You ----> PRON ::::: you
# were ----> AUX ::::: be
# right ----> ADJ ::::: right
# , ----> PUNCT ::::: ,
# Trish ----> PROPN ::::: Trish
# . ----> PUNCT ::::: .
# Now ----> ADV ::::: now
# you ----> PRON ::::: you
# can ----> AUX ::::: can
# surpass ----> VERB ::::: surpass
# not ----> PART ::::: not
# only ----> ADV ::::: only
# the ----> DET ::::: the
# past ----> NOUN ::::: past
# ... ----> PUNCT ::::: ...
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# King ----> NOUN ::::: king
# : ----> PUNCT ::::: :
# but ----> CCONJ ::::: but
# their ----> PRON ::::: their
# heads ----> NOUN ::::: head
# . ----> PUNCT ::::: .
#
#
#
#
#  ----> SPACE :::::
#
#
#
#
# Dia ----> PROPN ::::: Dia
# : ----> PUNCT ::::: :
# Trish ----> PROPN ::::: Trish
# ! ----> PUNCT ::::: !

# %%
spacy.explain("NUM")
# Out:
# 'numeral'

# %% [markdown]
# ### For spaCy: define a function to collect the words you want

# %%
def wordCollector(words):
    wordList = []
    count = 0
    for token in words:
        if token.pos_ == "VERB":
            count += 1
            # print(count, ": ", token.text, " lemma: ", token.lemma_, " pos: ", token.pos_)
            # don't forget the underscore after token.lemma_ , token.pos_, etc.!
            wordList.append(token.lemma_)
            # print(count, ": ", token, token.pos_)
    # print(count, ": ", adjectives)
    return wordList
myWords = wordCollector(spacyRead)
print(myWords)
# Out:
# ['use', 'get', 'feel', 'suck', 'say', 'have', 'go', 'go', 'go', 'win', 'call', 'have', 'escape', 'choose', 'remain', 'perish', 'exist', 'sing', 'vanish', 'hurry', 'pierce', 'go', 'head', 'stop', 'do', 'touch', 'let', 'go', 'let', 'go', 'take', 'get', 'think', 'talk', 'say', 'see', 'come', 'b*llet', 'see', 'break', 'overuse', 'break', 'have', 'doany', 'head', 'head', 'intend', 'finish', 'touch', 'reload', 'reload', 'need', 'take', 'reload', 'finish', 'throw', 'catch', 'go', 'throw', 'remember', 'say', 'be', 'start', 'understand', 'stop', 'come', 'start', 'change', 'stop', 'try', 'k*ll', 'go', 'make', 'swap', 'mean', 'make', 'start', 'change', 'start', 'play', 'give', 'k*lle', 'start', 'change', 'see', 'make', 'see', 'start', 'understand', 'figure', 'get', 'realize', 'go', 'spread', 'look', 'die', 'have', 'be', 'become', 'go', 'disappear', 'start', 'happen', 'start', 'have', 'leave', 'say', 'happen', 'bring', 'say', 'have', 'defeat', 'end', 'stop', 'find', 'defeat', 'get', 'get', 'get', 'see', 'become', 'grovel', 'move', 'stay', 'stay', 'tell', 'move', 'catch', 'shut', 'dumbass', 'disappear', 'pick', 'say', 'break', 'match', 'break', 'fit', 'get', 'need', 'stay', 'need', 'keep', 'get', 'say', 'have', 'match', 'fly', 'tell', 'see', 'lose', 'give', 'let', 'look', 'return', 'find', 'wait', 'say', 'use', 'tear', 'listen', 'be', 'get', 'do', 'need', 'stay', 'get', 'attack', 'have', 'get', 'inhabit', 'stay', 'detect', 'hide', 'wait', 'obtain', 'appear', 'destroy', 'know', 'keep', 'say', 'stay', 'stay', 'destroy', 'attack', 'do', 'keep', 'move', 'hide', 'have', 'make', 'appear', 'have', 'inhabit', 'have', 'inhabit', 'stay', 'manifest', 'move', 'live', 'eliminate', 'have', 'possess', 'k*lle', 'destroy', 'let', 'inhabit', 'put', 'sense', 'have', 'tell', 'get', 'touch', 'touch', 'tell', 'be', 'be', 'have', 'touch', 'find', 'go', 'get', 'learn', 'detect', 'increase', 'skip', 'avoid', 'dodge', 'k*lle', 'check', 'stop', 'stay', 'come', 'go', 'happen', 'die', 'travel', 'be', 'possess', 'say', 'have', 'confirm', 'mention', 'have', 'confirm', 'have', 'check', 'go', 'find', 'come', 'blow', 'stop', 'check', 'hurry', 'do', 'lose', 'say', 'depend', 'look', 'have', 'corner', 'be', 'have', 'do', 'go', 'attack', 'get', 'possess', 'get', 'move', 'wait', 'unleash', 'swap', 'have', 'mean', 'die', 'possess', '\\pos(.,)}giorno', 'reveal', 'corner', 'grab', 'move', 'make', 'run', 'go', 'attack', 'go', 'make', 'tell', 'run', 'attack', 'find', 'get', 'be', 'take', 'let', 'get', 'stop', 'waste', 'hesitate', 'fire', 'seem', 'fire', 'run', 'make', 'predict', 'get', 'finish', 'touch', 'move', 'move', 'mean', 'look', 'stretch', 'stretch', 'mean', 'depend', 'control', 'attack', 'mean', 'attack', 'rid', 'get', 'have', 'have', 'rush', 'destroy', 'get', 'have', 'find', 'grasp', 'take', 'tear', 'appear', 'happen', 'let', 'go', 'have', 'hurry', 'let', 'grab', 'shoot', 'make', 'predict', 'knock', 'come', 'knock', 'bring', 'throw', 'figure', 'land', 'return', 'be', 'surpass', 'get', 'trash', 'admit', 'make', 'sweat', 'dream', 'betray', 'think', 'find', 'figure', 'grant', 'defeat', 'need', 'b*llet', 'tell', 'take', 'reload', 'finish', 'deflect', 'make', 'stretch', 'chew', 'stick', 'have', 'use', 'return', 'blow', 'go', 'overcome', 'go', 'live', 'run', 'pass', 'climb', 'fly', 'get', 'predict', 'fall', 'erase', 'bear', 'come', 'anger', 'say', 'overcome', 'do', 'surpass']

# %% [markdown]
# ### Frequency of words
# Here is something we can do: Because we didn't make a set of unique words, we have a list full of the original words.
#
# The **Counter function** in python's collections library provides a speedy way to count the number of times something appears in a list!
#
# What we see in the output of this next cell is a special data structure in python: it's a list of tuples: `[('token', number), ('token', number), ...]`

# %%
from collections import Counter

word_freq = Counter(myWords)
# most_common() converts the Counter's dictionary to a tuple series and sorts it
ranked = word_freq.most_common()
# print(ranked)
topTen = word_freq.most_common()[:10]
# Hey DIGIT 210! This is called slicing a list! You're taking the first 10 or 20 items from the list
# you can also stick the 10 in most_common(10), to get the first ten entries. 

# Try uncommenting these others to see how they go:
print(topTen)
# lastTen = word_freq.most_common()[:-21:-1]
# This is slicing off the END of the list the bottom 20. 
# print(lastTen)
# Out:
# [('have', 25), ('get', 22), ('go', 19), ('say', 12), ('make', 10), ('be', 9), ('stay', 9), ('start', 8), ('move', 8), ('stop', 7)]

# %% [markdown]
# ## Write something to an output file (just text)
#
# Let's write that to an output file and save it, just to practice this.
# Set this to output in your workspace where you want it (same folder as this notebook or someplace new?)
# You can set a relative filepath if you want to be tidy and save things in an output folder...
#
# When you're saving output, Python (and most imperative programming languages) require that you first **open** the file you're going to be saving and set **w** for write.
# Here we're storing that opened file in a variable named `o`, and then **filling** it with the contents of your variable using `o.write()`.
# One more tricky thing: if we try to output `r` straight, we'll see an interesting error...run the cell to see it.

# %%
o = open("JojoverbFreq.txt", "w")
for r in ranked:
    o.write(r + "\n")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 o = open("JojoverbFreq.txt", "w")
#       2 for r in ranked:
# ----> 3     o.write(r + "\n")
#
# TypeError: can only concatenate tuple (not "str") to tuple

# %% [markdown]
# **Let's try that again...**
# The error message shows you what's wrong: Python won't print its super special tuple form to a file, so
# we convert it to a nice string with `str()`.
#
# **Update after April 8 2026 class**: There's another issue: running a "for loop" or "iterating" over the tuples.
# We need to format this properly to reach into the two parts of each tuple in order to output the whole tuple on each line:
# `for w, num in ranked:`
# That reaches each part of ("word", 15) within the tuple.

# %%
o = open("JoJoverbFreq.txt", "w")
for w, num in ranked:
    o.write(str(w) + ' :::: ' + str(num) + "\n")

# %% [markdown]
# Another way to do this is to **enumerate** the output so it can literally be numbered
# like we do in the next cell.

# %%
o = open("verbFreq2.txt", "w")
# ebb: on the next line, notice how we enumerate over the whole tuple: 
# the first variable will give us a position number, commonly known as an "index" called i.
for i, t in enumerate(ranked):
    o.write(str(i) + str(t) + "\n")

# %% [markdown]
# **Go browse in your local folder to find the output file and take a look at it.**
# Enumerating over tuples like this should output each one on its own line in ranked order based on our previous sorting!
#
# **Seeking extra credit just for fun?**
# We bet you could take that output and write an [invisible XML grammar](https://github.com/newtfire/textAnalysis-Hub/blob/main/Class-Examples/invisible_xml/iXMLstart.md) or regex search and replace to convert it to XML! Send us your grammar for the tuple list with this assignment. :-)

# %% [markdown]
# ## Plotting a simple chart with a Python Library
#
# We have data we can use to plot. There are SVG plotting libraries designed for Python, and one of the best for us working on websites is PyGal, since it's easy to customize and outputs a nice file for use on a website.
#
# Read the [PyGal documentation](https://www.pygal.org/en/stable/documentation/index.html) (or any plotting library you find) to see how you can adapt it as you wish.

# %%
import pygal
from pygal.style import DarkSolarizedStyle

# There are lots of chart types in pygal. Bar is a nice simple one:
bar_chart = pygal.Bar(style=DarkSolarizedStyle)
bar_chart.title = 'Top 10 Most Frequent Verbs in Sixteen Candles'

# Add data to the chart
for word, freq in topTen:
    bar_chart.add(word, freq)

# Render to file (SVG format)
bar_chart.render_to_file('top10_verbs.svg')

# %% [markdown]
# ### Go find the output SVG!
# ##### and go back and change the style :-)
# pygal's `render_to_file('....')` function is very convenient. Notice you don't have to open a file to write the output and all that, because pygal's function library is handling it.
#
# Remember to save your output file with the `.svg` output exgtension
#
# Open the output in a file browser on your computer. Like it? You can/should change the style to see how they look:
#
# * Check out the different types of plots (only you want to choose plot types that make sense for your data).
#   What else could you use? [PyGal documentation](https://www.pygal.org/en/stable/documentation/index.html)
#   * Notice that different plot types are looking for specific pieces of data.
# * Check out the styles: [PyGal Styles](https://www.pygal.org/en/stable/documentation/builtin_styles.html)
#
# You may want to change where you save this in your local workspace!

# %% [markdown]
# ### Send my list of words OR word lemmas to WordNet and get me synset info
#
# Okay, how about we try to connect this up with Wordnet to study ambiguity and such? We can use NLTK's power tools with spaCy as we wish. . .

# %%
import nltk
from nltk.corpus import wordnet as wn

# %%
setOfWords = set(myWords)
# ebb: remember, set() removes duplicates (takes distinct-values) in Python. 
lowerCased = [w.lower() for w in setOfWords]

sortedWords = sorted(lowerCased)
print(sortedWords)
# Out:
# ['\\pos(.,)}giorno', 'admit', 'anger', 'appear', 'attack', 'avoid', 'b*llet', 'be', 'bear', 'become', 'betray', 'blow', 'break', 'bring', 'call', 'catch', 'change', 'check', 'chew', 'choose', 'climb', 'come', 'confirm', 'control', 'corner', 'defeat', 'deflect', 'depend', 'destroy', 'detect', 'die', 'disappear', 'do', 'doany', 'dodge', 'dream', 'dumbass', 'eliminate', 'end', 'erase', 'escape', 'exist', 'fall', 'feel', 'figure', 'find', 'finish', 'fire', 'fit', 'fly', 'get', 'give', 'go', 'grab', 'grant', 'grasp', 'grovel', 'happen', 'have', 'head', 'hesitate', 'hide', 'hurry', 'increase', 'inhabit', 'intend', 'k*ll', 'k*lle', 'keep', 'knock', 'know', 'land', 'learn', 'leave', 'let', 'listen', 'live', 'look', 'lose', 'make', 'manifest', 'match', 'mean', 'mention', 'move', 'need', 'obtain', 'overcome', 'overuse', 'pass', 'perish', 'pick', 'pierce', 'play', 'possess', 'predict', 'put', 'realize', 'reload', 'remain', 'remember', 'return', 'reveal', 'rid', 'run', 'rush', 'say', 'see', 'seem', 'sense', 'shoot', 'shut', 'sing', 'skip', 'spread', 'start', 'stay', 'stick', 'stop', 'stretch', 'suck', 'surpass', 'swap', 'sweat', 'take', 'talk', 'tear', 'tell', 'think', 'throw', 'touch', 'trash', 'travel', 'try', 'understand', 'unleash', 'use', 'vanish', 'wait', 'waste', 'win']

# %%
for w in myWords:
    synsets = len(wn.synsets(w))
    print("The word ", w, "belongs to ", synsets, "synsets in WordNet.")
# Out:
# The word  use belongs to  13 synsets in WordNet.
# The word  get belongs to  37 synsets in WordNet.
# The word  feel belongs to  17 synsets in WordNet.
# The word  suck belongs to  8 synsets in WordNet.
# The word  say belongs to  12 synsets in WordNet.
# The word  have belongs to  20 synsets in WordNet.
# The word  go belongs to  35 synsets in WordNet.
# The word  go belongs to  35 synsets in WordNet.
# The word  go belongs to  35 synsets in WordNet.
# The word  win belongs to  6 synsets in WordNet.
# The word  call belongs to  41 synsets in WordNet.
# The word  have belongs to  20 synsets in WordNet.
# The word  escape belongs to  15 synsets in WordNet.
# The word  choose belongs to  3 synsets in WordNet.
# The word  remain belongs to  4 synsets in WordNet.
# The word  perish belongs to  1 synsets in WordNet.
# The word  exist belongs to  2 synsets in WordNet.
# The word  sing belongs to  5 synsets in WordNet.
# The word  vanish belongs to  5 synsets in WordNet.
# The word  hurry belongs to  6 synsets in WordNet.
# The word  pierce belongs to  6 synsets in WordNet.
# The word  go belongs to  35 synsets in WordNet.
# The word  head belongs to  42 synsets in WordNet.
# The word  stop belongs to  22 synsets in WordNet.
# The word  do belongs to  16 synsets in WordNet.
# The word  touch belongs to  27 synsets in WordNet.
# The word  let belongs to  8 synsets in WordNet.
# The word  go belongs to  35 synsets in WordNet.
# The word  let belongs to  8 synsets in WordNet.
# The word  go belongs to  35 synsets in WordNet.
# The word  take belongs to  44 synsets in WordNet.
# The word  get belongs to  37 synsets in WordNet.
# The word  think belongs to  14 synsets in WordNet.
# The word  talk belongs to  11 synsets in WordNet.
# The word  say belongs to  12 synsets in WordNet.
# The word  see belongs to  25 synsets in WordNet.
# The word  come belongs to  22 synsets in WordNet.
# The word  b*llet belongs to  0 synsets in WordNet.
# The word  see belongs to  25 synsets in WordNet.
# The word  break belongs to  75 synsets in WordNet.
# The word  overuse belongs to  2 synsets in WordNet.
# The word  break belongs to  75 synsets in WordNet.
# The word  have belongs to  20 synsets in WordNet.
# The word  doany belongs to  0 synsets in WordNet.
# The word  head belongs to  42 synsets in WordNet.
# The word  head belongs to  42 synsets in WordNet.
# The word  intend belongs to  4 synsets in WordNet.
# The word  finish belongs to  15 synsets in WordNet.
# The word  touch belongs to  27 synsets in WordNet.
# The word  reload belongs to  2 synsets in WordNet.
# The word  reload belongs to  2 synsets in WordNet.
# The word  need belongs to  7 synsets in WordNet.
# The word  take belongs to  44 synsets in WordNet.
# The word  reload belongs to  2 synsets in WordNet.
# The word  finish belongs to  15 synsets in WordNet.
# The word  throw belongs to  20 synsets in WordNet.
# The word  catch belongs to  39 synsets in WordNet.
# The word  go belongs to  35 synsets in WordNet.
# The word  throw belongs to  20 synsets in WordNet.
# The word  remember belongs to  8 synsets in WordNet.
# The word  say belongs to  12 synsets in WordNet.
# The word  be belongs to  14 synsets in WordNet.
# The word  start belongs to  22 synsets in WordNet.
# The word  understand belongs to  5 synsets in WordNet.
# The word  stop belongs to  22 synsets in WordNet.
# The word  come belongs to  22 synsets in WordNet.
# The word  start belongs to  22 synsets in WordNet.
# The word  change belongs to  20 synsets in WordNet.
# The word  stop belongs to  22 synsets in WordNet.
# The word  try belongs to  10 synsets in WordNet.
# The word  k*ll belongs to  0 synsets in WordNet.
# The word  go belongs to  35 synsets in WordNet.
# The word  make belongs to  51 synsets in WordNet.
# The word  swap belongs to  3 synsets in WordNet.
# The word  mean belongs to  16 synsets in WordNet.
# The word  make belongs to  51 synsets in WordNet.
# The word  start belongs to  22 synsets in WordNet.
# The word  change belongs to  20 synsets in WordNet.
# The word  start belongs to  22 synsets in WordNet.
# The word  play belongs to  52 synsets in WordNet.
# The word  give belongs to  45 synsets in WordNet.
# The word  k*lle belongs to  0 synsets in WordNet.
# The word  start belongs to  22 synsets in WordNet.
# The word  change belongs to  20 synsets in WordNet.
# The word  see belongs to  25 synsets in WordNet.
# The word  make belongs to  51 synsets in WordNet.
# The word  see belongs to  25 synsets in WordNet.
# The word  start belongs to  22 synsets in WordNet.
# The word  understand belongs to  5 synsets in WordNet.
# The word  figure belongs to  18 synsets in WordNet.
# The word  get belongs to  37 synsets in WordNet.
# The word  realize belongs to  6 synsets in WordNet.
# The word  go belongs to  35 synsets in WordNet.
# The word  spread belongs to  23 synsets in WordNet.
# The word  look belongs to  14 synsets in WordNet.
# The word  die belongs to  14 synsets in WordNet.
# The word  have belongs to  20 synsets in WordNet.
# The word  be belongs to  14 synsets in WordNet.
# The word  become belongs to  4 synsets in WordNet.
# The word  go belongs to  35 synsets in WordNet.
# The word  disappear belongs to  4 synsets in WordNet.
# The word  start belongs to  22 synsets in WordNet.
# The word  happen belongs to  5 synsets in WordNet.
# The word  start belongs to  22 synsets in WordNet.
# The word  have belongs to  20 synsets in WordNet.
# The word  leave belongs to  17 synsets in WordNet.
# The word  say belongs to  12 synsets in WordNet.
# The word  happen belongs to  5 synsets in WordNet.
# The word  bring belongs to  11 synsets in WordNet.
# The word  say belongs to  12 synsets in WordNet.
# The word  have belongs to  20 synsets in WordNet.
# The word  defeat belongs to  4 synsets in WordNet.
# The word  end belongs to  18 synsets in WordNet.
# The word  stop belongs to  22 synsets in WordNet.
# The word  find belongs to  18 synsets in WordNet.
# The word  defeat belongs to  4 synsets in WordNet.
# The word  get belongs to  37 synsets in WordNet.
# The word  get belongs to  37 synsets in WordNet.
# The word  get belongs to  37 synsets in WordNet.
# The word  see belongs to  25 synsets in WordNet.
# The word  become belongs to  4 synsets in WordNet.
# The word  grovel belongs to  1 synsets in WordNet.
# The word  move belongs to  21 synsets in WordNet.
# The word  stay belongs to  16 synsets in WordNet.
# The word  stay belongs to  16 synsets in WordNet.
# The word  tell belongs to  9 synsets in WordNet.
# The word  move belongs to  21 synsets in WordNet.
# The word  catch belongs to  39 synsets in WordNet.
# The word  shut belongs to  5 synsets in WordNet.
# The word  dumbass belongs to  1 synsets in WordNet.
# The word  disappear belongs to  4 synsets in WordNet.
# The word  pick belongs to  21 synsets in WordNet.
# The word  say belongs to  12 synsets in WordNet.
# The word  break belongs to  75 synsets in WordNet.
# The word  match belongs to  19 synsets in WordNet.
# The word  break belongs to  75 synsets in WordNet.
# The word  fit belongs to  16 synsets in WordNet.
# The word  get belongs to  37 synsets in WordNet.
# The word  need belongs to  7 synsets in WordNet.
# The word  stay belongs to  16 synsets in WordNet.
# The word  need belongs to  7 synsets in WordNet.
# The word  keep belongs to  25 synsets in WordNet.
# The word  get belongs to  37 synsets in WordNet.
# The word  say belongs to  12 synsets in WordNet.
# The word  have belongs to  20 synsets in WordNet.
# The word  match belongs to  19 synsets in WordNet.
# The word  fly belongs to  20 synsets in WordNet.
# The word  tell belongs to  9 synsets in WordNet.
# The word  see belongs to  25 synsets in WordNet.
# The word  lose belongs to  11 synsets in WordNet.
# The word  give belongs to  45 synsets in WordNet.
# The word  let belongs to  8 synsets in WordNet.
# The word  look belongs to  14 synsets in WordNet.
# The word  return belongs to  29 synsets in WordNet.
# The word  find belongs to  18 synsets in WordNet.
# The word  wait belongs to  6 synsets in WordNet.
# The word  say belongs to  12 synsets in WordNet.
# The word  use belongs to  13 synsets in WordNet.
# The word  tear belongs to  9 synsets in WordNet.
# The word  listen belongs to  3 synsets in WordNet.
# The word  be belongs to  14 synsets in WordNet.
# The word  get belongs to  37 synsets in WordNet.
# The word  do belongs to  16 synsets in WordNet.
# The word  need belongs to  7 synsets in WordNet.
# The word  stay belongs to  16 synsets in WordNet.
# The word  get belongs to  37 synsets in WordNet.
# The word  attack belongs to  15 synsets in WordNet.
# The word  have belongs to  20 synsets in WordNet.
# The word  get belongs to  37 synsets in WordNet.
# The word  inhabit belongs to  3 synsets in WordNet.
# The word  stay belongs to  16 synsets in WordNet.
# The word  detect belongs to  1 synsets in WordNet.
# The word  hide belongs to  6 synsets in WordNet.
# The word  wait belongs to  6 synsets in WordNet.
# The word  obtain belongs to  3 synsets in WordNet.
# The word  appear belongs to  7 synsets in WordNet.
# The word  destroy belongs to  4 synsets in WordNet.
# The word  know belongs to  12 synsets in WordNet.
# The word  keep belongs to  25 synsets in WordNet.
# The word  say belongs to  12 synsets in WordNet.
# The word  stay belongs to  16 synsets in WordNet.
# The word  stay belongs to  16 synsets in WordNet.
# The word  destroy belongs to  4 synsets in WordNet.
# The word  attack belongs to  15 synsets in WordNet.
# The word  do belongs to  16 synsets in WordNet.
# The word  keep belongs to  25 synsets in WordNet.
# The word  move belongs to  21 synsets in WordNet.
# The word  hide belongs to  6 synsets in WordNet.
# The word  have belongs to  20 synsets in WordNet.
# The word  make belongs to  51 synsets in WordNet.
# The word  appear belongs to  7 synsets in WordNet.
# The word  have belongs to  20 synsets in WordNet.
# The word  inhabit belongs to  3 synsets in WordNet.
# The word  have belongs to  20 synsets in WordNet.
# The word  inhabit belongs to  3 synsets in WordNet.
# The word  stay belongs to  16 synsets in WordNet.
# The word  manifest belongs to  5 synsets in WordNet.
# The word  move belongs to  21 synsets in WordNet.
# The word  live belongs to  19 synsets in WordNet.
# The word  eliminate belongs to  7 synsets in WordNet.
# The word  have belongs to  20 synsets in WordNet.
# The word  possess belongs to  3 synsets in WordNet.
# The word  k*lle belongs to  0 synsets in WordNet.
# The word  destroy belongs to  4 synsets in WordNet.
# The word  let belongs to  8 synsets in WordNet.
# The word  inhabit belongs to  3 synsets in WordNet.
# The word  put belongs to  10 synsets in WordNet.
# The word  sense belongs to  9 synsets in WordNet.
# The word  have belongs to  20 synsets in WordNet.
# The word  tell belongs to  9 synsets in WordNet.
# The word  get belongs to  37 synsets in WordNet.
# The word  touch belongs to  27 synsets in WordNet.
# The word  touch belongs to  27 synsets in WordNet.
# The word  tell belongs to  9 synsets in WordNet.
# The word  be belongs to  14 synsets in WordNet.
# The word  be belongs to  14 synsets in WordNet.
# The word  have belongs to  20 synsets in WordNet.
# The word  touch belongs to  27 synsets in WordNet.
# The word  find belongs to  18 synsets in WordNet.
# The word  go belongs to  35 synsets in WordNet.
# The word  get belongs to  37 synsets in WordNet.
# The word  learn belongs to  6 synsets in WordNet.
# The word  detect belongs to  1 synsets in WordNet.
# The word  increase belongs to  7 synsets in WordNet.
# The word  skip belongs to  8 synsets in WordNet.
# The word  avoid belongs to  5 synsets in WordNet.
# The word  dodge belongs to  6 synsets in WordNet.
# The word  k*lle belongs to  0 synsets in WordNet.
# The word  check belongs to  38 synsets in WordNet.
# The word  stop belongs to  22 synsets in WordNet.
# The word  stay belongs to  16 synsets in WordNet.
# The word  come belongs to  22 synsets in WordNet.
# The word  go belongs to  35 synsets in WordNet.
# The word  happen belongs to  5 synsets in WordNet.
# The word  die belongs to  14 synsets in WordNet.
# The word  travel belongs to  9 synsets in WordNet.
# The word  be belongs to  14 synsets in WordNet.
# The word  possess belongs to  3 synsets in WordNet.
# The word  say belongs to  12 synsets in WordNet.
# The word  have belongs to  20 synsets in WordNet.
# The word  confirm belongs to  5 synsets in WordNet.
# The word  mention belongs to  6 synsets in WordNet.
# The word  have belongs to  20 synsets in WordNet.
# The word  confirm belongs to  5 synsets in WordNet.
# The word  have belongs to  20 synsets in WordNet.
# The word  check belongs to  38 synsets in WordNet.
# The word  go belongs to  35 synsets in WordNet.
# The word  find belongs to  18 synsets in WordNet.
# The word  come belongs to  22 synsets in WordNet.
# The word  blow belongs to  29 synsets in WordNet.
# The word  stop belongs to  22 synsets in WordNet.
# The word  check belongs to  38 synsets in WordNet.
# The word  hurry belongs to  6 synsets in WordNet.
# The word  do belongs to  16 synsets in WordNet.
# The word  lose belongs to  11 synsets in WordNet.
# The word  say belongs to  12 synsets in WordNet.
# The word  depend belongs to  2 synsets in WordNet.
# The word  look belongs to  14 synsets in WordNet.
# The word  have belongs to  20 synsets in WordNet.
# The word  corner belongs to  14 synsets in WordNet.
# The word  be belongs to  14 synsets in WordNet.
# The word  have belongs to  20 synsets in WordNet.
# The word  do belongs to  16 synsets in WordNet.
# The word  go belongs to  35 synsets in WordNet.
# The word  attack belongs to  15 synsets in WordNet.
# The word  get belongs to  37 synsets in WordNet.
# The word  possess belongs to  3 synsets in WordNet.
# The word  get belongs to  37 synsets in WordNet.
# The word  move belongs to  21 synsets in WordNet.
# The word  wait belongs to  6 synsets in WordNet.
# The word  unleash belongs to  3 synsets in WordNet.
# The word  swap belongs to  3 synsets in WordNet.
# The word  have belongs to  20 synsets in WordNet.
# The word  mean belongs to  16 synsets in WordNet.
# The word  die belongs to  14 synsets in WordNet.
# The word  possess belongs to  3 synsets in WordNet.
# The word  \pos(.,)}giorno belongs to  0 synsets in WordNet.
# The word  reveal belongs to  3 synsets in WordNet.
# The word  corner belongs to  14 synsets in WordNet.
# The word  grab belongs to  8 synsets in WordNet.
# The word  move belongs to  21 synsets in WordNet.
# The word  make belongs to  51 synsets in WordNet.
# The word  run belongs to  57 synsets in WordNet.
# The word  go belongs to  35 synsets in WordNet.
# The word  attack belongs to  15 synsets in WordNet.
# The word  go belongs to  35 synsets in WordNet.
# The word  make belongs to  51 synsets in WordNet.
# The word  tell belongs to  9 synsets in WordNet.
# The word  run belongs to  57 synsets in WordNet.
# The word  attack belongs to  15 synsets in WordNet.
# The word  find belongs to  18 synsets in WordNet.
# The word  get belongs to  37 synsets in WordNet.
# The word  be belongs to  14 synsets in WordNet.
# The word  take belongs to  44 synsets in WordNet.
# The word  let belongs to  8 synsets in WordNet.
# The word  get belongs to  37 synsets in WordNet.
# The word  stop belongs to  22 synsets in WordNet.
# The word  waste belongs to  16 synsets in WordNet.
# The word  hesitate belongs to  2 synsets in WordNet.
# The word  fire belongs to  18 synsets in WordNet.
# The word  seem belongs to  4 synsets in WordNet.
# The word  fire belongs to  18 synsets in WordNet.
# The word  run belongs to  57 synsets in WordNet.
# The word  make belongs to  51 synsets in WordNet.
# The word  predict belongs to  2 synsets in WordNet.
# The word  get belongs to  37 synsets in WordNet.
# The word  finish belongs to  15 synsets in WordNet.
# The word  touch belongs to  27 synsets in WordNet.
# The word  move belongs to  21 synsets in WordNet.
# The word  move belongs to  21 synsets in WordNet.
# The word  mean belongs to  16 synsets in WordNet.
# The word  look belongs to  14 synsets in WordNet.
# The word  stretch belongs to  20 synsets in WordNet.
# The word  stretch belongs to  20 synsets in WordNet.
# The word  mean belongs to  16 synsets in WordNet.
# The word  depend belongs to  2 synsets in WordNet.
# The word  control belongs to  19 synsets in WordNet.
# The word  attack belongs to  15 synsets in WordNet.
# The word  mean belongs to  16 synsets in WordNet.
# The word  attack belongs to  15 synsets in WordNet.
# The word  rid belongs to  1 synsets in WordNet.
# The word  get belongs to  37 synsets in WordNet.
# The word  have belongs to  20 synsets in WordNet.
# The word  have belongs to  20 synsets in WordNet.
# The word  rush belongs to  16 synsets in WordNet.
# The word  destroy belongs to  4 synsets in WordNet.
# The word  get belongs to  37 synsets in WordNet.
# The word  have belongs to  20 synsets in WordNet.
# The word  find belongs to  18 synsets in WordNet.
# The word  grasp belongs to  6 synsets in WordNet.
# The word  take belongs to  44 synsets in WordNet.
# The word  tear belongs to  9 synsets in WordNet.
# The word  appear belongs to  7 synsets in WordNet.
# The word  happen belongs to  5 synsets in WordNet.
# The word  let belongs to  8 synsets in WordNet.
# The word  go belongs to  35 synsets in WordNet.
# The word  have belongs to  20 synsets in WordNet.
# The word  hurry belongs to  6 synsets in WordNet.
# The word  let belongs to  8 synsets in WordNet.
# The word  grab belongs to  8 synsets in WordNet.
# The word  shoot belongs to  22 synsets in WordNet.
# The word  make belongs to  51 synsets in WordNet.
# The word  predict belongs to  2 synsets in WordNet.
# The word  knock belongs to  11 synsets in WordNet.
# The word  come belongs to  22 synsets in WordNet.
# The word  knock belongs to  11 synsets in WordNet.
# The word  bring belongs to  11 synsets in WordNet.
# The word  throw belongs to  20 synsets in WordNet.
# The word  figure belongs to  18 synsets in WordNet.
# The word  land belongs to  18 synsets in WordNet.
# The word  return belongs to  29 synsets in WordNet.
# The word  be belongs to  14 synsets in WordNet.
# The word  surpass belongs to  4 synsets in WordNet.
# The word  get belongs to  37 synsets in WordNet.
# The word  trash belongs to  6 synsets in WordNet.
# The word  admit belongs to  8 synsets in WordNet.
# The word  make belongs to  51 synsets in WordNet.
# The word  sweat belongs to  5 synsets in WordNet.
# The word  dream belongs to  8 synsets in WordNet.
# The word  betray belongs to  6 synsets in WordNet.
# The word  think belongs to  14 synsets in WordNet.
# The word  find belongs to  18 synsets in WordNet.
# The word  figure belongs to  18 synsets in WordNet.
# The word  grant belongs to  15 synsets in WordNet.
# The word  defeat belongs to  4 synsets in WordNet.
# The word  need belongs to  7 synsets in WordNet.
# The word  b*llet belongs to  0 synsets in WordNet.
# The word  tell belongs to  9 synsets in WordNet.
# The word  take belongs to  44 synsets in WordNet.
# The word  reload belongs to  2 synsets in WordNet.
# The word  finish belongs to  15 synsets in WordNet.
# The word  deflect belongs to  5 synsets in WordNet.
# The word  make belongs to  51 synsets in WordNet.
# The word  stretch belongs to  20 synsets in WordNet.
# The word  chew belongs to  3 synsets in WordNet.
# The word  stick belongs to  25 synsets in WordNet.
# The word  have belongs to  20 synsets in WordNet.
# The word  use belongs to  13 synsets in WordNet.
# The word  return belongs to  29 synsets in WordNet.
# The word  blow belongs to  29 synsets in WordNet.
# The word  go belongs to  35 synsets in WordNet.
# The word  overcome belongs to  4 synsets in WordNet.
# The word  go belongs to  35 synsets in WordNet.
# The word  live belongs to  19 synsets in WordNet.
# The word  run belongs to  57 synsets in WordNet.
# The word  pass belongs to  43 synsets in WordNet.
# The word  climb belongs to  9 synsets in WordNet.
# The word  fly belongs to  20 synsets in WordNet.
# The word  get belongs to  37 synsets in WordNet.
# The word  predict belongs to  2 synsets in WordNet.
# The word  fall belongs to  44 synsets in WordNet.
# The word  erase belongs to  3 synsets in WordNet.
# The word  bear belongs to  15 synsets in WordNet.
# The word  come belongs to  22 synsets in WordNet.
# The word  anger belongs to  5 synsets in WordNet.
# The word  say belongs to  12 synsets in WordNet.
# The word  overcome belongs to  4 synsets in WordNet.
# The word  do belongs to  16 synsets in WordNet.
# The word  surpass belongs to  4 synsets in WordNet.

# %% [markdown]
# ## PyGal Fun with Ambiguity Data
# Okay, what if I want to customize the colors of my plot using the synset ambiguity information?
# This is a little tricky, but we can work with the rgb() color values to plot on a scale of 0 to 255. Here's a little recipe I cooked up, and I got a little help from ChatGPT for the color function.

# %%
from collections import Counter
import pygal
from pygal.style import Style
from nltk.corpus import wordnet as wn

word_freq = Counter(myWords)
topTen = word_freq.most_common(10)
print(topTen)

# Step 1: Get synset count for each of the top 10 verbs
synset_counts = {}
for word, freq in topTen:
    synset_counts[word] = len(wn.synsets(word, pos='v'))
    # ebb: Note: we're giving wordnet the pos (part of speech) value of "v" for verb to make sure we get the correct synsets back.
    # If you're trying to search up adjectives (like I did in class, you should change the pos variable to match what Wordnet knows.
    # From the Wordnet documentation at https://wordnet.princeton.edu/documentation/wndb5wn here are some standard Wordnet pos tags:
        # n    NOUN 
        # v    VERB 
        # a    ADJECTIVE 
        # s    ADJECTIVE SATELLITE 
        # r    ADVERB 

# Step 2: Normalize synset counts to 0–255 for coloring
max_syn = max(synset_counts.values())
min_syn = min(synset_counts.values())

def synset_to_color(syn_count):
    """Maps synset count to a shade of blue (darker = more ambiguous)"""
    if max_syn == min_syn:
        blue = 150
    else:
        blue = int(50 + 205 * (syn_count - min_syn) / (max_syn - min_syn))
    return f'#{0:02x}{0:02x}{blue:02x}'

# Step 3: Create custom Pygal style
custom_style = Style(
    background='white',
    plot_background='white',
    foreground='black',
    foreground_strong='black',
    foreground_subtle='gray',
    opacity='.8',
    opacity_hover='.9',
    transition='400ms ease-in',
    colors=('#cccccc',)  # Give PyGal a dummy color to start
)

# Step 4: Create the bar chart
bar_chart = pygal.Bar(style=custom_style)
bar_chart.title = 'Top 10 Verb Frequencies Colored by Ambiguity (Synsets)'

for word, freq in topTen:
    syns = synset_counts[word]
    color = synset_to_color(syns)
    bar_chart.add(word, [{'value': freq, 'label': f'{word} has {syns} synsets', 'style': f'fill:{color}'}])
    # I can add whatever new info I want (beyond the 'value') to PyGal's tooltip using 'label': 

# Step 5: Render the SVG chart
bar_chart.render_to_file('top_verbs_colored_by_synsets.svg')
# Out:
# [('have', 25), ('get', 22), ('go', 19), ('say', 12), ('make', 10), ('be', 9), ('stay', 9), ('start', 8), ('move', 8), ('stop', 7)]

# %% [markdown]
# ## Your Turn!
# Adapt this notebook to explore one or more of your project files. Be sure that you are able to:
# * **Open a file with Python first before you tokenize it**. (This time, try out spaCy.)
# * Collect a selection of words, with POS tagging or without it. (Can you output all the tokens that just have the same beginning or ending?)
# * Options:
#      * Send your words or word lemmas to WordNet and return synset info, and/or
#      * Find out about how frequently each of your selected tokens is used in the text using the Counter.
# * This time, **open a file to write some of the information you retrieve to output**.
# * Add, commit, and push to your GitHub repo.
